# %% [markdown]
# <a href="https://colab.research.google.com/github/k-vinamr/rera_construction_pred/blob/main/7_floor_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display
import statsmodels as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.model_selection import train_test_split,GridSearchCV,RandomizedSearchCV
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor
from sklearn.metrics import r2_score,mean_squared_error
from sklearn import preprocessing
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from datetime import datetime
# Load your dataset
data = pd.read_csv('augmented_7_floor.csv')

# %%
data
# Out:
#                     organisation_name           project_category  \
# 0     NAKSHATRA BUILDERS & DEVELOPERS  Residential/Group Housing
# 1           KRISHNA BHOORARAM PUROHIT  Residential/Group Housing
# 2                 Sudarshan Realities  Residential/Group Housing
# 3                         Sai Reality  Residential/Group Housing
# 4                    SAGAR DEVELOPERS  Residential/Group Housing
# ...                               ...                        ...
# 9995                  ADITYA BUILDCON  Residential/Group Housing
# 9996                  PRISHA REALTORS  Residential/Group Housing
# 9997                SHREYASH BUILDCON  Residential/Group Housing
# 9998          SHRIPAD VINAYAK THOMBRE  Residential/Group Housing
# 9999     SHREE VASTUNIRMAN DEVELOPERS  Residential/Group Housing
#
#      actual_commencement_date estimated_finish_date  \
# 0                  14-08-2017            15-11-2017
# 1                  09-09-2021            30-12-2021
# 2                  09-09-2021            30-12-2021
# 3                  09-09-2021            30-12-2021
# 4                  09-09-2021            30-12-2021
# ...                       ...                   ...
# 9995               06-11-2022            25-02-2023
# 9996               01-06-2023            28-12-2026
# 9997               01-03-2023            31-12-2025
# 9998               26-01-2018            06-07-2019
# 9999               08-07-2023            06-04-2025
#
#       total_built_up_area_saleable_area  total_area_of_project  floor  \
# 0                           2214.080000            1341.870000      7
# 1                            821.670000             442.200000      7
# 2                            704.300000             507.240000      7
# 3                            886.600000             513.750000      7
# 4                            700.000000             538.170000      7
# ...                                 ...                    ...    ...
# 9995                         817.240769             373.884892      7
# 9996                        9622.471757            4143.100420      7
# 9997                       11674.584460            5842.718848      7
# 9998                        2460.790003            3707.900268      7
# 9999                        3401.524935            1109.845002      7
#
#      project_state  total_days  Cleaning & survey  ...  Tiles work  \
# 0      MAHARASHTRA          93           0.463609  ...    8.344965
# 1      MAHARASHTRA         112           0.558325  ...   10.049850
# 2      MAHARASHTRA         112           0.558325  ...   10.049850
# 3      MAHARASHTRA         112           0.558325  ...   10.049850
# 4      MAHARASHTRA         112           0.558325  ...   10.049850
# ...            ...         ...                ...  ...         ...
# 9995   MAHARASHTRA         117           0.583250  ...   10.498504
# 9996   MAHARASHTRA        1307           6.515454  ...  117.278166
# 9997   MAHARASHTRA        1043           5.199402  ...   93.589232
# 9998   MAHARASHTRA         514           2.562313  ...   46.121635
# 9999   MAHARASHTRA         638           3.180459  ...   57.248255
#
#       Painting and Finishing  Plumbing & Sanitary,Electrification Works  \
# 0                   8.344965                                   5.563310
# 1                  10.049850                                   6.699900
# 2                  10.049850                                   6.699900
# 3                  10.049850                                   6.699900
# 4                  10.049850                                   6.699900
# ...                      ...                                        ...
# 9995               10.498504                                   6.999003
# 9996              117.278166                                  78.185444
# 9997               93.589232                                  62.392822
# 9998               46.121635                                  30.747757
# 9999               57.248255                                  38.165503
#
#       Doors & Windows Fixing Furniture work  other work  \
# 0                                  8.344965    2.781655
# 1                                 10.049850    3.349950
# 2                                 10.049850    3.349950
# 3                                 10.049850    3.349950
# 4                                 10.049850    3.349950
# ...                                     ...         ...
# 9995                              10.498504    3.499501
# 9996                             117.278166   39.092722
# 9997                              93.589232   31.196411
# 9998                              46.121635   15.373878
# 9999                              57.248255   19.082752
#
#       duration_since_commencement  remaining_duration  progress_ratio  \
# 0                            2269               -2177       24.397849
# 1                             782                -671        6.982143
# 2                             782                -671        6.982143
# 3                             782                -671        6.982143
# 4                             782                -671        6.982143
# ...                           ...                 ...             ...
# 9995                          361                -245        3.085470
# 9996                          150                1156        0.114767
# 9997                          251                 791        0.240652
# 9998                         2098               -1585        4.081712
# 9999                          121                 516        0.189655
#
#       current_stage        area_bin
# 0         completed    (2000, 2500]
# 1         completed     (500, 1000]
# 2         completed     (500, 1000]
# 3         completed     (500, 1000]
# 4         completed     (500, 1000]
# ...             ...             ...
# 9995      completed     (500, 1000]
# 9996        running   (9500, 10000]
# 9997        running  (11500, 12000]
# 9998      completed    (2000, 2500]
# 9999        running    (3000, 3500]
#
# [10000 rows x 51 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 51 columns):
#  #   Column                                                                     Non-Null Count  Dtype
# ---  ------                                                                     --------------  -----
#  0   organisation_name                                                          10000 non-null  object
#  1   project_category                                                           10000 non-null  object
#  2   actual_commencement_date                                                   10000 non-null  object
#  3   estimated_finish_date                                                      10000 non-null  object
#  4   total_built_up_area_saleable_area                                          10000 non-null  float64
#  5   total_area_of_project                                                      10000 non-null  float64
#  6   floor                                                                      10000 non-null  int64
#  7   project_state                                                              10000 non-null  object
#  8   total_days                                                                 10000 non-null  int64
#  9   Cleaning & survey                                                          10000 non-null  float64
#  10  Excavation,leveling & P.C.C  for Basement  B1                              10000 non-null  float64
#  11   Raft footing, Column B1, Retaining wall Reinforcement ,Concrete pouring   10000 non-null  float64
#  12  Slab of B (bottom)                                                         10000 non-null  float64
#  13   Ground Floor slab casting                                                 10000 non-null  float64
#  14   1st floor Columns casting                                                 10000 non-null  float64
#  15   1st Floor slab casting                                                    10000 non-null  float64
#  16  2nd floor Columns casting                                                  10000 non-null  float64
#  17  2nd Floor slab casting                                                     10000 non-null  float64
#  18   Brick work at Basement to Ground Floor                                    10000 non-null  float64
#  19  Electrical concealed, PVC Fitting, plastering at Basement                  10000 non-null  float64
#  20  3rd floor Columns casting                                                  10000 non-null  float64
#  21  3rd Floor slab casting                                                     10000 non-null  float64
#  22   Brick work at 1st Floor                                                   10000 non-null  float64
#  23  Electrical concealed, PVC Fitting, plastering at ground floor              10000 non-null  float64
#  24  4th floor Columns casting                                                  10000 non-null  float64
#  25  4th Floor slab casting                                                     10000 non-null  float64
#  26   Brick work at 2nd Floor                                                   10000 non-null  float64
#  27  Electrical concealed, PVC Fitting, plastering at 1st floor                 10000 non-null  float64
#  28  5th floor Columns casting                                                  10000 non-null  float64
#  29  5th Floor slab casting                                                     10000 non-null  float64
#  30   Brick work at 3rd Floor                                                   10000 non-null  float64
#  31  Electrical concealed, PVC Fitting, plastering at 2nd floor                 10000 non-null  float64
#  32  6th floor Columns casting                                                  10000 non-null  float64
#  33  6th Floor slab casting                                                     10000 non-null  float64
#  34   Brick work at 4th Floor                                                   10000 non-null  float64
#  35  Electrical concealed, PVC Fitting, plastering at 3rd floor                 10000 non-null  float64
#  36  7th floor Columns casting                                                  10000 non-null  float64
#  37  7th Floor slab casting                                                     10000 non-null  float64
#  38   Brickwork of  5th to 7th Floor                                            10000 non-null  float64
#  39  Electrical concealed, PVC Fitting, plastering at 4th-7th floor             10000 non-null  float64
#  40  Plastering on outer sides                                                  10000 non-null  float64
#  41  Tiles work                                                                 10000 non-null  float64
#  42  Painting and Finishing                                                     10000 non-null  float64
#  43  Plumbing & Sanitary,Electrification Works                                  10000 non-null  float64
#  44  Doors & Windows Fixing Furniture work                                      10000 non-null  float64
#  45  other work                                                                 10000 non-null  float64
#  46  duration_since_commencement                                                10000 non-null  int64
#  47  remaining_duration                                                         10000 non-null  int64
#  48  progress_ratio                                                             10000 non-null  float64
#  49  current_stage                                                              10000 non-null  object
#  50  area_bin                                                                   10000 non-null  object
# dtypes: float64(40), int64(4), object(7)
# memory usage: 3.9+ MB

# %%
# Converting date columns to datetime objects
data['actual_commencement_date'] = pd.to_datetime(data['actual_commencement_date'], errors='coerce')
data['estimated_finish_date'] = pd.to_datetime(data['estimated_finish_date'], errors='coerce')
# Out:
# <ipython-input-21-1b85272236a7>:2: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   data['actual_commencement_date'] = pd.to_datetime(data['actual_commencement_date'], errors='coerce')
# <ipython-input-21-1b85272236a7>:3: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   data['estimated_finish_date'] = pd.to_datetime(data['estimated_finish_date'], errors='coerce')

# %%
current_date = datetime.now()

# %%
data['duration_since_commencement'] = (current_date - data['actual_commencement_date']).dt.days
data['remaining_duration'] = (data['estimated_finish_date'] - current_date).dt.days
data['progress_ratio'] = data['duration_since_commencement'] / data['total_days']

# %%
# Define a function to determine the project status
def determine_status(row):
    if current_date > row['estimated_finish_date']:
        return 'completed'
    elif current_date >= row['actual_commencement_date']:
        return 'running'
    else:
        return 'upcoming'

# Apply the function to create the 'Status' column
data['current_stage'] = data.apply(determine_status, axis=1)

# %%
data.columns
# Out:
# Index(['organisation_name', 'project_category', 'actual_commencement_date',
#        'estimated_finish_date', 'total_built_up_area_saleable_area',
#        'total_area_of_project', 'floor', 'project_state', 'total_days',
#        'Cleaning & survey', 'Excavation,leveling & P.C.C  for Basement  B1 ',
#        ' Raft footing, Column B1, Retaining wall Reinforcement ,Concrete pouring ',
#        'Slab of B (bottom) ', ' Ground Floor slab casting ',
#        ' 1st floor Columns casting', ' 1st Floor slab casting',
#        '2nd floor Columns casting ', '2nd Floor slab casting',
#        ' Brick work at Basement to Ground Floor ',
#        'Electrical concealed, PVC Fitting, plastering at Basement',
#        '3rd floor Columns casting ', '3rd Floor slab casting',
#        ' Brick work at 1st Floor ',
#        'Electrical concealed, PVC Fitting, plastering at ground floor',
#        '4th floor Columns casting ', '4th Floor slab casting',
#        ' Brick work at 2nd Floor ',
#        'Electrical concealed, PVC Fitting, plastering at 1st floor',
#        '5th floor Columns casting ', '5th Floor slab casting',
#        ' Brick work at 3rd Floor ',
#        'Electrical concealed, PVC Fitting, plastering at 2nd floor',
#        '6th floor Columns casting ', '6th Floor slab casting',
#        ' Brick work at 4th Floor ',
#        'Electrical concealed, PVC Fitting, plastering at 3rd floor',
#        '7th floor Columns casting ', '7th Floor slab casting',
#        ' Brickwork of  5th to 7th Floor ',
#        'Electrical concealed, PVC Fitting, plastering at 4th-7th floor',
#        'Plastering on outer sides', 'Tiles work', 'Painting and Finishing',
#        'Plumbing & Sanitary,Electrification Works',
#        'Doors & Windows Fixing Furniture work', 'other work',
#        'duration_since_commencement', 'remaining_duration', 'progress_ratio',
#        'current_stage', 'area_bin'],
#       dtype='object')

# %%
# Performing label encoding on the 'current_stage' column
label_encoder = LabelEncoder()
data['current_stage'] = data['current_stage'].astype(str) # Converting to string to handle any NaN values left
data['current_stage_encoded'] = label_encoder.fit_transform(data['current_stage'])

# %%
# Performing label encoding on the 'current_stage' column
label_encoder = LabelEncoder()
data['project_state'] = data['project_state'].astype(str) # Converting to string to handle any NaN values left
data['project_state_encoded'] = label_encoder.fit_transform(data['project_state'])

# %%
(data['current_stage'].value_counts()).plot(kind='barh'); plt.show()

# %%
data['total_days'].describe()
# Out:
# count    10000.000000
# mean       952.426300
# std        515.095608
# min         93.000000
# 25%        567.750000
# 50%        901.000000
# 75%       1239.000000
# max       3375.000000
# Name: total_days, dtype: float64

# %%
# Feature selection - use relevant features for input
numerical_columns = data.select_dtypes(include=['int64', 'float64'])
stage_columns = [ 'Cleaning & survey',
       'Excavation,leveling & P.C.C  for Basement  B1 ',
       ' Raft footing, Column B1, Retaining wall Reinforcement ,Concrete pouring ',
       'Slab of B (bottom) ', ' Ground Floor slab casting ',
       ' 1st floor Columns casting', ' 1st Floor slab casting',
       '2nd floor Columns casting ', '2nd Floor slab casting',
       ' Brick work at Basement to Ground Floor ',
       'Electrical concealed, PVC Fitting, plastering at Basement',
       '3rd floor Columns casting ', '3rd Floor slab casting',
       ' Brick work at 1st Floor ',
       'Electrical concealed, PVC Fitting, plastering at ground floor',
       '4th floor Columns casting ', '4th Floor slab casting',
       ' Brick work at 2nd Floor ',
       'Electrical concealed, PVC Fitting, plastering at 1st floor',
       '5th floor Columns casting ', '5th Floor slab casting',
       ' Brick work at 3rd Floor ',
       'Electrical concealed, PVC Fitting, plastering at 2nd floor',
       '6th floor Columns casting ', '6th Floor slab casting',
       ' Brick work at 4th Floor ',
       'Electrical concealed, PVC Fitting, plastering at 3rd floor',
       '7th floor Columns casting ', '7th Floor slab casting',
       ' Brickwork of  5th to 7th Floor ',
       'Electrical concealed, PVC Fitting, plastering at 4th-7th floor',
       'Plastering on outer sides', 'Tiles work', 'Painting and Finishing',
       'Plumbing & Sanitary,Electrification Works',
       'Doors & Windows Fixing Furniture work', 'other work']
# Target variables
X = data[numerical_columns.columns.difference(stage_columns)].drop(columns='total_days')
y_total_days = data['total_days']
y_time_taken_at_each_stage = data[stage_columns]

# %%
X.columns
# Out:
# Index(['current_stage_encoded', 'duration_since_commencement', 'floor',
#        'progress_ratio', 'project_state_encoded', 'remaining_duration',
#        'total_area_of_project', 'total_built_up_area_saleable_area'],
#       dtype='object')

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# Assuming you have loaded your data and defined 'X' and 'y_total_days' as specified

# Split the data into training and testing sets
X_train, X_test, y_train_total_days, y_test_total_days = train_test_split(
    X, y_total_days, test_size=0.2, random_state=42)

# Create a function to train a Random Forest regression model, make predictions, and evaluate its performance
def train_evaluate_model(X_train, X_test, y_train_total_days, y_test_total_day):
    model = RandomForestRegressor(n_estimators=100, random_state=42)
    model.fit(X_train, y_train_total_days)
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test_total_days, y_pred)
    r2 = r2_score(y_test_total_days, y_pred)
    return mse, r2

# Initial model performance
initial_mse, initial_r2 = train_evaluate_model(X_train, X_test, y_train_total_days, y_test_total_days)
feature_impact = {}

for column in X.columns:
    X_temp = X.drop(columns=[column])
    mse, r2 = train_evaluate_model(X_train, X_test, y_train_total_days, y_test_total_days)
    mse_change = initial_mse - mse
    r2_change = r2 - initial_r2
    feature_impact[column] = {'MSE Change': mse_change, 'R-squared Change': r2_change}

# Print the impact of removing each feature
for column, impact in feature_impact.items():
    print(f"Removed '{column}':")
    print(f"MSE Change: {impact['MSE Change']:.2f}")
    print(f"R-squared Change: {impact['R-squared Change']:.4f}\n")
# Out:
# Removed 'current_stage_encoded':
# MSE Change: 0.00
# R-squared Change: 0.0000
#
# Removed 'duration_since_commencement':
# MSE Change: 0.00
# R-squared Change: 0.0000
#
# Removed 'floor':
# MSE Change: 0.00
# R-squared Change: 0.0000
#
# Removed 'progress_ratio':
# MSE Change: 0.00
# R-squared Change: 0.0000
#
# Removed 'project_state_encoded':
# MSE Change: 0.00
# R-squared Change: 0.0000
#
# Removed 'remaining_duration':
# MSE Change: 0.00
# R-squared Change: 0.0000
#
# Removed 'total_area_of_project':
# MSE Change: 0.00
# R-squared Change: 0.0000
#
# Removed 'total_built_up_area_saleable_area':
# MSE Change: 0.00
# R-squared Change: 0.0000

# %%
# Train a Random Forest model on the entire dataset
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X, y_total_days)

# Get feature importances
importances = model.feature_importances_

# Pair feature names with their importance scores
feature_importance = list(zip(X.columns, importances))

# Sort features by importance (in descending order)
feature_importance.sort(key=lambda x: x[1], reverse=True)

# Print the feature importances
for feature, importance in feature_importance:
    print(f"{feature}: {importance:.4f}")
# Out:
# remaining_duration: 0.6328
# progress_ratio: 0.2156
# duration_since_commencement: 0.1465
# total_area_of_project: 0.0025
# total_built_up_area_saleable_area: 0.0023
# current_stage_encoded: 0.0001
# project_state_encoded: 0.0001
# floor: 0.0000

# %%
# Split the data into training and testing sets
X_train, X_test, y_train_total_days, y_test_total_days, y_train_time, y_test_time = train_test_split(
    X, y_total_days, y_time_taken_at_each_stage, test_size=0.2, random_state=42)

# Create and train the regression model for total days
total_days_model = RandomForestRegressor(n_estimators=100, random_state=42)
total_days_model.fit(X_train, y_train_total_days)

# Predict total days on the test set
y_pred_total_days = total_days_model.predict(X_test)

# Evaluate the model for total days
mse_total_days = mean_squared_error(y_test_total_days, y_pred_total_days)
r2_total_days = r2_score(y_test_total_days, y_pred_total_days)
print(f'Mean Squared Error (Total Days): {mse_total_days}')
print(f'R-squared (Total Days): {r2_total_days}')
# Out:
# Mean Squared Error (Total Days): 655.04205745
# R-squared (Total Days): 0.9974279499070431

# %%
from sklearn.metrics import make_scorer
from sklearn.model_selection import cross_val_score
# Define a custom scorer for cross-validation
mse_scorer = make_scorer(mean_squared_error)  # Use make_scorer to create the custom scorer

# Perform K-Fold Cross-Validation
k = 5  # You can adjust the number of folds
cv_scores = cross_val_score(total_days_model, X, y_total_days, cv=k, scoring=mse_scorer)

# Print the mean and standard deviation of MSE scores
print("Cross-Validation Mean MSE:", np.mean(cv_scores))
print("Cross-Validation MSE Std Dev:", np.std(cv_scores))
# Out:
# Cross-Validation Mean MSE: 667.80340967
# Cross-Validation MSE Std Dev: 106.25875288665064

# %%
# Create and train the regression model for time taken at each stage
stage_models = {}
for stage in stage_columns:
    stage_model = RandomForestRegressor(n_estimators=100, random_state=42)
    stage_model.fit(X_train, y_train_time[stage])
    stage_models[stage] = stage_model

# Predict time taken at each stage on the test set
y_pred_time = {}
for stage, stage_model in stage_models.items():
    y_pred_time[stage] = stage_model.predict(X_test)

# %%
# Assuming you have already converted 'actual_commencement_date' to a datetime object
# Calculate days elapsed for each project
current_date = datetime.now()
data['days_elapsed'] = (current_date - data['actual_commencement_date']).dt.days

# Define a function to determine the relevant stage and relevant columns for each project
def determine_relevant_stage_and_columns(row):
    days_elapsed = row['days_elapsed']
    total_days = 0
    relevant_stage = None
    relevant_columns = []

    for stage in stage_columns:
        stage_duration = row[stage]  # Days required for the current stage
        total_days += stage_duration
        if total_days >= days_elapsed:
            relevant_stage = stage
            relevant_columns = [stage for stage in stage_columns[stage_columns.index(stage):]]
            break

    return relevant_stage, relevant_columns, total_days

# Apply the function to create the 'relevant_stage' and 'relevant_columns' columns
data[['relevant_stage', 'relevant_columns', 'total_days']] = data.apply(determine_relevant_stage_and_columns, axis=1, result_type='expand')

# Filter projects based on current_stage
completed_projects = data[data['current_stage'] == 'completed']
running_projects = data[data['current_stage'] == 'running']
upcoming_projects = data[data['current_stage'] == 'upcoming']

# Define a function to make predictions based on the current stage
def make_predictions(row):
    if row['current_stage'] == 'completed':
        return None  # No predictions for completed projects
    elif row['current_stage'] == 'running':
        if row['relevant_stage'] is not None:
            if row['relevant_stage'] in row['relevant_columns']:
                return row[row['relevant_stage']] - (row['days_elapsed'] - row['total_days'])
            else:
                return None  # Skip stages before the relevant stage
        else:
            return None  # Skip predictions for running projects with no relevant stage
    elif row['current_stage'] == 'upcoming':
        return row['total_days']  # Include all stages for upcoming projects

# Apply the make_predictions function to create the 'predicted_time_taken' column
data['predicted_time_taken'] = data.apply(make_predictions, axis=1)

# %%
# Evaluate the models for time taken at each stage
mse_stage = {}
r2_stage = {}
for stage in stage_columns:
    mse_stage[stage] = mean_squared_error(y_test_time[stage], y_pred_time[stage])
    r2_stage[stage] = r2_score(y_test_time[stage], y_pred_time[stage])
    print(f'Mean Squared Error ({stage}): {mse_stage[stage]}')
    print(f'R-squared ({stage}): {r2_stage[stage]}')
# Out:
# Mean Squared Error (Cleaning & survey): 0.016956471660366026
# R-squared (Cleaning & survey): 0.997320784893356
# Mean Squared Error (Excavation,leveling & P.C.C  for Basement  B1 ): 0.5052300366549761
# R-squared (Excavation,leveling & P.C.C  for Basement  B1 ): 0.9974544290687656
# Mean Squared Error ( Raft footing, Column B1, Retaining wall Reinforcement ,Concrete pouring ): 0.5932363756741762
# R-squared ( Raft footing, Column B1, Retaining wall Reinforcement ,Concrete pouring ): 0.9973962614862751
# Mean Squared Error (Slab of B (bottom) ): 0.1489229280871572
# R-squared (Slab of B (bottom) ): 0.9973854849140467
# Mean Squared Error ( Ground Floor slab casting ): 0.2103313344899331
# R-squared ( Ground Floor slab casting ): 0.9974356867837796
# Mean Squared Error ( 1st floor Columns casting): 0.0784495753172517
# R-squared ( 1st floor Columns casting): 0.9974389542886352
# Mean Squared Error ( 1st Floor slab casting): 0.254833833315076
# R-squared ( 1st Floor slab casting): 0.9974834289321921
# Mean Squared Error (2nd floor Columns casting ): 0.0784495753172517
# R-squared (2nd floor Columns casting ): 0.9974389542886352
# Mean Squared Error (2nd Floor slab casting): 0.2844409598395757
# R-squared (2nd Floor slab casting): 0.9974521981444301
# Mean Squared Error ( Brick work at Basement to Ground Floor ): 0.35053287186057225
# R-squared ( Brick work at Basement to Ground Floor ): 0.9973825090878408
# Mean Squared Error (Electrical concealed, PVC Fitting, plastering at Basement): 0.1489229280871572
# R-squared (Electrical concealed, PVC Fitting, plastering at Basement): 0.9973854849140467
# Mean Squared Error (3rd floor Columns casting ): 0.09503567440049601
# R-squared (3rd floor Columns casting ): 0.9973930285658861
# Mean Squared Error (3rd Floor slab casting): 0.3261694495508541
# R-squared (3rd Floor slab casting): 0.997337987915825
# Mean Squared Error ( Brick work at 1st Floor ): 0.06670350867291926
# R-squared ( Brick work at 1st Floor ): 0.9973651203552866
# Mean Squared Error (Electrical concealed, PVC Fitting, plastering at ground floor): 0.173279023808641
# R-squared (Electrical concealed, PVC Fitting, plastering at ground floor): 0.9973262664175997
# Mean Squared Error (4th floor Columns casting ): 0.09503567440049601
# R-squared (4th floor Columns casting ): 0.9973930285658861
# Mean Squared Error (4th Floor slab casting): 0.2844409598395757
# R-squared (4th Floor slab casting): 0.9974521981444301
# Mean Squared Error ( Brick work at 2nd Floor ): 0.0784495753172517
# R-squared ( Brick work at 2nd Floor ): 0.9974389542886352
# Mean Squared Error (Electrical concealed, PVC Fitting, plastering at 1st floor): 0.173279023808641
# R-squared (Electrical concealed, PVC Fitting, plastering at 1st floor): 0.9973262664175997
# Mean Squared Error (5th floor Columns casting ): 0.11121470008711234
# R-squared (5th floor Columns casting ): 0.9974005133345465
# Mean Squared Error (5th Floor slab casting): 0.3261694495508541
# R-squared (5th Floor slab casting): 0.997337987915825
# Mean Squared Error ( Brick work at 3rd Floor ): 0.11121470008711234
# R-squared ( Brick work at 3rd Floor ): 0.9974005133345465
# Mean Squared Error (Electrical concealed, PVC Fitting, plastering at 2nd floor): 0.18700320297687853
# R-squared (Electrical concealed, PVC Fitting, plastering at 2nd floor): 0.997443985542548
# Mean Squared Error (6th floor Columns casting ): 0.09503567440049601
# R-squared (6th floor Columns casting ): 0.9973930285658861
# Mean Squared Error (6th Floor slab casting): 0.35053287186057225
# R-squared (6th Floor slab casting): 0.9973825090878408
# Mean Squared Error ( Brick work at 4th Floor ): 0.11121470008711234
# R-squared ( Brick work at 4th Floor ): 0.9974005133345465
# Mean Squared Error (Electrical concealed, PVC Fitting, plastering at 3rd floor): 0.173279023808641
# R-squared (Electrical concealed, PVC Fitting, plastering at 3rd floor): 0.9973262664175997
# Mean Squared Error (7th floor Columns casting ): 0.11121470008711234
# R-squared (7th floor Columns casting ): 0.9974005133345465
# Mean Squared Error (7th Floor slab casting): 0.3261694495508541
# R-squared (7th Floor slab casting): 0.997337987915825
# Mean Squared Error ( Brickwork of  5th to 7th Floor ): 0.7848660911606266
# R-squared ( Brickwork of  5th to 7th Floor ): 0.9974691198396066
# Mean Squared Error (Electrical concealed, PVC Fitting, plastering at 4th-7th floor): 1.780587571165178
# R-squared (Electrical concealed, PVC Fitting, plastering at 4th-7th floor): 0.9973988298958506
# Mean Squared Error (Plastering on outer sides): 3.7028494345095835
# R-squared (Plastering on outer sides): 0.9973996869840225
# Mean Squared Error (Tiles work): 5.373159331894225
# R-squared (Tiles work): 0.9973796650849874
# Mean Squared Error (Painting and Finishing): 5.373159331894225
# R-squared (Painting and Finishing): 0.9973796650849874
# Mean Squared Error (Plumbing & Sanitary,Electrification Works): 2.31950939075295
# R-squared (Plumbing & Sanitary,Electrification Works): 0.9974548948018571
# Mean Squared Error (Doors & Windows Fixing Furniture work): 5.373159331894225
# R-squared (Doors & Windows Fixing Furniture work): 0.9973796650849874
# Mean Squared Error (other work): 0.5932363756741762
# R-squared (other work): 0.9973962614862751

# %%
# Load the new data (replace 'new_data.csv' with the actual file path)
new_data = pd.read_csv('new_7_test_file.csv')

# %%
# Converting date columns to datetime objeacts
new_data['actual_commencement_date'] = pd.to_datetime(new_data['actual_commencement_date'], errors='coerce')
new_data['estimated_finish_date'] = pd.to_datetime(new_data['estimated_finish_date'], errors='coerce')

# %%
current_date = datetime.now()

# %%
new_data['total_days'] = (new_data['estimated_finish_date'] - new_data['actual_commencement_date']).dt.days

# %%
new_data['duration_since_commencement'] = (current_date - new_data['actual_commencement_date']).dt.days
new_data['remaining_duration'] = (new_data['estimated_finish_date'] - current_date).dt.days
new_data['progress_ratio'] = new_data['duration_since_commencement'] / new_data['total_days']

# %%
# Define a function to determine the project status
def determine_status(row):
    if current_date > row['estimated_finish_date']:
        return 'completed'
    elif current_date >= row['actual_commencement_date']:
        return 'running'
    else:
        return 'upcoming'

# Apply the function to create the 'Status' column
new_data['current_stage'] = new_data.apply(determine_status, axis=1)

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 417 entries, 0 to 416
# Data columns (total 15 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   organisation_name                  417 non-null    object
#  1   project_category                   417 non-null    object
#  2   actual_commencement_date           417 non-null    datetime64[ns]
#  3   estimated_finish_date              417 non-null    datetime64[ns]
#  4   total_built_up_area_saleable_area  417 non-null    float64
#  5   total_area_of_project              417 non-null    float64
#  6   floor                              417 non-null    int64
#  7   project_state                      417 non-null    object
#  8   office_no                          417 non-null    float64
#  9   project_res_no                     417 non-null    object
#  10  total_days                         417 non-null    int64
#  11  duration_since_commencement        417 non-null    int64
#  12  remaining_duration                 417 non-null    int64
#  13  progress_ratio                     417 non-null    float64
#  14  current_stage                      417 non-null    object
# dtypes: datetime64[ns](2), float64(4), int64(4), object(5)
# memory usage: 49.0+ KB

# %%
# Performing label encoding on the 'current_stage' column
label_encoder = LabelEncoder()
new_data['current_stage'] =new_data['current_stage'].astype(str) # Converting to string to handle any NaN values left
new_data['current_stage_encoded'] = label_encoder.fit_transform(new_data['current_stage'])

# %%
# Performing label encoding on the 'current_stage' column
label_encoder = LabelEncoder()
new_data['project_state'] =new_data['project_state'].astype(str) # Converting to string to handle any NaN values left
new_data['project_state_encoded'] = label_encoder.fit_transform(new_data['project_state'])

# %%
new_data['office_no'] = new_data['office_no'].astype(str)

# %%
stage_columns = [ 'Cleaning & survey',
       'Excavation,leveling & P.C.C  for Basement  B1 ',
       ' Raft footing, Column B1, Retaining wall Reinforcement ,Concrete pouring ',
       'Slab of B (bottom) ', ' Ground Floor slab casting ',
       ' 1st floor Columns casting', ' 1st Floor slab casting',
       '2nd floor Columns casting ', '2nd Floor slab casting',
       ' Brick work at Basement to Ground Floor ',
       'Electrical concealed, PVC Fitting, plastering at Basement',
       '3rd floor Columns casting ', '3rd Floor slab casting',
       ' Brick work at 1st Floor ',
       'Electrical concealed, PVC Fitting, plastering at ground floor',
       '4th floor Columns casting ', '4th Floor slab casting',
       ' Brick work at 2nd Floor ',
       'Electrical concealed, PVC Fitting, plastering at 1st floor',
       '5th floor Columns casting ', '5th Floor slab casting',
       ' Brick work at 3rd Floor ',
       'Electrical concealed, PVC Fitting, plastering at 2nd floor',
       '6th floor Columns casting ', '6th Floor slab casting',
       ' Brick work at 4th Floor ',
       'Electrical concealed, PVC Fitting, plastering at 3rd floor',
       '7th floor Columns casting ', '7th Floor slab casting',
       ' Brickwork of  5th to 7th Floor ',
       'Electrical concealed, PVC Fitting, plastering at 4th-7th floor',
       'Plastering on outer sides', 'Tiles work', 'Painting and Finishing',
       'Plumbing & Sanitary,Electrification Works',
       'Doors & Windows Fixing Furniture work', 'other work']

# %%
# Create an empty DataFrame to store 'new_data' with added columns
new_data = new_data.copy()  # Assuming 'new_data' is your original DataFrame

# Add stage-related columns and 'total_days' column with NaN values
for stage in stage_columns:
    new_data[stage] = np.nan

new_data['total_days'] = np.nan

# Now, 'new_data_with_stages' contains the additional columns with NaN values

# %%
numerical_columns = new_data.select_dtypes(include=['int64', 'float64'])
stage_columns = [ 'Cleaning & survey',
       'Excavation,leveling & P.C.C  for Basement  B1 ',
       ' Raft footing, Column B1, Retaining wall Reinforcement ,Concrete pouring ',
       'Slab of B (bottom) ', ' Ground Floor slab casting ',
       ' 1st floor Columns casting', ' 1st Floor slab casting',
       '2nd floor Columns casting ', '2nd Floor slab casting',
       ' Brick work at Basement to Ground Floor ',
       'Electrical concealed, PVC Fitting, plastering at Basement',
       '3rd floor Columns casting ', '3rd Floor slab casting',
       ' Brick work at 1st Floor ',
       'Electrical concealed, PVC Fitting, plastering at ground floor',
       '4th floor Columns casting ', '4th Floor slab casting',
       ' Brick work at 2nd Floor ',
       'Electrical concealed, PVC Fitting, plastering at 1st floor',
       '5th floor Columns casting ', '5th Floor slab casting',
       ' Brick work at 3rd Floor ',
       'Electrical concealed, PVC Fitting, plastering at 2nd floor',
       '6th floor Columns casting ', '6th Floor slab casting',
       ' Brick work at 4th Floor ',
       'Electrical concealed, PVC Fitting, plastering at 3rd floor',
       '7th floor Columns casting ', '7th Floor slab casting',
       ' Brickwork of  5th to 7th Floor ',
       'Electrical concealed, PVC Fitting, plastering at 4th-7th floor',
       'Plastering on outer sides', 'Tiles work', 'Painting and Finishing',
       'Plumbing & Sanitary,Electrification Works',
       'Doors & Windows Fixing Furniture work', 'other work']
# Target variables
X_new = new_data[numerical_columns.columns.difference(stage_columns)].drop(columns='total_days')
#y_total_days = new_data['total_days']
#y_time_taken_at_each_stage = new_data[stage_columns]  # Replace with your actual stage columns

# %%
new_data['total_days'] = total_days_model.predict(new_data[X_new.columns])

for stage in stage_columns:
    stage_model = stage_models.get(stage)  # Use get to avoid KeyError
    if stage_model:
        new_data[stage] = stage_model.predict(new_data[X_new.columns])
    else:
        # If the stage column isn't in stage_models, fill it with NaN
        new_data[stage] = np.nan

# %%
stage_materials = {
    'Cleaning & survey': [],
    'Excavation,leveling & P.C.C  for Basement  B1 ': ['cement', 'sand', 'aggregates'],
    ' Raft footing, Column B1, Retaining wall Reinforcement ,Concrete pouring ': ['TMT bar', 'cement', 'sand', 'aggregates'],
    'Slab of B (bottom) ': ['TMT bar', 'cement', 'sand', 'aggregates'],
    ' Ground Floor slab casting ': ['TMT bar', 'cement', 'sand', 'aggregates'],
    ' 1st floor Columns casting': ['TMT bar', 'cement', 'sand', 'aggregates'],
    ' 1st Floor slab casting': ['TMT bar', 'cement', 'sand', 'aggregates'],
    '2nd floor Columns casting ': ['TMT bar', 'cement', 'sand', 'aggregates'],
    '2nd Floor slab casting': ['TMT bar', 'cement', 'sand', 'aggregates'],
    ' Brick work at Basement to Ground Floor ': ['blocks/bricks'],
    'Electrical concealed, PVC Fitting, plastering at Basement': ['circuit pipe', 'Cpvc', '&Pvc pipe'],
    '3rd floor Columns casting ': ['TMT bar', 'cement', 'sand', 'aggregates', 'cement', 'sand'],
    '3rd Floor slab casting': ['TMT bar', 'cement', 'sand', 'aggregates', 'cement', 'sand'],
    ' Brick work at 1st Floor ': ['blocks/bricks'],
    'Electrical concealed, PVC Fitting, plastering at ground floor': ['circuit pipe', 'Cpvc', '&Pvc pipe'],
    '4th floor Columns casting ': ['TMT bar', 'cement', 'sand', 'aggregates', 'cement', 'sand'],
    '4th Floor slab casting': ['TMT bar', 'cement', 'sand', 'aggregates', 'cement', 'sand'],
    ' Brick work at 2nd Floor ': ['blocks/bricks'],
    'Electrical concealed, PVC Fitting, plastering at 1st floor': ['circuit pipe', 'Cpvc', '&Pvc pipe'],
    '5th floor Columns casting ': ['TMT bar', 'cement', 'sand', 'aggregates', 'cement', 'sand'],
    '5th Floor slab casting': ['TMT bar', 'cement', 'sand', 'aggregates', 'cement', 'sand'],
    ' Brick work at 3rd Floor ': ['blocks/bricks'],
    'Electrical concealed, PVC Fitting, plastering at 2nd floor': ['circuit pipe', 'Cpvc', '&Pvc pipe'],
    '6th floor Columns casting ': ['TMT bar', 'cement', 'sand', 'aggregates', 'cement', 'sand'],
    '6th Floor slab casting': ['TMT bar', 'cement', 'sand', 'aggregates', 'cement', 'sand'],
    ' Brick work at 4th Floor ': ['blocks/bricks'],
    'Electrical concealed, PVC Fitting, plastering at 3rd floor': ['circuit pipe', 'Cpvc', '&Pvc pipe'],
    '7th floor Columns casting ': ['TMT bar', 'cement', 'sand', 'aggregates', 'cement', 'sand'],
    '7th Floor slab casting': [],
    ' Brick work of 5th to 7th Floor ': ['blocks/bricks'],
    'Electrical concealed, PVC Fitting, plastering at 4th-7th floor': ['circuit pipe', 'Cpvc', '&Pvc pipe'],
    'Plastering on outer sides': ['cement', 'sand'],
    'Tiles work': ['Tiles'],
    'Painting and Finishing': ['paint', 'putty', 'primer'],
    'Plumbing & Sanitary, Electrification Works': ['Wire', 'switch', 'nozzle Bib cock', 'shower', 'kitchen accessories', 'lights', 'fans', 'sheets', 'basin', 'sink', 'etc.'],
    'Doors & Windows Fixing Furniture work': ['Furniture', 'hardware', 'glass'],
    'other work': []
}

# %%
# Initialize empty lists to store relevant_stage and relevant_columns
relevant_stage_list = []
relevant_columns_list = []

# Iterate through each row (project) in new_data
for index, row in new_data.iterrows():
    days_elapsed = (current_date - row['actual_commencement_date']).days
    total_days = row['total_days']

    relevant_stage = None
    relevant_columns = []

    for stage in stage_columns:

        if total_days is None or np.isnan(total_days):
            # Set relevant_stage and relevant_columns to None if total_days is missing
            relevant_stage = None
            relevant_columns = []
            break

        stage_duration = row[stage]
        total_days -= stage_duration

        if total_days <= days_elapsed:
            relevant_stage = stage
            relevant_columns = [stage for stage in stage_columns[stage_columns.index(stage):]]
            break

    relevant_stage_list.append(relevant_stage)
    relevant_columns_list.append(relevant_columns)

    # Add the 'relevant_stage' and 'relevant_columns' columns to the new_data DataFrame
new_data['relevant_stage'] = relevant_stage_list
new_data['relevant_columns'] = relevant_columns_list

# %%
import pandas as pd
import numpy as np

# Initialize empty DataFrame to store adjusted days data
adjusted_days_data = pd.DataFrame(columns=stage_columns)

# Iterate through each row (project) in new_data
for index, row in new_data.iterrows():
    current_stage = row['current_stage']
    relevant_columns = row['relevant_columns']

    if current_stage == 'completed':
        # For completed projects, set 'days' to NaN for all stage columns
        days_values = [np.nan] * len(stage_columns)
    elif current_stage == 'running':
        # For running projects, update 'days' based on relevant_columns
        days_values = [row[stage] if stage in relevant_columns else np.nan for stage in stage_columns]
    elif current_stage == 'upcoming':
        # For upcoming projects, keep the predicted 'days' values
        days_values = [row[stage] for stage in stage_columns]

    # Append the days_values to the adjusted_days_data
    adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)

# Replace the original stage values in new_data with adjusted values
new_data[stage_columns] = adjusted_days_data
# Out:
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# ...
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-57-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)

# %%
new_data
# Out:
#                             organisation_name           project_category  \
# 0                AARYAN REALTORS & DEVELOPERS  Residential/Group Housing
# 1                          MEGHA RAJESH TOMAR  Residential/Group Housing
# 2                      VIJAY PUNDALIK SHIRODE  Residential/Group Housing
# 3         MATRUBHUMI LANDMARK PRIVATE LIMITED  Residential/Group Housing
# 4                          ICON REALTY UNIT 2  Residential/Group Housing
# ..                                        ...                        ...
# 412  MAHAVIR BUILDERS AND DEVELOPERS PVT.LTD.  Residential/Group Housing
# 413                       SHIVSHRI PROPERTIES  Residential/Group Housing
# 414                 DEEPAK VENKATRAO KULKARNI  Residential/Group Housing
# 415                        Gold Coin Builders  Residential/Group Housing
# 416                     Vijay Shankar Inamdar  Residential/Group Housing
#
#     actual_commencement_date estimated_finish_date  \
# 0                 2022-09-11            2025-03-31
# 1                 2021-03-11            2023-09-30
# 2                 2021-09-09            2024-03-30
# 3                 2021-09-09            2024-03-30
# 4                 2022-07-12            2025-01-31
# ..                       ...                   ...
# 412               2022-09-02            2026-12-31
# 413               2022-11-28            2027-03-31
# 414               2022-12-05            2027-04-20
# 415               2021-08-15            2025-12-31
# 416               2021-08-09            2025-12-30
#
#      total_built_up_area_saleable_area  total_area_of_project  floor  \
# 0                              1291.08                1291.08      7
# 1                               933.53                 431.20      7
# 2                              3508.74                1950.00      7
# 3                              3296.70                3330.00      7
# 4                               877.13                 498.42      7
# ..                                 ...                    ...    ...
# 412                            2146.62                 752.00      7
# 413                            3019.94                1356.68      7
# 414                            1303.16                 410.40      7
# 415                            3116.56                 917.70      7
# 416                             716.87                 312.70      7
#
#     project_state     office_no                        project_res_no  ...  \
# 0     MAHARASHTRA  2225618790.0           Mumbai_Suburban_Three_35500  ...
# 1     MAHARASHTRA  7122777052.0  Nagpur5_Sangli_4s_Kohlapur_4s_145000  ...
# 2     MAHARASHTRA  2532310599.0       Sindh3s_Wardha2s_NASIK8S_673500  ...
# 3     MAHARASHTRA  2402365897.0      AHMED2S_AMra3s_AUR7S_TH1S_625500  ...
# 4     MAHARASHTRA  2041405632.0                       Pune_Six_711000  ...
# ..            ...           ...                                   ...  ...
# 412   MAHARASHTRA  2532397482.0                 NASIK11S_AHMED1S_6000  ...
# 413   MAHARASHTRA  9689361195.0                       Pune_Six_339500  ...
# 414   MAHARASHTRA  2402339293.0      AHMED2S_AMra3s_AUR7S_TH1S_713000  ...
# 415   MAHARASHTRA  2226673464.0           Mumbai_Suburban_Three_16000  ...
# 416   MAHARASHTRA  9822491596.0                       PUNE_One_802500  ...
#
#       Brickwork of  5th to 7th Floor   \
# 0                                 NaN
# 1                                 NaN
# 2                           32.589781
# 3                           32.601994
# 4                           32.543021
# ..                                ...
# 412                               NaN
# 413                               NaN
# 414                               NaN
# 415                         55.824128
# 416                         55.984995
#
#      Electrical concealed, PVC Fitting, plastering at 4th-7th floor  \
# 0                                            48.206540
# 1                                                  NaN
# 2                                            48.451246
# 3                                            48.451246
# 4                                            48.318524
# ..                                                 ...
# 412                                                NaN
# 413                                                NaN
# 414                                                NaN
# 415                                          82.939741
# 416                                          83.344128
#
#      Plastering on outer sides  Tiles work Painting and Finishing  \
# 0                    69.544367   83.560020              83.560020
# 1                          NaN         NaN                    NaN
# 2                    69.893569   83.872283              83.872283
# 3                    69.893569   83.872283              83.872283
# 4                    69.711117   83.657827              83.657827
# ..                         ...         ...                    ...
# 412                        NaN         NaN             143.414058
# 413                        NaN         NaN             142.246660
# 414                        NaN         NaN             144.037687
# 415                 119.626869  143.554038             143.554038
# 416                 120.109920  144.255733             144.255733
#
#      Plumbing & Sanitary,Electrification Works  \
# 0                                    55.716849
# 1                                          NaN
# 2                                    55.893918
# 3                                    55.914855
# 4                                    55.752742
# ..                                         ...
# 412                                  95.807976
# 413                                  94.748554
# 414                                  95.909073
# 415                                  95.699701
# 416                                  96.166301
#
#      Doors & Windows Fixing Furniture work  other work  \
# 0                                83.560020   27.852144
# 1                                      NaN         NaN
# 2                                83.872283   27.949352
# 3                                83.872283   27.949352
# 4                                83.657827   27.851246
# ..                                     ...         ...
# 412                             143.414058   47.804985
# 413                             142.246660   47.438883
# 414                             144.037687   47.953340
# 415                             143.554038   47.849252
# 416                             144.255733   48.121436
#
#                                         relevant_stage  \
# 0    Electrical concealed, PVC Fitting, plastering ...
# 1                                    Cleaning & survey
# 2              Brick work at Basement to Ground Floor
# 3              Brick work at Basement to Ground Floor
# 4                      Brickwork of  5th to 7th Floor
# ..                                                 ...
# 412                             Painting and Finishing
# 413                             Painting and Finishing
# 414                             Painting and Finishing
# 415                    Brickwork of  5th to 7th Floor
# 416                    Brickwork of  5th to 7th Floor
#
#                                       relevant_columns
# 0    [Electrical concealed, PVC Fitting, plastering...
# 1    [Cleaning & survey, Excavation,leveling & P.C....
# 2    [ Brick work at Basement to Ground Floor , Ele...
# 3    [ Brick work at Basement to Ground Floor , Ele...
# 4    [ Brickwork of  5th to 7th Floor , Electrical ...
# ..                                                 ...
# 412  [Painting and Finishing, Plumbing & Sanitary,E...
# 413  [Painting and Finishing, Plumbing & Sanitary,E...
# 414  [Painting and Finishing, Plumbing & Sanitary,E...
# 415  [ Brickwork of  5th to 7th Floor , Electrical ...
# 416  [ Brickwork of  5th to 7th Floor , Electrical ...
#
# [417 rows x 56 columns]

# %%
# Define a function to print project details
def print_project_details(row, current_date):
    print(f'Organization Name: {row["organisation_name"]}')
    print(f'office_no	: {row["office_no"]}')
    print(f'project_res_no: {row["project_res_no"]}')
    print(f'Current Stage: {row["current_stage"]}')
    print(f'Total Days: {row["total_days"]}')
    print('Stage Details:')
    current_materials = []  # List to store materials for the current stage
    current_stage_start_date = current_date  # Initialize with the current date

    for stage in stage_columns:
        stage_duration = row[stage]

        if not pd.isna(stage_duration):
            # Calculate the stage end date
            stage_end_date = current_stage_start_date + pd.Timedelta(days=stage_duration)

            # Format the dates for display
            start_date_str = current_stage_start_date.strftime('%Y-%m-%d')
            end_date_str = stage_end_date.strftime('%Y-%m-%d')

            # Print the stage, days, and start and end dates
            print(f'{stage}: {stage_duration} days ({start_date_str} - {end_date_str})')

            # Update the start date for the next stage
            current_stage_start_date = stage_end_date

            # Check if there are materials for this stage
            materials = stage_materials.get(stage, [])

            if materials:
                # Display materials if available
                current_materials = materials

            if current_materials:
                # Print materials for the stage
                print(f'Materials: {", ".join(current_materials)}')

    print('-----------------')

# Iterate through each row (project) in the new_data DataFrame
for index, row in new_data.iterrows():
    # You need to pass the current date as an argument
    print_project_details(row, current_date)
# Out:
# Streaming output truncated to the last 5000 lines.
# 6th floor Columns casting : 13.579262210000017 days (2023-11-19 - 2023-12-03)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 6th Floor slab casting: 26.02691924000005 days (2023-12-03 - 2023-12-29)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 4th Floor : 14.710867400000023 days (2023-12-29 - 2024-01-12)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 3rd floor: 18.10568295000002 days (2024-01-12 - 2024-01-30)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 7th floor Columns casting : 14.710867400000023 days (2024-01-30 - 2024-02-14)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 7th Floor slab casting: 24.895314059999997 days (2024-02-14 - 2024-03-10)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brickwork of  5th to 7th Floor : 39.6061814599999 days (2024-03-10 - 2024-04-19)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# Electrical concealed, PVC Fitting, plastering at 4th-7th floor: 58.8434695899999 days (2024-04-19 - 2024-06-16)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# Plastering on outer sides: 84.8703888299999 days (2024-06-16 - 2024-09-09)
# Materials: cement, sand
# Tiles work: 101.84446659999976 days (2024-09-09 - 2024-12-20)
# Materials: Tiles
# Painting and Finishing: 101.84446659999976 days (2024-12-20 - 2025-04-01)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 67.8963110699999 days (2025-04-01 - 2025-06-08)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 101.84446659999976 days (2025-06-08 - 2025-09-18)
# Materials: Furniture, hardware, glass
# other work: 33.94815552999993 days (2025-09-18 - 2025-10-22)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: Vatsalya Properties
# office_no	: 9623004545.0
# project_res_no: PUNE_One_794000
# Current Stage: running
# Total Days: 1135.0
# Stage Details:
# Electrical concealed, PVC Fitting, plastering at 2nd floor: 19.23728813999997 days (2023-10-31 - 2023-11-19)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 6th floor Columns casting : 13.579262210000017 days (2023-11-19 - 2023-12-03)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 6th Floor slab casting: 26.02691924000005 days (2023-12-03 - 2023-12-29)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 4th Floor : 14.710867400000023 days (2023-12-29 - 2024-01-12)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 3rd floor: 18.10568295000002 days (2024-01-12 - 2024-01-30)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 7th floor Columns casting : 14.710867400000023 days (2024-01-30 - 2024-02-14)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 7th Floor slab casting: 24.895314059999997 days (2024-02-14 - 2024-03-10)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brickwork of  5th to 7th Floor : 39.6061814599999 days (2024-03-10 - 2024-04-19)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# Electrical concealed, PVC Fitting, plastering at 4th-7th floor: 58.8434695899999 days (2024-04-19 - 2024-06-16)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# Plastering on outer sides: 84.8703888299999 days (2024-06-16 - 2024-09-09)
# Materials: cement, sand
# Tiles work: 101.84446659999976 days (2024-09-09 - 2024-12-20)
# Materials: Tiles
# Painting and Finishing: 101.84446659999976 days (2024-12-20 - 2025-04-01)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 67.8963110699999 days (2025-04-01 - 2025-06-08)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 101.84446659999976 days (2025-06-08 - 2025-09-18)
# Materials: Furniture, hardware, glass
# other work: 33.94815552999993 days (2025-09-18 - 2025-10-22)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: MAHALAXMI CONSTRUCTIONS
# office_no	: 2532257357.0
# project_res_no: NASIK11S_AHMED1S_509500
# Current Stage: running
# Total Days: 1139.33
# Stage Details:
# Painting and Finishing: 102.21505479849996 days (2023-10-31 - 2024-02-10)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 68.12003988149988 days (2024-02-10 - 2024-04-18)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 102.21505479849996 days (2024-04-18 - 2024-07-29)
# Materials: Furniture, hardware, glass
# other work: 34.077666999599934 days (2024-07-29 - 2024-09-01)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: D A CONSTRUCTION
# office_no	: 2221634936.0
# project_res_no: THANE11S_565500
# Current Stage: running
# Total Days: 1144.16
# Stage Details:
# Tiles work: 102.5623131 days (2023-10-31 - 2024-02-10)
# Materials: Tiles
# Painting and Finishing: 102.5623131 days (2024-02-10 - 2024-05-23)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 68.4598205346001 days (2024-05-23 - 2024-07-30)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 102.5623131 days (2024-07-30 - 2024-11-10)
# Materials: Furniture, hardware, glass
# other work: 34.25054835800002 days (2024-11-10 - 2024-12-14)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: Saurabh Surendra Tatke
# office_no	: 8554907878.0
# project_res_no: Jalga2s_Chand2s_Sola3_Sat6s_553500
# Current Stage: running
# Total Days: 1148.77
# Stage Details:
# Electrical concealed, PVC Fitting, plastering at 2nd floor: 19.466610172100015 days (2023-10-31 - 2023-11-19)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 6th floor Columns casting : 13.747956134300011 days (2023-11-19 - 2023-12-03)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 6th Floor slab casting: 26.289481555799988 days (2023-12-03 - 2023-12-29)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 4th Floor : 14.875343969899998 days (2023-12-29 - 2024-01-13)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 3rd floor: 18.307956128699985 days (2024-01-13 - 2024-01-31)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 7th floor Columns casting : 14.875343969899998 days (2024-01-31 - 2024-02-15)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 7th Floor slab casting: 25.18089731039997 days (2024-02-15 - 2024-03-11)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brickwork of  5th to 7th Floor : 40.021784644000036 days (2024-03-11 - 2024-04-20)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# Electrical concealed, PVC Fitting, plastering at 4th-7th floor: 59.57188434660003 days (2024-04-20 - 2024-06-19)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# Plastering on outer sides: 85.8035892325 days (2024-06-19 - 2024-09-13)
# Materials: cement, sand
# Tiles work: 103.10338983740003 days (2024-09-13 - 2024-12-25)
# Materials: Tiles
# Painting and Finishing: 103.10338983740003 days (2024-12-25 - 2025-04-07)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 68.70867398079993 days (2025-04-07 - 2025-06-15)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 103.10338983740003 days (2025-06-15 - 2025-09-26)
# Materials: Furniture, hardware, glass
# other work: 34.33310069479998 days (2025-09-26 - 2025-10-30)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: ATHARVASHREE BUILDMAT PVT LTD
# office_no	: 2532991727.0
# project_res_no: NASIK11S_AHMED1S_478000
# Current Stage: running
# Total Days: 1145.49
# Stage Details:
# Electrical concealed, PVC Fitting, plastering at 2nd floor: 19.416949155100003 days (2023-10-31 - 2023-11-19)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 6th floor Columns casting : 13.707876371100015 days (2023-11-19 - 2023-12-03)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 6th Floor slab casting: 26.231006978600007 days (2023-12-03 - 2023-12-29)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 4th Floor : 14.8372382866 days (2023-12-29 - 2024-01-13)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 3rd floor: 18.278444663600002 days (2024-01-13 - 2024-01-31)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 7th floor Columns casting : 14.8372382866 days (2024-01-31 - 2024-02-15)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 7th Floor slab casting: 25.12101695129997 days (2024-02-15 - 2024-03-11)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brickwork of  5th to 7th Floor : 39.93978065779999 days (2024-03-11 - 2024-04-20)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# Electrical concealed, PVC Fitting, plastering at 4th-7th floor: 59.41479561280003 days (2024-04-20 - 2024-06-19)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# Plastering on outer sides: 85.63683948089997 days (2024-06-19 - 2024-09-12)
# Materials: cement, sand
# Tiles work: 102.82612163979998 days (2024-09-12 - 2024-12-24)
# Materials: Tiles
# Painting and Finishing: 102.82612163979998 days (2024-12-24 - 2025-04-06)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 68.56390827809994 days (2025-04-06 - 2025-06-13)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 102.82612163979998 days (2025-06-13 - 2025-09-24)
# Materials: Furniture, hardware, glass
# other work: 34.233499498499974 days (2025-09-24 - 2025-10-28)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: HANMANTU KOMARAYYA BURA
# office_no	: 9527825000.0
# project_res_no: Jalga2s_Chand2s_Sola3_Sat6s_415500
# Current Stage: running
# Total Days: 1150.45
# Stage Details:
#  Brick work at 2nd Floor : 12.591764703800022 days (2023-10-31 - 2023-11-12)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 1st floor: 18.322153541499976 days (2023-11-12 - 2023-12-01)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 5th floor Columns casting : 14.893619138899966 days (2023-12-01 - 2023-12-16)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 5th Floor slab casting: 25.229152538700035 days (2023-12-16 - 2024-01-10)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 3rd Floor : 14.893619138899966 days (2024-01-10 - 2024-01-25)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 2nd floor: 19.45677966210004 days (2024-01-25 - 2024-02-13)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 6th floor Columns casting : 13.733958123099992 days (2024-02-13 - 2024-02-27)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 6th Floor slab casting: 26.374785647499966 days (2024-02-27 - 2024-03-24)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 4th Floor : 14.893619138899966 days (2024-03-24 - 2024-04-08)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 3rd floor: 18.322153541499976 days (2024-04-08 - 2024-04-26)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 7th floor Columns casting : 14.893619138899966 days (2024-04-26 - 2024-05-11)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 7th Floor slab casting: 25.229152538700035 days (2024-05-11 - 2024-06-06)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brickwork of  5th to 7th Floor : 40.148803590700055 days (2024-06-06 - 2024-07-16)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# Electrical concealed, PVC Fitting, plastering at 4th-7th floor: 59.521595216999884 days (2024-07-16 - 2024-09-13)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# Plastering on outer sides: 86.06455632919982 days (2024-09-13 - 2024-12-08)
# Materials: cement, sand
# Tiles work: 103.01365902279986 days (2024-12-08 - 2025-03-21)
# Materials: Tiles
# Painting and Finishing: 103.01365902279986 days (2025-03-21 - 2025-07-02)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 68.77328016329999 days (2025-07-02 - 2025-09-09)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 103.01365902279986 days (2025-09-09 - 2025-12-21)
# Materials: Furniture, hardware, glass
# other work: 34.37168494270003 days (2025-12-21 - 2026-01-24)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: ASSOCIATED RECONS
# office_no	: 2024377669.0
# project_res_no: PUNE_Two_526000
# Current Stage: running
# Total Days: 1148.44
# Stage Details:
#  Brick work at 2nd Floor : 12.581674973200021 days (2023-10-31 - 2023-11-12)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 1st floor: 18.314815555599967 days (2023-11-12 - 2023-12-01)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 5th floor Columns casting : 14.880917244199965 days (2023-12-01 - 2023-12-15)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 5th Floor slab casting: 25.19734795230004 days (2023-12-15 - 2024-01-10)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 3rd Floor : 14.880917244199965 days (2024-01-10 - 2024-01-25)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 2nd floor: 19.45016949280004 days (2024-01-25 - 2024-02-13)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 6th floor Columns casting : 13.728693915499994 days (2024-02-13 - 2024-02-27)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 6th Floor slab casting: 26.336719845099964 days (2024-02-27 - 2024-03-24)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 4th Floor : 14.880917244199965 days (2024-03-24 - 2024-04-08)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 3rd floor: 18.314815555599967 days (2024-04-08 - 2024-04-26)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 7th floor Columns casting : 14.880917244199965 days (2024-04-26 - 2024-05-11)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 7th Floor slab casting: 25.19734795230004 days (2024-05-11 - 2024-06-05)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brickwork of  5th to 7th Floor : 40.06435693070005 days (2024-06-05 - 2024-07-15)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# Electrical concealed, PVC Fitting, plastering at 4th-7th floor: 59.47337986319988 days (2024-07-15 - 2024-09-13)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# Plastering on outer sides: 85.87462611959981 days (2024-09-13 - 2024-12-08)
# Materials: cement, sand
# Tiles work: 102.85124626219985 days (2024-12-08 - 2025-03-21)
# Materials: Tiles
# Painting and Finishing: 102.85124626219985 days (2025-03-21 - 2025-07-01)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 68.64526421129999 days (2025-07-01 - 2025-09-08)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 102.85124626219985 days (2025-09-08 - 2025-12-20)
# Materials: Furniture, hardware, glass
# other work: 34.333399797900036 days (2025-12-20 - 2026-01-23)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: NASHIK HOUSING AND AREA DEVELOPMENT BOARD
# office_no	: 2532229227.0
# project_res_no: Sindh3s_Wardha2s_NASIK8S_498500
# Current Stage: running
# Total Days: 1150.07
# Stage Details:
#  Brick work at 2nd Floor : 12.59549351770002 days (2023-10-31 - 2023-11-12)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 1st floor: 18.335234299299973 days (2023-11-12 - 2023-12-01)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 5th floor Columns casting : 14.893748749799965 days (2023-12-01 - 2023-12-16)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 5th Floor slab casting: 25.21138583870004 days (2023-12-16 - 2024-01-10)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 3rd Floor : 14.893748749799965 days (2024-01-10 - 2024-01-25)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 2nd floor: 19.46101695040004 days (2024-01-25 - 2024-02-13)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 6th floor Columns casting : 13.740418741099994 days (2024-02-13 - 2024-02-27)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 6th Floor slab casting: 26.365842476999966 days (2024-02-27 - 2024-03-24)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 4th Floor : 14.893748749799965 days (2024-03-24 - 2024-04-08)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 3rd floor: 18.335234299299973 days (2024-04-08 - 2024-04-26)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 7th floor Columns casting : 14.893748749799965 days (2024-04-26 - 2024-05-11)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 7th Floor slab casting: 25.21138583870004 days (2024-05-11 - 2024-06-06)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brickwork of  5th to 7th Floor : 40.11076769830005 days (2024-06-06 - 2024-07-16)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# Electrical concealed, PVC Fitting, plastering at 4th-7th floor: 59.557367898999885 days (2024-07-16 - 2024-09-13)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# Plastering on outer sides: 85.94790627919981 days (2024-09-13 - 2024-12-08)
# Materials: cement, sand
# Tiles work: 102.97148554399986 days (2024-12-08 - 2025-03-21)
# Materials: Tiles
# Painting and Finishing: 102.97148554399986 days (2025-03-21 - 2025-07-02)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 68.70448654429998 days (2025-07-02 - 2025-09-09)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 102.97148554399986 days (2025-09-09 - 2025-12-21)
# Materials: Furniture, hardware, glass
# other work: 34.35194416480003 days (2025-12-21 - 2026-01-24)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: ASHAPURA INFRA
# office_no	: 9890450151.0
# project_res_no: Sindh3s_Wardha2s_NASIK8S_755500
# Current Stage: running
# Total Days: 1150.05
# Stage Details:
#  Brick work at 2nd Floor : 12.59549351770002 days (2023-10-31 - 2023-11-12)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 1st floor: 18.335074777899973 days (2023-11-12 - 2023-12-01)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 5th floor Columns casting : 14.893748749799965 days (2023-12-01 - 2023-12-16)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 5th Floor slab casting: 25.21138583870004 days (2023-12-16 - 2024-01-10)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 3rd Floor : 14.893748749799965 days (2024-01-10 - 2024-01-25)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 2nd floor: 19.460847458900037 days (2024-01-25 - 2024-02-13)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 6th floor Columns casting : 13.740299099999993 days (2024-02-13 - 2024-02-27)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 6th Floor slab casting: 26.365842476999966 days (2024-02-27 - 2024-03-24)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 4th Floor : 14.893748749799965 days (2024-03-24 - 2024-04-08)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 3rd floor: 18.335074777899973 days (2024-04-08 - 2024-04-26)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 7th floor Columns casting : 14.893748749799965 days (2024-04-26 - 2024-05-11)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 7th Floor slab casting: 25.21138583870004 days (2024-05-11 - 2024-06-06)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brickwork of  5th to 7th Floor : 40.11076769830005 days (2024-06-06 - 2024-07-16)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# Electrical concealed, PVC Fitting, plastering at 4th-7th floor: 59.55633100959988 days (2024-07-16 - 2024-09-13)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# Plastering on outer sides: 85.94790627919981 days (2024-09-13 - 2024-12-08)
# Materials: cement, sand
# Tiles work: 102.97058823599986 days (2024-12-08 - 2025-03-21)
# Materials: Tiles
# Painting and Finishing: 102.97058823599986 days (2025-03-21 - 2025-07-02)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 68.70329013349999 days (2025-07-02 - 2025-09-09)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 102.97058823599986 days (2025-09-09 - 2025-12-21)
# Materials: Furniture, hardware, glass
# other work: 34.35164506210003 days (2025-12-21 - 2026-01-24)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: Muktai Developers
# office_no	: 2112244767.0
# project_res_no: PUNE_Five_749500
# Current Stage: running
# Total Days: 1148.92
# Stage Details:
#  Brick work at 2nd Floor : 12.586281154600021 days (2023-10-31 - 2023-11-12)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 1st floor: 18.31306081979997 days (2023-11-12 - 2023-12-01)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 5th floor Columns casting : 14.879491521399963 days (2023-12-01 - 2023-12-16)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 5th Floor slab casting: 25.20656031520004 days (2023-12-16 - 2024-01-10)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 3rd Floor : 14.879491521399963 days (2024-01-10 - 2024-01-25)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 2nd floor: 19.45254237420004 days (2024-01-25 - 2024-02-13)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 6th floor Columns casting : 13.733599199599993 days (2024-02-13 - 2024-02-27)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 6th Floor slab casting: 26.338095717499964 days (2024-02-27 - 2024-03-24)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 4th Floor : 14.879491521399963 days (2024-03-24 - 2024-04-08)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 3rd floor: 18.31306081979997 days (2024-04-08 - 2024-04-26)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 7th floor Columns casting : 14.879491521399963 days (2024-04-26 - 2024-05-11)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 7th Floor slab casting: 25.20656031520004 days (2024-05-11 - 2024-06-05)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brickwork of  5th to 7th Floor : 40.07866400940005 days (2024-06-05 - 2024-07-15)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# Electrical concealed, PVC Fitting, plastering at 4th-7th floor: 59.47026919519988 days (2024-07-15 - 2024-09-13)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# Plastering on outer sides: 85.90603190219981 days (2024-09-13 - 2024-12-08)
# Materials: cement, sand
# Tiles work: 102.89431704999987 days (2024-12-08 - 2025-03-21)
# Materials: Tiles
# Painting and Finishing: 102.89431704999987 days (2025-03-21 - 2025-07-02)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 68.65902293509998 days (2025-07-02 - 2025-09-08)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 102.89431704999987 days (2025-09-08 - 2025-12-20)
# Materials: Furniture, hardware, glass
# other work: 34.345663008200034 days (2025-12-20 - 2026-01-24)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: RISING ASSOCIATES
# office_no	: 2067242206.0
# project_res_no: PUNE_One_133500
# Current Stage: running
# Total Days: 1148.92
# Stage Details:
#  Brick work at 2nd Floor : 12.58617148360002 days (2023-10-31 - 2023-11-12)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 1st floor: 18.308594219599968 days (2023-11-12 - 2023-12-01)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 5th floor Columns casting : 14.875732797599964 days (2023-12-01 - 2023-12-15)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 5th Floor slab casting: 25.20656031520004 days (2023-12-15 - 2024-01-10)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 3rd Floor : 14.875732797599964 days (2024-01-10 - 2024-01-25)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 2nd floor: 19.45254237420004 days (2024-01-25 - 2024-02-13)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 6th floor Columns casting : 13.733599199599993 days (2024-02-13 - 2024-02-27)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 6th Floor slab casting: 26.337866405399964 days (2024-02-27 - 2024-03-24)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 4th Floor : 14.875732797599964 days (2024-03-24 - 2024-04-08)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 3rd floor: 18.308594219599968 days (2024-04-08 - 2024-04-26)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 7th floor Columns casting : 14.875732797599964 days (2024-04-26 - 2024-05-11)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 7th Floor slab casting: 25.20656031520004 days (2024-05-11 - 2024-06-05)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brickwork of  5th to 7th Floor : 40.06889332150005 days (2024-06-05 - 2024-07-15)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# Electrical concealed, PVC Fitting, plastering at 4th-7th floor: 59.46975075049988 days (2024-07-15 - 2024-09-13)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# Plastering on outer sides: 85.90603190219981 days (2024-09-13 - 2024-12-08)
# Materials: cement, sand
# Tiles work: 102.89431704999987 days (2024-12-08 - 2025-03-21)
# Materials: Tiles
# Painting and Finishing: 102.89431704999987 days (2025-03-21 - 2025-07-02)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 68.65842472969999 days (2025-07-02 - 2025-09-08)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 102.89431704999987 days (2025-09-08 - 2025-12-20)
# Materials: Furniture, hardware, glass
# other work: 34.34536390550004 days (2025-12-20 - 2026-01-23)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: Jayesh Last Name Pandya
# office_no	: 2226719207.0
# project_res_no: Mumbai_Suburban_Two_737500
# Current Stage: running
# Total Days: 1153.76
# Stage Details:
# Tiles work: 103.771884336 days (2023-10-31 - 2024-02-11)
# Materials: Tiles
# Painting and Finishing: 103.771884336 days (2024-02-11 - 2024-05-25)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 69.23449651259997 days (2024-05-25 - 2024-08-02)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 103.771884336 days (2024-08-02 - 2024-11-14)
# Materials: Furniture, hardware, glass
# other work: 34.64925224449998 days (2024-11-14 - 2024-12-19)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: JEM DEVELOPERS AND BUILDERS
# office_no	: 2228493535.0
# project_res_no: Mumbai_Suburban_Two_675000
# Current Stage: running
# Total Days: 1180.88
# Stage Details:
# Tiles work: 105.98554336100004 days (2023-10-31 - 2024-02-14)
# Materials: Tiles
# Painting and Finishing: 105.98554336100004 days (2024-02-14 - 2024-05-30)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 70.56550349019999 days (2024-05-30 - 2024-08-08)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 105.98554336100004 days (2024-08-08 - 2024-11-22)
# Materials: Furniture, hardware, glass
# other work: 35.306979064599986 days (2024-11-22 - 2024-12-28)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: Dilip Babulal Wani
# office_no	: 9823728578.0
# project_res_no: NASIK11S_AHMED1S_858500
# Current Stage: running
# Total Days: 1156.0
# Stage Details:
# Painting and Finishing: 103.72881360000007 days (2023-10-31 - 2024-02-11)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 69.14297108390018 days (2024-02-11 - 2024-04-21)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 103.72881360000007 days (2024-04-21 - 2024-08-02)
# Materials: Furniture, hardware, glass
# other work: 34.57627119000004 days (2024-08-02 - 2024-09-06)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: NIWAS ENTERPRISES
# office_no	: 2024485163.0
# project_res_no: Pune_Six_337500
# Current Stage: running
# Total Days: 1164.62
# Stage Details:
# Tiles work: 104.45832505619988 days (2023-10-31 - 2024-02-12)
# Materials: Tiles
# Painting and Finishing: 104.45832505619988 days (2024-02-12 - 2024-05-27)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 69.5766699890999 days (2024-05-27 - 2024-08-04)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 104.45832505619988 days (2024-08-04 - 2024-11-17)
# Materials: Furniture, hardware, glass
# other work: 34.738983054599935 days (2024-11-17 - 2024-12-21)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: NILESH PRAKASHRAO THAKARE
# office_no	: 7212530340.0
# project_res_no: AHMED2S_AMra3s_AUR7S_TH1S_229000
# Current Stage: running
# Total Days: 1156.37
# Stage Details:
# 7th floor Columns casting : 14.976699896300017 days (2023-10-31 - 2023-11-15)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 7th Floor slab casting: 25.36338982969999 days (2023-11-15 - 2023-12-10)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brickwork of  5th to 7th Floor : 40.35189431220007 days (2023-12-10 - 2024-01-19)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# Electrical concealed, PVC Fitting, plastering at 4th-7th floor: 59.912502495999945 days (2024-01-19 - 2024-03-19)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# Plastering on outer sides: 86.46610169579985 days (2024-03-19 - 2024-06-14)
# Materials: cement, sand
# Tiles work: 103.75932206669987 days (2024-06-14 - 2024-09-26)
# Materials: Tiles
# Painting and Finishing: 103.75932206669987 days (2024-09-26 - 2025-01-07)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 69.12801595089991 days (2025-01-07 - 2025-03-17)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 103.75932206669987 days (2025-03-17 - 2025-06-29)
# Materials: Furniture, hardware, glass
# other work: 34.56490528849992 days (2025-06-29 - 2025-08-03)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: praveenkumar meghraj baldawa
# office_no	: 7020009441.0
# project_res_no: Nagpur5_Sangli_4s_Kohlapur_4s_934000
# Current Stage: running
# Total Days: 1156.54
# Stage Details:
# Electrical concealed, PVC Fitting, plastering at 4th-7th floor: 59.754895317599946 days (2023-10-31 - 2023-12-29)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# Plastering on outer sides: 86.18494516549985 days (2023-12-29 - 2024-03-25)
# Materials: cement, sand
# Tiles work: 103.54037889559987 days (2024-03-25 - 2024-07-06)
# Materials: Tiles
# Painting and Finishing: 103.54037889559987 days (2024-07-06 - 2024-10-18)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 69.02691924099992 days (2024-10-18 - 2024-12-26)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 103.54037889559987 days (2024-12-26 - 2025-04-08)
# Materials: Furniture, hardware, glass
# other work: 34.552941180699925 days (2025-04-08 - 2025-05-13)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: H S Motiwala Builders
# office_no	: 9975309892.0
# project_res_no: Jalga2s_Chand2s_Sola3_Sat6s_381000
# Current Stage: running
# Total Days: 1165.81
# Stage Details:
# Electrical concealed, PVC Fitting, plastering at 2nd floor: 19.75949152110003 days (2023-10-31 - 2023-11-19)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 6th floor Columns casting : 13.947876369600024 days (2023-11-19 - 2023-12-03)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 6th Floor slab casting: 26.733429710800028 days (2023-12-03 - 2023-12-30)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 4th Floor : 15.11019939789997 days (2023-12-30 - 2024-01-14)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 3rd floor: 18.597168492700018 days (2024-01-14 - 2024-02-02)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 7th floor Columns casting : 15.11019939789997 days (2024-02-02 - 2024-02-17)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 7th Floor slab casting: 25.5711066825 days (2024-02-17 - 2024-03-14)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brickwork of  5th to 7th Floor : 40.681306080300054 days (2024-03-14 - 2024-04-23)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# Electrical concealed, PVC Fitting, plastering at 4th-7th floor: 60.44079761130004 days (2024-04-23 - 2024-06-23)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# Plastering on outer sides: 87.16001994419977 days (2024-06-23 - 2024-09-18)
# Materials: cement, sand
# Tiles work: 104.60907274700011 days (2024-09-18 - 2024-12-31)
# Materials: Tiles
# Painting and Finishing: 104.60907274700011 days (2024-12-31 - 2025-04-15)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 69.73938185770012 days (2025-04-15 - 2025-06-24)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 104.60907274700011 days (2025-06-24 - 2025-10-06)
# Materials: Furniture, hardware, glass
# other work: 34.86969092880006 days (2025-10-06 - 2025-11-10)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: TRINITY DREAM HOMES LLP
# office_no	: 2228906462.0
# project_res_no: Palghar_Two_131000
# Current Stage: running
# Total Days: 1168.26
# Stage Details:
# Tiles work: 104.91684948800014 days (2023-10-31 - 2024-02-13)
# Materials: Tiles
# Painting and Finishing: 104.91684948800014 days (2024-02-13 - 2024-05-28)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 69.8907278145999 days (2024-05-28 - 2024-08-05)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 104.91684948800014 days (2024-08-05 - 2024-11-18)
# Materials: Furniture, hardware, glass
# other work: 34.95822532799997 days (2024-11-18 - 2024-12-23)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: Genbaji Developers
# office_no	: 9096727255.0
# project_res_no: Pune_Six_255500
# Current Stage: running
# Total Days: 1150.81
# Stage Details:
#  Brick work at 4th Floor : 14.987716847500012 days (2023-10-31 - 2023-11-15)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 3rd floor: 18.36203389750003 days (2023-11-15 - 2023-12-03)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 7th floor Columns casting : 14.987716847500012 days (2023-12-03 - 2023-12-18)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 7th Floor slab casting: 25.3026321027 days (2023-12-18 - 2024-01-12)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brickwork of  5th to 7th Floor : 40.30897307900005 days (2024-01-12 - 2024-02-22)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# Electrical concealed, PVC Fitting, plastering at 4th-7th floor: 59.7118644091 days (2024-02-22 - 2024-04-21)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# Plastering on outer sides: 86.29187437739992 days (2024-04-21 - 2024-07-17)
# Materials: cement, sand
# Tiles work: 103.50089733109994 days (2024-07-17 - 2024-10-28)
# Materials: Tiles
# Painting and Finishing: 103.50089733109994 days (2024-10-28 - 2025-02-09)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 68.82771684879995 days (2025-02-09 - 2025-04-19)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 103.50089733109994 days (2025-04-19 - 2025-07-31)
# Materials: Furniture, hardware, glass
# other work: 34.66959122929995 days (2025-07-31 - 2025-09-04)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: STATUS REALTOR
# office_no	: 2225416384.0
# project_res_no: RAIGARH_One_800500
# Current Stage: running
# Total Days: 1149.58
# Stage Details:
#  Brick work at Basement to Ground Floor : 26.454586240399976 days (2023-10-31 - 2023-11-26)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at Basement: 17.25508474889998 days (2023-11-26 - 2023-12-13)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 3rd floor Columns casting : 13.776550349599987 days (2023-12-13 - 2023-12-27)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 3rd Floor slab casting: 25.279381852299984 days (2023-12-27 - 2024-01-21)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 1st Floor : 11.499102689699992 days (2024-01-21 - 2024-02-02)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at ground floor: 18.311625126799996 days (2024-02-02 - 2024-02-20)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 4th floor Columns casting : 13.776550349599987 days (2024-02-20 - 2024-03-05)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 4th Floor slab casting: 24.0865603194 days (2024-03-05 - 2024-03-29)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 2nd Floor : 12.610408775399998 days (2024-03-29 - 2024-04-11)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 1st floor: 18.311625126799996 days (2024-04-11 - 2024-04-29)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 5th floor Columns casting : 14.953629111499986 days (2024-04-29 - 2024-05-14)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 5th Floor slab casting: 25.279381852299984 days (2024-05-14 - 2024-06-08)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 3rd Floor : 14.953629111499986 days (2024-06-08 - 2024-06-23)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 2nd floor: 19.553050847600023 days (2024-06-23 - 2024-07-13)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 6th floor Columns casting : 13.776550349599987 days (2024-07-13 - 2024-07-27)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 6th Floor slab casting: 26.454586240399976 days (2024-07-27 - 2024-08-22)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 4th Floor : 14.953629111499986 days (2024-08-22 - 2024-09-06)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 3rd floor: 18.311625126799996 days (2024-09-06 - 2024-09-24)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 7th floor Columns casting : 14.953629111499986 days (2024-09-24 - 2024-10-09)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 7th Floor slab casting: 25.279381852299984 days (2024-10-09 - 2024-11-04)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brickwork of  5th to 7th Floor : 40.19800598170004 days (2024-11-04 - 2024-12-14)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# Electrical concealed, PVC Fitting, plastering at 4th-7th floor: 59.85910269169997 days (2024-12-14 - 2025-02-12)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# Plastering on outer sides: 86.2537387859999 days (2025-02-12 - 2025-05-09)
# Materials: cement, sand
# Tiles work: 103.53140577560005 days (2025-05-09 - 2025-08-20)
# Materials: Tiles
# Painting and Finishing: 103.53140577560005 days (2025-08-20 - 2025-12-02)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 68.89830508480001 days (2025-12-02 - 2026-02-09)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 103.53140577560005 days (2026-02-09 - 2026-05-23)
# Materials: Furniture, hardware, glass
# other work: 34.45573280080002 days (2026-05-23 - 2026-06-27)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: PRADEEP BABURAO TAKALE
# office_no	: 9822975599.0
# project_res_no: PUNE_One_200500
# Current Stage: running
# Total Days: 1180.32
# Stage Details:
# Electrical concealed, PVC Fitting, plastering at 1st floor: 18.827996011000025 days (2023-10-31 - 2023-11-19)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 5th floor Columns casting : 15.28102692169999 days (2023-11-19 - 2023-12-04)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 5th Floor slab casting: 25.86677966179996 days (2023-12-04 - 2023-12-30)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 3rd Floor : 15.28102692169999 days (2023-12-30 - 2024-01-14)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 2nd floor: 19.99152542189996 days (2024-01-14 - 2024-02-03)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 6th floor Columns casting : 14.106520442399974 days (2024-02-03 - 2024-02-17)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 6th Floor slab casting: 27.03153539359998 days (2024-02-17 - 2024-03-15)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 4th Floor : 15.28102692169999 days (2024-03-15 - 2024-03-30)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 3rd floor: 18.827996011000025 days (2024-03-30 - 2024-04-18)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 7th floor Columns casting : 15.28102692169999 days (2024-04-18 - 2024-05-03)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 7th Floor slab casting: 25.86677966179996 days (2024-05-03 - 2024-05-29)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brickwork of  5th to 7th Floor : 41.20648056170006 days (2024-05-29 - 2024-07-10)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# Electrical concealed, PVC Fitting, plastering at 4th-7th floor: 61.183728815000016 days (2024-07-10 - 2024-09-09)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# Plastering on outer sides: 88.10144566409994 days (2024-09-09 - 2024-12-06)
# Materials: cement, sand
# Tiles work: 105.69122630609985 days (2024-12-06 - 2025-03-22)
# Materials: Tiles
# Painting and Finishing: 105.69122630609985 days (2025-03-22 - 2025-07-05)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 70.5666999015001 days (2025-07-05 - 2025-09-14)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 105.69122630609985 days (2025-09-14 - 2025-12-28)
# Materials: Furniture, hardware, glass
# other work: 35.28334995030005 days (2025-12-28 - 2026-02-02)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: DHANALAXMI REALTORS
# office_no	: 8149326780.0
# project_res_no: RAIGARH_Two_772000
# Current Stage: running
# Total Days: 1225.98
# Stage Details:
# Tiles work: 110.14097706800008 days (2023-10-31 - 2024-02-18)
# Materials: Tiles
# Painting and Finishing: 110.14097706800008 days (2024-02-18 - 2024-06-07)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 73.4667996001 days (2024-06-07 - 2024-08-19)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 110.14097706800008 days (2024-08-19 - 2024-12-08)
# Materials: Furniture, hardware, glass
# other work: 36.65024925330002 days (2024-12-08 - 2025-01-13)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: Nilesh Vilas Dhumal
# office_no	: 9822333305.0
# project_res_no: Nagpur5_Sangli_4s_Kohlapur_4s_897500
# Current Stage: running
# Total Days: 1190.05
# Stage Details:
#  Brick work at 3rd Floor : 15.426709873299973 days (2023-10-31 - 2023-11-15)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 2nd floor: 20.167288132799992 days (2023-11-15 - 2023-12-05)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 6th floor Columns casting : 14.242193421699987 days (2023-12-05 - 2023-12-20)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 6th Floor slab casting: 27.297537390299958 days (2023-12-20 - 2024-01-16)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 4th Floor : 15.426709873299973 days (2024-01-16 - 2024-01-31)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 3rd floor: 18.983848451199968 days (2024-01-31 - 2024-02-19)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 7th floor Columns casting : 15.426709873299973 days (2024-02-19 - 2024-03-06)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 7th Floor slab casting: 26.10871386020002 days (2024-03-06 - 2024-04-01)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brickwork of  5th to 7th Floor : 41.53344964670001 days (2024-04-01 - 2024-05-12)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# Electrical concealed, PVC Fitting, plastering at 4th-7th floor: 61.71150548579993 days (2024-05-12 - 2024-07-13)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# Plastering on outer sides: 89.00697905859992 days (2024-07-13 - 2024-10-10)
# Materials: cement, sand
# Tiles work: 106.79222332400012 days (2024-10-10 - 2025-01-25)
# Materials: Tiles
# Painting and Finishing: 106.79222332400012 days (2025-01-25 - 2025-05-12)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 71.17866400850009 days (2025-05-12 - 2025-07-22)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 106.79222332400012 days (2025-07-22 - 2025-11-06)
# Materials: Furniture, hardware, glass
# other work: 35.59740777660005 days (2025-11-06 - 2025-12-11)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: AJASRA GROUP
# office_no	: 9711961513.0
# project_res_no: Palghar_Two_188500
# Current Stage: running
# Total Days: 1191.88
# Stage Details:
# Tiles work: 106.96181452399996 days (2023-10-31 - 2024-02-15)
# Materials: Tiles
# Painting and Finishing: 106.96181452399996 days (2024-02-15 - 2024-06-01)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 71.28454635619998 days (2024-06-01 - 2024-08-11)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 106.96181452399996 days (2024-08-11 - 2024-11-26)
# Materials: Furniture, hardware, glass
# other work: 35.657527420399965 days (2024-11-26 - 2025-01-01)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: RA CONSTRUCTIONS
# office_no	: 7122545627.0
# project_res_no: Nagpur5_Sangli_4s_Kohlapur_4s_341000
# Current Stage: running
# Total Days: 1197.96
# Stage Details:
# Painting and Finishing: 107.65992020629983 days (2023-10-31 - 2024-02-15)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 71.83908274890007 days (2024-02-15 - 2024-04-27)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 107.65992020629983 days (2024-04-27 - 2024-08-13)
# Materials: Furniture, hardware, glass
# other work: 35.9895314089 days (2024-08-13 - 2024-09-18)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: SHIVAM PRAKASH PATEL
# office_no	: 2532530031.0
# project_res_no: NASIK11S_AHMED1S_240000
# Current Stage: running
# Total Days: 1198.1
# Stage Details:
# 5th Floor slab casting: 26.279361909799942 days (2023-10-31 - 2023-11-26)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 3rd Floor : 15.528713861600025 days (2023-11-26 - 2023-12-12)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 2nd floor: 20.306779665200047 days (2023-12-12 - 2024-01-01)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 6th floor Columns casting : 14.334197410699986 days (2024-01-01 - 2024-01-15)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 6th Floor slab casting: 27.47410767269998 days (2024-01-15 - 2024-02-12)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 4th Floor : 15.528713861600025 days (2024-02-12 - 2024-02-27)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 3rd floor: 19.11226321430002 days (2024-02-27 - 2024-03-17)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 7th floor Columns casting : 15.528713861600025 days (2024-03-17 - 2024-04-02)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 7th Floor slab casting: 26.279361909799942 days (2024-04-02 - 2024-04-28)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brickwork of  5th to 7th Floor : 41.80807577139997 days (2024-04-28 - 2024-06-09)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# Electrical concealed, PVC Fitting, plastering at 4th-7th floor: 62.11485543660004 days (2024-06-09 - 2024-08-10)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# Plastering on outer sides: 89.58948155399985 days (2024-08-10 - 2024-11-08)
# Materials: cement, sand
# Tiles work: 107.50648058100016 days (2024-11-08 - 2025-02-23)
# Materials: Tiles
# Painting and Finishing: 107.50648058100016 days (2025-02-23 - 2025-06-11)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 71.67158524919995 days (2025-06-11 - 2025-08-21)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 107.50648058100016 days (2025-08-21 - 2025-12-07)
# Materials: Furniture, hardware, glass
# other work: 35.835493516900016 days (2025-12-07 - 2026-01-12)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: MAITREE VENTURES
# office_no	: 9503284656.0
# project_res_no: PUNE_Five_636000
# Current Stage: running
# Total Days: 1197.91
# Stage Details:
#  Brick work at 3rd Floor : 15.525084749000023 days (2023-10-31 - 2023-11-15)
# Materials: blocks/bricks
# ...
# Plastering on outer sides: 110.53788635749984 days (2024-04-27 - 2024-08-16)
# Materials: cement, sand
# Tiles work: 132.11066797399988 days (2024-08-16 - 2024-12-26)
# Materials: Tiles
# Painting and Finishing: 132.11066797399988 days (2024-12-26 - 2025-05-07)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 88.564307078 days (2025-05-07 - 2025-08-03)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 132.11066797399988 days (2025-08-03 - 2025-12-13)
# Materials: Furniture, hardware, glass
# other work: 44.17597208370001 days (2025-12-13 - 2026-01-27)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: Swapnil Suhas Raut
# office_no	: 2172300237.0
# project_res_no: Jalga2s_Chand2s_Sola3_Sat6s_356000
# Current Stage: running
# Total Days: 1529.9
# Stage Details:
# Electrical concealed, PVC Fitting, plastering at 4th-7th floor: 79.27174476409989 days (2023-10-31 - 2024-01-18)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# Plastering on outer sides: 114.39855434899991 days (2024-01-18 - 2024-05-11)
# Materials: cement, sand
# Tiles work: 137.2800598349999 days (2024-05-11 - 2024-09-26)
# Materials: Tiles
# Painting and Finishing: 137.2800598349999 days (2024-09-26 - 2025-02-10)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 91.46560319000008 days (2025-02-10 - 2025-05-12)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 137.2800598349999 days (2025-05-12 - 2025-09-27)
# Materials: Furniture, hardware, glass
# other work: 45.732801600000045 days (2025-09-27 - 2025-11-11)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: VASUDEVAY BUILDERS & DEVELOPERS
# office_no	: 2532397482.0
# project_res_no: Sindh3s_Wardha2s_NASIK8S_627500
# Current Stage: running
# Total Days: 1530.73
# Stage Details:
# Electrical concealed, PVC Fitting, plastering at 4th-7th floor: 79.31425722949996 days (2023-10-31 - 2024-01-18)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# Plastering on outer sides: 114.4636092080001 days (2024-01-18 - 2024-05-11)
# Materials: cement, sand
# Tiles work: 137.3554337069999 days (2024-05-11 - 2024-09-26)
# Materials: Tiles
# Painting and Finishing: 137.3554337069999 days (2024-09-26 - 2025-02-10)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 91.51585244359985 days (2025-02-10 - 2025-05-13)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 137.3554337069999 days (2025-05-13 - 2025-09-27)
# Materials: Furniture, hardware, glass
# other work: 45.75792621839999 days (2025-09-27 - 2025-11-12)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: SHEELA SANTOSH BORADE
# office_no	: 2532397482.0
# project_res_no: Sindh3s_Wardha2s_NASIK8S_551500
# Current Stage: running
# Total Days: 1535.24
# Stage Details:
# Painting and Finishing: 137.7008972849998 days (2023-10-31 - 2024-03-16)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 91.80897307840004 days (2024-03-16 - 2024-06-16)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 137.7008972849998 days (2024-06-16 - 2024-11-01)
# Materials: Furniture, hardware, glass
# other work: 45.89341973960002 days (2024-11-01 - 2024-12-17)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: Nkg Buildcon Private Limited
# office_no	: 9773338587.0
# project_res_no: RAJ/P/2022/2252
# Current Stage: running
# Total Days: 1705.97
# Stage Details:
# Painting and Finishing: 153.47736791000014 days (2023-10-31 - 2024-04-01)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 102.21176468240003 days (2024-04-01 - 2024-07-12)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 153.47736791000014 days (2024-07-12 - 2024-12-13)
# Materials: Furniture, hardware, glass
# other work: 51.057128611600035 days (2024-12-13 - 2025-02-02)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: SANSKAR BUILDERS AND DEVELOPERS
# office_no	: 2532397482.0
# project_res_no: NASIK11S_AHMED1S_741500
# Current Stage: running
# Total Days: 1540.31
# Stage Details:
# Painting and Finishing: 138.09391824399984 days (2023-10-31 - 2024-03-17)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 92.20737786819994 days (2024-03-17 - 2024-06-17)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 138.09391824399984 days (2024-06-17 - 2024-11-02)
# Materials: Furniture, hardware, glass
# other work: 46.048953137100014 days (2024-11-02 - 2024-12-18)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: Kumkum Constructions
# office_no	: 8237369692.0
# project_res_no: Palghar_Two_168500
# Current Stage: running
# Total Days: 1525.11
# Stage Details:
# Painting and Finishing: 136.93549349700007 days (2023-10-31 - 2024-03-16)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 90.6729810560001 days (2024-03-16 - 2024-06-14)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 136.93549349700007 days (2024-06-14 - 2024-10-29)
# Materials: Furniture, hardware, glass
# other work: 45.488434694000055 days (2024-10-29 - 2024-12-14)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: M SONS BUILDER AND DEVELOPERS
# office_no	: 0.0
# project_res_no: Jalga2s_Chand2s_Sola3_Sat6s_829500
# Current Stage: running
# Total Days: 1567.08
# Stage Details:
# Painting and Finishing: 140.61535391999973 days (2023-10-31 - 2024-03-19)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 93.77886340929994 days (2024-03-19 - 2024-06-21)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 140.61535391999973 days (2024-06-21 - 2024-11-09)
# Materials: Furniture, hardware, glass
# other work: 46.90019940139996 days (2024-11-09 - 2024-12-26)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: BHAGYALAXMI BUILDERS AND DEVELOPERS
# office_no	: 2532347444.0
# project_res_no: Sindh3s_Wardha2s_NASIK8S_384000
# Current Stage: running
# Total Days: 1563.22
# Stage Details:
#  Brickwork of  5th to 7th Floor : 54.54521435459996 days (2023-10-31 - 2023-12-24)
# Electrical concealed, PVC Fitting, plastering at 4th-7th floor: 81.04430708260003 days (2023-12-24 - 2024-03-14)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# Plastering on outer sides: 116.88260222399985 days (2024-03-14 - 2024-07-09)
# Materials: cement, sand
# Tiles work: 140.26899297799983 days (2024-07-09 - 2024-11-26)
# Materials: Tiles
# Painting and Finishing: 140.26899297799983 days (2024-11-26 - 2025-04-16)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 93.5060817592002 days (2025-04-16 - 2025-07-18)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 140.26899297799983 days (2025-07-18 - 2025-12-06)
# Materials: Furniture, hardware, glass
# other work: 46.7530408796001 days (2025-12-06 - 2026-01-21)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: MAHALAXMI ENTERPRISE
# office_no	: 2412321376.0
# project_res_no: NASIK11S_AHMED1S_903500
# Current Stage: running
# Total Days: 1563.77
# Stage Details:
#  Brickwork of  5th to 7th Floor : 54.56440677759996 days (2023-10-31 - 2023-12-24)
# Electrical concealed, PVC Fitting, plastering at 4th-7th floor: 81.07282153910003 days (2023-12-24 - 2024-03-14)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# Plastering on outer sides: 116.93195416799989 days (2024-03-14 - 2024-07-09)
# Materials: cement, sand
# Tiles work: 140.30847453399983 days (2024-07-09 - 2024-11-27)
# Materials: Tiles
# Painting and Finishing: 140.30847453399983 days (2024-11-27 - 2025-04-16)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 93.5389830552002 days (2025-04-16 - 2025-07-18)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 140.30847453399983 days (2025-07-18 - 2025-12-06)
# Materials: Furniture, hardware, glass
# other work: 46.772781657200106 days (2025-12-06 - 2026-01-22)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: Kiran Jagannath Katale
# office_no	: 9545195777.0
# project_res_no: NASIK11S_AHMED1S_800500
# Current Stage: running
# Total Days: 1572.27
# Stage Details:
# Painting and Finishing: 141.0729810459998 days (2023-10-31 - 2024-03-20)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 94.04865403700009 days (2024-03-20 - 2024-06-22)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 141.0729810459998 days (2024-06-22 - 2024-11-10)
# Materials: Furniture, hardware, glass
# other work: 47.024327018400044 days (2024-11-10 - 2024-12-27)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: MOHAN HARDASMAL THARWANI
# office_no	: 2512720600.0
# project_res_no: THANE11S_318000
# Current Stage: running
# Total Days: 1574.28
# Stage Details:
# Painting and Finishing: 141.4202392709998 days (2023-10-31 - 2024-03-20)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 94.30049850390007 days (2024-03-20 - 2024-06-22)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 141.4202392709998 days (2024-06-22 - 2024-11-11)
# Materials: Furniture, hardware, glass
# other work: 47.129012960600036 days (2024-11-11 - 2024-12-28)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: KASHINATH SOPAN DABHADE
# office_no	: 2225299942.0
# project_res_no: PUNE_Two_623000
# Current Stage: running
# Total Days: 1576.78
# Stage Details:
#  Brickwork of  5th to 7th Floor : 55.0260717868 days (2023-10-31 - 2023-12-25)
# Electrical concealed, PVC Fitting, plastering at 4th-7th floor: 81.7447258237999 days (2023-12-25 - 2024-03-15)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# Plastering on outer sides: 117.8920738020001 days (2024-03-15 - 2024-07-11)
# Materials: cement, sand
# Tiles work: 141.497407757 days (2024-07-11 - 2024-11-30)
# Materials: Tiles
# Painting and Finishing: 141.497407757 days (2024-11-30 - 2025-04-20)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 94.3178464630002 days (2025-04-20 - 2025-07-24)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 141.497407757 days (2025-07-24 - 2025-12-12)
# Materials: Furniture, hardware, glass
# other work: 47.158025922900094 days (2025-12-12 - 2026-01-28)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: GOLOK DEVELOPERS
# office_no	: 9822292029.0
# project_res_no: AHMED2S_AMra3s_AUR7S_TH1S_551500
# Current Stage: running
# Total Days: 1576.97
# Stage Details:
#  Brickwork of  5th to 7th Floor : 55.0368893347 days (2023-10-31 - 2023-12-25)
# Electrical concealed, PVC Fitting, plastering at 4th-7th floor: 81.75198404939991 days (2023-12-25 - 2024-03-16)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# Plastering on outer sides: 117.93320042600011 days (2024-03-16 - 2024-07-11)
# Materials: cement, sand
# Tiles work: 141.524327 days (2024-07-11 - 2024-11-30)
# Materials: Tiles
# Painting and Finishing: 141.524327 days (2024-11-30 - 2025-04-20)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 94.3286141597002 days (2025-04-20 - 2025-07-24)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 141.524327 days (2025-07-24 - 2025-12-12)
# Materials: Furniture, hardware, glass
# other work: 47.161316052400096 days (2025-12-12 - 2026-01-29)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: VARAD DEVELOPERS
# office_no	: 2312657349.0
# project_res_no: Nagpur5_Sangli_4s_Kohlapur_4s_977500
# Current Stage: running
# Total Days: 1592.21
# Stage Details:
# Painting and Finishing: 142.46739782199987 days (2023-10-31 - 2024-03-21)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 95.17148554599999 days (2024-03-21 - 2024-06-24)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 142.46739782199987 days (2024-06-24 - 2024-11-14)
# Materials: Furniture, hardware, glass
# other work: 47.486440675099956 days (2024-11-14 - 2024-12-31)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: MAHAVIR BUILDERS AND DEVELOPERS PVT.LTD.
# office_no	: 2532397482.0
# project_res_no: NASIK11S_AHMED1S_6000
# Current Stage: running
# Total Days: 1602.27
# Stage Details:
# Painting and Finishing: 143.41405784199986 days (2023-10-31 - 2024-03-22)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 95.80797607499998 days (2024-03-22 - 2024-06-26)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 143.41405784199986 days (2024-06-26 - 2024-11-16)
# Materials: Furniture, hardware, glass
# other work: 47.804985041999956 days (2024-11-16 - 2025-01-03)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: SHIVSHRI PROPERTIES
# office_no	: 9689361195.0
# project_res_no: Pune_Six_339500
# Current Stage: running
# Total Days: 1585.56
# Stage Details:
# Painting and Finishing: 142.24666001700024 days (2023-10-31 - 2024-03-21)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 94.7485543354001 days (2024-03-21 - 2024-06-24)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 142.24666001700024 days (2024-06-24 - 2024-11-13)
# Materials: Furniture, hardware, glass
# other work: 47.438883349100045 days (2024-11-13 - 2024-12-30)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: DEEPAK VENKATRAO KULKARNI
# office_no	: 2402339293.0
# project_res_no: AHMED2S_AMra3s_AUR7S_TH1S_713000
# Current Stage: running
# Total Days: 1604.45
# Stage Details:
# Painting and Finishing: 144.03768693399996 days (2023-10-31 - 2024-03-23)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 95.90907277729997 days (2024-03-23 - 2024-06-27)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 144.03768693399996 days (2024-06-27 - 2024-11-18)
# Materials: Furniture, hardware, glass
# other work: 47.9533399797 days (2024-11-18 - 2025-01-05)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: Gold Coin Builders
# office_no	: 2226673464.0
# project_res_no: Mumbai_Suburban_Three_16000
# Current Stage: running
# Total Days: 1599.77
# Stage Details:
#  Brickwork of  5th to 7th Floor : 55.82412761840001 days (2023-10-31 - 2023-12-26)
# Electrical concealed, PVC Fitting, plastering at 4th-7th floor: 82.93974077439994 days (2023-12-26 - 2024-03-17)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# Plastering on outer sides: 119.62686939599982 days (2024-03-17 - 2024-07-15)
# Materials: cement, sand
# Tiles work: 143.5540378790001 days (2024-07-15 - 2024-12-06)
# Materials: Tiles
# Painting and Finishing: 143.5540378790001 days (2024-12-06 - 2025-04-28)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 95.69970089980005 days (2025-04-28 - 2025-08-02)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 143.5540378790001 days (2025-08-02 - 2025-12-23)
# Materials: Furniture, hardware, glass
# other work: 47.84925224380004 days (2025-12-23 - 2026-02-09)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: Vijay Shankar Inamdar
# office_no	: 9822491596.0
# project_res_no: PUNE_One_802500
# Current Stage: running
# Total Days: 1605.44
# Stage Details:
#  Brickwork of  5th to 7th Floor : 55.984995015999964 days (2023-10-31 - 2023-12-26)
# Electrical concealed, PVC Fitting, plastering at 4th-7th floor: 83.34412761820008 days (2023-12-26 - 2024-03-18)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# Plastering on outer sides: 120.1099202639999 days (2024-03-18 - 2024-07-16)
# Materials: cement, sand
# Tiles work: 144.25573282799988 days (2024-07-16 - 2024-12-07)
# Materials: Tiles
# Painting and Finishing: 144.25573282799988 days (2024-12-07 - 2025-05-01)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 96.16630109800006 days (2025-05-01 - 2025-08-05)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 144.25573282799988 days (2025-08-05 - 2025-12-27)
# Materials: Furniture, hardware, glass
# other work: 48.121435690000006 days (2025-12-27 - 2026-02-13)
# Materials: Furniture, hardware, glass
# -----------------

# %%
import pandas as pd

# Create a list to store the data
data = []

# Iterate through each row (project) in the new_data DataFrame
for index, row in new_data.iterrows():
    current_materials = []  # List to store materials for the current stage
    current_stage_start_date = current_date  # Initialize with the current date
    project_id = f'Project_{index + 1}'  # Generate a project_id

    for stage in stage_columns:
        stage_duration = row[stage]

        if not pd.isna(stage_duration):
            # Calculate the stage end date
            stage_end_date = current_stage_start_date + pd.Timedelta(days=stage_duration)

            # Format the dates for display
            start_date_str = current_stage_start_date.strftime('%m/%d/%Y')
            end_date_str = stage_end_date.strftime('%m/%d/%Y')

            # Check if there are materials for this stage
            materials = stage_materials.get(stage, [])

            if materials:
                # Store the data in the desired format
                data.append([end_date_str, stage, ", ".join(materials), project_id, row['organisation_name'], row['office_no'], row['project_res_no']])

            # Update the start date for the next stage
            current_stage_start_date = stage_end_date

# Create a DataFrame from the data
output_data = pd.DataFrame(data, columns=['Date', 'Stage', 'Recommended Materials', 'Project_ID', 'organisation_name', 'office_no', 'project_res_no'])

# Save the DataFrame to a CSV file
output_data.to_csv('output_7_final.csv', index=False)
