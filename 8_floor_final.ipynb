# %% [markdown]
# <a href="https://colab.research.google.com/github/k-vinamr/rera_construction_pred/blob/main/8_floor_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display
import statsmodels as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.model_selection import train_test_split,GridSearchCV,RandomizedSearchCV
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor
from sklearn.metrics import r2_score,mean_squared_error
from sklearn import preprocessing
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from datetime import datetime
# Load your dataset
data = pd.read_csv('augmented_8_floor.csv')

# %%
data
# Out:
#                                   organisation_name  \
# 0      SHREE SWAMI SAMARTH PROMOTERS AND DEVELOPERS
# 1                                  Orion Developers
# 2                              GLOBAL CONSTRUCTIONS
# 3                   VERSATILEREALTORSPRIVATELIMITED
# 4                                     ARFA REALTIES
# ...                                             ...
# 19995                           Shrinath Developers
# 19996                     Dipti Home Makers Pvt Ltd
# 19997                       MUNISH GROUP OF COMPANY
# 19998                      SAI SHRUSHTI ENTERPRISES
# 19999                               SLV ENTERPRISES
#
#                 project_category actual_commencement_date  \
# 0      Residential/Group Housing               02-09-2022
# 1      Residential/Group Housing               20-06-2022
# 2      Residential/Group Housing               09-09-2021
# 3      Residential/Group Housing               18-05-2020
# 4      Residential/Group Housing               24-01-2023
# ...                          ...                      ...
# 19995  Residential/Group Housing               07-09-2021
# 19996  Residential/Group Housing               15-09-2021
# 19997  Residential/Group Housing               14-06-2022
# 19998  Residential/Group Housing               02-09-2021
# 19999  Residential/Group Housing               09-04-2017
#
#       estimated_finish_date  total_built_up_area_saleable_area  \
# 0                31-12-2023                         685.000000
# 1                31-12-2025                         419.720000
# 2                30-03-2022                         326.950000
# 3                30-09-2020                         798.210000
# 4                31-07-2024                         851.970000
# ...                     ...                                ...
# 19995            26-05-2022                         767.359392
# 19996            06-08-2022                       17438.471230
# 19997            27-12-2027                        4548.256675
# 19998            05-01-2022                        1818.804599
# 19999            03-01-2018                         805.993283
#
#        total_area_of_project  floor project_state  total_days  \
# 0                 141.300000      8   MAHARASHTRA         485
# 1                 148.800000      8   MAHARASHTRA        1290
# 2                 152.300000      8   MAHARASHTRA         202
# 3                 152.750000      8   MAHARASHTRA         135
# 4                 154.700000      8   MAHARASHTRA         554
# ...                      ...    ...           ...         ...
# 19995            1406.314254      8   MAHARASHTRA         263
# 19996            4812.919934      8   MAHARASHTRA         325
# 19997            2566.508795      8   MAHARASHTRA        2025
# 19998            1033.712488      8   MAHARASHTRA         112
# 19999             373.466697      8   MAHARASHTRA         263
#
#        Cleaning & survey  ...  Tiles work  Painting and Finishing  \
# 0               2.313931  ...   41.650763               41.650763
# 1               6.154580  ...  110.782443              110.782443
# 2               0.963740  ...   17.347328               17.347328
# 3               0.644084  ...   11.593511               11.593511
# 4               2.643130  ...   47.576336               47.576336
# ...                  ...  ...         ...                     ...
# 19995           1.254771  ...   22.585878               22.585878
# 19996           1.550573  ...   27.910305               27.910305
# 19997           9.661260  ...  173.902672              173.902672
# 19998           0.534351  ...    9.618321                9.618321
# 19999           1.254771  ...   22.585878               22.585878
#
#        Plumbing & Sanitary,Electrification Works  \
# 0                                      25.453244
# 1                                      67.700382
# 2                                      10.601145
# 3                                       7.084924
# 4                                      29.074427
# ...                                          ...
# 19995                                  13.802481
# 19996                                  17.056298
# 19997                                 106.273855
# 19998                                   5.877863
# 19999                                  13.802481
#
#        Doors & Windows Fixing Furniture work  other work  \
# 0                                  41.650763   13.883588
# 1                                 110.782443   36.927481
# 2                                  17.347328    5.782443
# 3                                  11.593511    3.864504
# 4                                  47.576336   15.858779
# ...                                      ...         ...
# 19995                              22.585878    7.528626
# 19996                              27.910305    9.303435
# 19997                             173.902672   57.967557
# 19998                               9.618321    3.206107
# 19999                              22.585878    7.528626
#
#        duration_since_commencement  remaining_duration  progress_ratio  \
# 0                              423                  61        0.872165
# 1                              497                 792        0.385271
# 2                              781                -580        3.866337
# 3                             1260               -1126        9.333333
# 4                              279                 274        0.503610
# ...                            ...                 ...             ...
# 19995                          781                -519        2.969582
# 19996                          781                -457        2.403077
# 19997                          502                1522        0.247901
# 19998                          781                -670        6.973214
# 19999                         2392               -2130        9.095057
#
#        current_stage        area_bin
# 0            running     (500, 1000]
# 1            running        (0, 500]
# 2          completed        (0, 500]
# 3          completed     (500, 1000]
# 4            running     (500, 1000]
# ...              ...             ...
# 19995      completed     (500, 1000]
# 19996      completed  (17000, 17500]
# 19997        running    (4500, 5000]
# 19998      completed    (1500, 2000]
# 19999      completed     (500, 1000]
#
# [20000 rows x 55 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 55 columns):
#  #   Column                                                                     Non-Null Count  Dtype
# ---  ------                                                                     --------------  -----
#  0   organisation_name                                                          20000 non-null  object
#  1   project_category                                                           20000 non-null  object
#  2   actual_commencement_date                                                   20000 non-null  object
#  3   estimated_finish_date                                                      20000 non-null  object
#  4   total_built_up_area_saleable_area                                          20000 non-null  float64
#  5   total_area_of_project                                                      20000 non-null  float64
#  6   floor                                                                      20000 non-null  int64
#  7   project_state                                                              20000 non-null  object
#  8   total_days                                                                 20000 non-null  int64
#  9   Cleaning & survey                                                          20000 non-null  float64
#  10  Excavation,leveling & P.C.C  for Basement  B1                              20000 non-null  float64
#  11   Raft footing, Column B1, Retaining wall Reinforcement ,Concrete pouring   20000 non-null  float64
#  12  Slab of B (bottom)                                                         20000 non-null  float64
#  13   Ground Floor slab casting                                                 20000 non-null  float64
#  14   1st floor Columns casting                                                 20000 non-null  float64
#  15   1st Floor slab casting                                                    20000 non-null  float64
#  16  2nd floor Columns casting                                                  20000 non-null  float64
#  17  2nd Floor slab casting                                                     20000 non-null  float64
#  18   Brick work at Basement to Ground Floor                                    20000 non-null  float64
#  19  Electrical concealed, PVC Fitting, plastering at Basement                  20000 non-null  float64
#  20  3rd floor Columns casting                                                  20000 non-null  float64
#  21  3rd Floor slab casting                                                     20000 non-null  float64
#  22   Brick work at 1st Floor                                                   20000 non-null  float64
#  23  Electrical concealed, PVC Fitting, plastering at ground floor              20000 non-null  float64
#  24  4th floor Columns casting                                                  20000 non-null  float64
#  25  4th Floor slab casting                                                     20000 non-null  float64
#  26   Brick work at 2nd Floor                                                   20000 non-null  float64
#  27  Electrical concealed, PVC Fitting, plastering at 1st floor                 20000 non-null  float64
#  28  5th floor Columns casting                                                  20000 non-null  float64
#  29  5th Floor slab casting                                                     20000 non-null  float64
#  30   Brick work at 3rd Floor                                                   20000 non-null  float64
#  31  Electrical concealed, PVC Fitting, plastering at 2nd floor                 20000 non-null  float64
#  32  6th floor Columns casting                                                  20000 non-null  float64
#  33  6th Floor slab casting                                                     20000 non-null  float64
#  34   Brick work at 4th Floor                                                   20000 non-null  float64
#  35  Electrical concealed, PVC Fitting, plastering at 3rd floor                 20000 non-null  float64
#  36  7th floor Columns casting                                                  20000 non-null  float64
#  37  7th Floor slab casting                                                     20000 non-null  float64
#  38   Brick work at 5th Floor                                                   20000 non-null  float64
#  39  Electrical concealed, PVC Fitting, plastering at 4th floor                 20000 non-null  float64
#  40  8th floor Columns casting                                                  20000 non-null  float64
#  41  8th Floor slab casting                                                     20000 non-null  float64
#  42   Brick work of 6th to 8th Floor                                            20000 non-null  float64
#  43  Electrical concealed, PVC Fitting, plastering at 5th-8th floor             20000 non-null  float64
#  44  Plastering on outer sides                                                  20000 non-null  float64
#  45  Tiles work                                                                 20000 non-null  float64
#  46  Painting and Finishing                                                     20000 non-null  float64
#  47  Plumbing & Sanitary,Electrification Works                                  20000 non-null  float64
#  48  Doors & Windows Fixing Furniture work                                      20000 non-null  float64
#  49  other work                                                                 20000 non-null  float64
#  50  duration_since_commencement                                                20000 non-null  int64
#  51  remaining_duration                                                         20000 non-null  int64
#  52  progress_ratio                                                             20000 non-null  float64
#  53  current_stage                                                              20000 non-null  object
#  54  area_bin                                                                   20000 non-null  object
# dtypes: float64(44), int64(4), object(7)
# memory usage: 8.4+ MB

# %%
# Converting date columns to datetime objects
data['actual_commencement_date'] = pd.to_datetime(data['actual_commencement_date'], errors='coerce')
data['estimated_finish_date'] = pd.to_datetime(data['estimated_finish_date'], errors='coerce')
# Out:
# <ipython-input-68-1b85272236a7>:2: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   data['actual_commencement_date'] = pd.to_datetime(data['actual_commencement_date'], errors='coerce')
# <ipython-input-68-1b85272236a7>:3: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   data['estimated_finish_date'] = pd.to_datetime(data['estimated_finish_date'], errors='coerce')

# %%
current_date = datetime.now()

# %%
data['duration_since_commencement'] = (current_date - data['actual_commencement_date']).dt.days
data['remaining_duration'] = (data['estimated_finish_date'] - current_date).dt.days
data['progress_ratio'] = data['duration_since_commencement'] / data['total_days']

# %%
# Define a function to determine the project status
def determine_status(row):
    if current_date > row['estimated_finish_date']:
        return 'completed'
    elif current_date >= row['actual_commencement_date']:
        return 'running'
    else:
        return 'upcoming'

# Apply the function to create the 'Status' column
data['current_stage'] = data.apply(determine_status, axis=1)

# %%
data.columns
# Out:
# Index(['organisation_name', 'project_category', 'actual_commencement_date',
#        'estimated_finish_date', 'total_built_up_area_saleable_area',
#        'total_area_of_project', 'floor', 'project_state', 'total_days',
#        'Cleaning & survey', 'Excavation,leveling & P.C.C  for Basement  B1 ',
#        ' Raft footing, Column B1, Retaining wall Reinforcement ,Concrete pouring ',
#        'Slab of B (bottom) ', ' Ground Floor slab casting ',
#        ' 1st floor Columns casting', ' 1st Floor slab casting',
#        '2nd floor Columns casting ', '2nd Floor slab casting',
#        ' Brick work at Basement to Ground Floor ',
#        'Electrical concealed, PVC Fitting, plastering at Basement',
#        '3rd floor Columns casting ', '3rd Floor slab casting',
#        ' Brick work at 1st Floor ',
#        'Electrical concealed, PVC Fitting, plastering at ground floor',
#        '4th floor Columns casting ', '4th Floor slab casting',
#        ' Brick work at 2nd Floor ',
#        'Electrical concealed, PVC Fitting, plastering at 1st floor',
#        '5th floor Columns casting ', '5th Floor slab casting',
#        ' Brick work at 3rd Floor ',
#        'Electrical concealed, PVC Fitting, plastering at 2nd floor',
#        '6th floor Columns casting ', '6th Floor slab casting',
#        ' Brick work at 4th Floor ',
#        'Electrical concealed, PVC Fitting, plastering at 3rd floor',
#        '7th floor Columns casting ', '7th Floor slab casting',
#        ' Brick work at 5th Floor ',
#        'Electrical concealed, PVC Fitting, plastering at 4th floor',
#        '8th floor Columns casting ', '8th Floor slab casting',
#        ' Brick work of 6th to 8th Floor ',
#        'Electrical concealed, PVC Fitting, plastering at 5th-8th floor',
#        'Plastering on outer sides', 'Tiles work', 'Painting and Finishing',
#        'Plumbing & Sanitary,Electrification Works',
#        'Doors & Windows Fixing Furniture work', 'other work',
#        'duration_since_commencement', 'remaining_duration', 'progress_ratio',
#        'current_stage', 'area_bin'],
#       dtype='object')

# %%
# Performing label encoding on the 'current_stage' column
label_encoder = LabelEncoder()
data['current_stage'] = data['current_stage'].astype(str) # Converting to string to handle any NaN values left
data['current_stage_encoded'] = label_encoder.fit_transform(data['current_stage'])

# %%
# Performing label encoding on the 'current_stage' column
label_encoder = LabelEncoder()
data['project_state'] = data['project_state'].astype(str) # Converting to string to handle any NaN values left
data['project_state_encoded'] = label_encoder.fit_transform(data['project_state'])

# %%
(data['current_stage'].value_counts()).plot(kind='barh'); plt.show()

# %%
data['total_days'].describe()
# Out:
# count    20000.000000
# mean       870.918350
# std        543.635541
# min         94.000000
# 25%        477.000000
# 50%        830.000000
# 75%       1216.000000
# max       3934.000000
# Name: total_days, dtype: float64

# %%
# Feature selection - use relevant features for input
numerical_columns = data.select_dtypes(include=['int64', 'float64'])
stage_columns = [ 'Cleaning & survey',
       'Excavation,leveling & P.C.C  for Basement  B1 ',
       ' Raft footing, Column B1, Retaining wall Reinforcement ,Concrete pouring ',
       'Slab of B (bottom) ', ' Ground Floor slab casting ',
       ' 1st floor Columns casting', ' 1st Floor slab casting',
       '2nd floor Columns casting ', '2nd Floor slab casting',
       ' Brick work at Basement to Ground Floor ',
       'Electrical concealed, PVC Fitting, plastering at Basement',
       '3rd floor Columns casting ', '3rd Floor slab casting',
       ' Brick work at 1st Floor ',
       'Electrical concealed, PVC Fitting, plastering at ground floor',
       '4th floor Columns casting ', '4th Floor slab casting',
       ' Brick work at 2nd Floor ',
       'Electrical concealed, PVC Fitting, plastering at 1st floor',
       '5th floor Columns casting ', '5th Floor slab casting',
       ' Brick work at 3rd Floor ',
       'Electrical concealed, PVC Fitting, plastering at 2nd floor',
       '6th floor Columns casting ', '6th Floor slab casting',
       ' Brick work at 4th Floor ',
       'Electrical concealed, PVC Fitting, plastering at 3rd floor',
       '7th floor Columns casting ', '7th Floor slab casting',
       ' Brick work at 5th Floor ',
       'Electrical concealed, PVC Fitting, plastering at 4th floor',
       '8th floor Columns casting ', '8th Floor slab casting',
       ' Brick work of 6th to 8th Floor ',
       'Electrical concealed, PVC Fitting, plastering at 5th-8th floor',
       'Plastering on outer sides', 'Tiles work', 'Painting and Finishing',
       'Plumbing & Sanitary,Electrification Works',
       'Doors & Windows Fixing Furniture work', 'other work']
# Target variables
X = data[numerical_columns.columns.difference(stage_columns)].drop(columns='total_days')
y_total_days = data['total_days']
y_time_taken_at_each_stage = data[stage_columns]

# %%
X.columns
# Out:
# Index(['current_stage_encoded', 'duration_since_commencement', 'floor',
#        'progress_ratio', 'project_state_encoded', 'remaining_duration',
#        'total_area_of_project', 'total_built_up_area_saleable_area'],
#       dtype='object')

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# Assuming you have loaded your data and defined 'X' and 'y_total_days' as specified

# Split the data into training and testing sets
X_train, X_test, y_train_total_days, y_test_total_days = train_test_split(
    X, y_total_days, test_size=0.2, random_state=42)

# Create a function to train a Random Forest regression model, make predictions, and evaluate its performance
def train_evaluate_model(X_train, X_test, y_train_total_days, y_test_total_day):
    model = RandomForestRegressor(n_estimators=100, random_state=42)
    model.fit(X_train, y_train_total_days)
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test_total_days, y_pred)
    r2 = r2_score(y_test_total_days, y_pred)
    return mse, r2

# Initial model performance
initial_mse, initial_r2 = train_evaluate_model(X_train, X_test, y_train_total_days, y_test_total_days)
feature_impact = {}

for column in X.columns:
    X_temp = X.drop(columns=[column])
    mse, r2 = train_evaluate_model(X_train, X_test, y_train_total_days, y_test_total_days)
    mse_change = initial_mse - mse
    r2_change = r2 - initial_r2
    feature_impact[column] = {'MSE Change': mse_change, 'R-squared Change': r2_change}

# Print the impact of removing each feature
for column, impact in feature_impact.items():
    print(f"Removed '{column}':")
    print(f"MSE Change: {impact['MSE Change']:.2f}")
    print(f"R-squared Change: {impact['R-squared Change']:.4f}\n")
# Out:
# Removed 'current_stage_encoded':
# MSE Change: 0.00
# R-squared Change: 0.0000
#
# Removed 'duration_since_commencement':
# MSE Change: 0.00
# R-squared Change: 0.0000
#
# Removed 'floor':
# MSE Change: 0.00
# R-squared Change: 0.0000
#
# Removed 'progress_ratio':
# MSE Change: 0.00
# R-squared Change: 0.0000
#
# Removed 'project_state_encoded':
# MSE Change: 0.00
# R-squared Change: 0.0000
#
# Removed 'remaining_duration':
# MSE Change: 0.00
# R-squared Change: 0.0000
#
# Removed 'total_area_of_project':
# MSE Change: 0.00
# R-squared Change: 0.0000
#
# Removed 'total_built_up_area_saleable_area':
# MSE Change: 0.00
# R-squared Change: 0.0000

# %%
# Train a Random Forest model on the entire dataset
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X, y_total_days)

# Get feature importances
importances = model.feature_importances_

# Pair feature names with their importance scores
feature_importance = list(zip(X.columns, importances))

# Sort features by importance (in descending order)
feature_importance.sort(key=lambda x: x[1], reverse=True)

# Print the feature importances
for feature, importance in feature_importance:
    print(f"{feature}: {importance:.4f}")
# Out:
# remaining_duration: 0.6616
# progress_ratio: 0.1730
# duration_since_commencement: 0.1267
# project_state_encoded: 0.0327
# total_area_of_project: 0.0030
# total_built_up_area_saleable_area: 0.0029
# current_stage_encoded: 0.0001
# floor: 0.0000

# %%
# Split the data into training and testing sets
X_train, X_test, y_train_total_days, y_test_total_days, y_train_time, y_test_time = train_test_split(
    X, y_total_days, y_time_taken_at_each_stage, test_size=0.2, random_state=42)

# Create and train the regression model for total days
total_days_model = RandomForestRegressor(n_estimators=100, random_state=42)
total_days_model.fit(X_train, y_train_total_days)

# Predict total days on the test set
y_pred_total_days = total_days_model.predict(X_test)

# Evaluate the model for total days
mse_total_days = mean_squared_error(y_test_total_days, y_pred_total_days)
r2_total_days = r2_score(y_test_total_days, y_pred_total_days)
print(f'Mean Squared Error (Total Days): {mse_total_days}')
print(f'R-squared (Total Days): {r2_total_days}')
# Out:
# Mean Squared Error (Total Days): 333.65274205000003
# R-squared (Total Days): 0.9988473845852655

# %%
from sklearn.metrics import make_scorer
from sklearn.model_selection import cross_val_score
# Define a custom scorer for cross-validation
mse_scorer = make_scorer(mean_squared_error)  # Use make_scorer to create the custom scorer

# Perform K-Fold Cross-Validation
k = 5  # You can adjust the number of folds
cv_scores = cross_val_score(total_days_model, X, y_total_days, cv=k, scoring=mse_scorer)

# Print the mean and standard deviation of MSE scores
print("Cross-Validation Mean MSE:", np.mean(cv_scores))
print("Cross-Validation MSE Std Dev:", np.std(cv_scores))
# Out:
# Cross-Validation Mean MSE: 381.451389015
# Cross-Validation MSE Std Dev: 78.98425411808016

# %%
# Create and train the regression model for time taken at each stage
stage_models = {}
for stage in stage_columns:
    stage_model = RandomForestRegressor(n_estimators=100, random_state=42)
    stage_model.fit(X_train, y_train_time[stage])
    stage_models[stage] = stage_model

# Predict time taken at each stage on the test set
y_pred_time = {}
for stage, stage_model in stage_models.items():
    y_pred_time[stage] = stage_model.predict(X_test)

# %%
# Assuming you have already converted 'actual_commencement_date' to a datetime object
# Calculate days elapsed for each project
current_date = datetime.now()
data['days_elapsed'] = (current_date - data['actual_commencement_date']).dt.days

# Define a function to determine the relevant stage and relevant columns for each project
def determine_relevant_stage_and_columns(row):
    days_elapsed = row['days_elapsed']
    total_days = 0
    relevant_stage = None
    relevant_columns = []

    for stage in stage_columns:
        stage_duration = row[stage]  # Days required for the current stage
        total_days += stage_duration
        if total_days >= days_elapsed:
            relevant_stage = stage
            relevant_columns = [stage for stage in stage_columns[stage_columns.index(stage):]]
            break

    return relevant_stage, relevant_columns, total_days

# Apply the function to create the 'relevant_stage' and 'relevant_columns' columns
data[['relevant_stage', 'relevant_columns', 'total_days']] = data.apply(determine_relevant_stage_and_columns, axis=1, result_type='expand')

# Filter projects based on current_stage
completed_projects = data[data['current_stage'] == 'completed']
running_projects = data[data['current_stage'] == 'running']
upcoming_projects = data[data['current_stage'] == 'upcoming']

# Define a function to make predictions based on the current stage
def make_predictions(row):
    if row['current_stage'] == 'completed':
        return None  # No predictions for completed projects
    elif row['current_stage'] == 'running':
        if row['relevant_stage'] is not None:
            if row['relevant_stage'] in row['relevant_columns']:
                return row[row['relevant_stage']] - (row['days_elapsed'] - row['total_days'])
            else:
                return None  # Skip stages before the relevant stage
        else:
            return None  # Skip predictions for running projects with no relevant stage
    elif row['current_stage'] == 'upcoming':
        return row['total_days']  # Include all stages for upcoming projects

# Apply the make_predictions function to create the 'predicted_time_taken' column
data['predicted_time_taken'] = data.apply(make_predictions, axis=1)

# %%
# Evaluate the models for time taken at each stage
mse_stage = {}
r2_stage = {}
for stage in stage_columns:
    mse_stage[stage] = mean_squared_error(y_test_time[stage], y_pred_time[stage])
    r2_stage[stage] = r2_score(y_test_time[stage], y_pred_time[stage])
    print(f'Mean Squared Error ({stage}): {mse_stage[stage]}')
    print(f'R-squared ({stage}): {r2_stage[stage]}')
# Out:
# Mean Squared Error (Cleaning & survey): 0.007466803389089968
# R-squared (Cleaning & survey): 0.9988667988734524
# Mean Squared Error (Excavation,leveling & P.C.C  for Basement  B1 ): 0.2510102994038726
# R-squared (Excavation,leveling & P.C.C  for Basement  B1 ): 0.9987852475898821
# Mean Squared Error ( Raft footing, Column B1, Retaining wall Reinforcement ,Concrete pouring ): 0.2782535001818472
# R-squared ( Raft footing, Column B1, Retaining wall Reinforcement ,Concrete pouring ): 0.9988269664947982
# Mean Squared Error (Slab of B (bottom) ): 0.07345495166265963
# R-squared (Slab of B (bottom) ): 0.9987613436041011
# Mean Squared Error ( Ground Floor slab casting ): 0.0945767997280797
# R-squared ( Ground Floor slab casting ): 0.9988924791918712
# Mean Squared Error ( 1st floor Columns casting): 0.0365064346554323
# R-squared ( 1st floor Columns casting): 0.9988552877237468
# Mean Squared Error ( 1st Floor slab casting): 0.11835531930768843
# R-squared ( 1st Floor slab casting): 0.9988773611160138
# Mean Squared Error (2nd floor Columns casting ): 0.0365064346554323
# R-squared (2nd floor Columns casting ): 0.9988552877237468
# Mean Squared Error (2nd Floor slab casting): 0.1354431352220851
# R-squared (2nd Floor slab casting): 0.9988347189093308
# Mean Squared Error ( Brick work at Basement to Ground Floor ): 0.1603627473380533
# R-squared ( Brick work at Basement to Ground Floor ): 0.9988498351096169
# Mean Squared Error (Electrical concealed, PVC Fitting, plastering at Basement): 0.07345495166265963
# R-squared (Electrical concealed, PVC Fitting, plastering at Basement): 0.9987613436041011
# Mean Squared Error (3rd floor Columns casting ): 0.045912934629760045
# R-squared (3rd floor Columns casting ): 0.9987902800277259
# Mean Squared Error (3rd Floor slab casting): 0.1490667019980288
# R-squared (3rd Floor slab casting): 0.9988314492679718
# Mean Squared Error ( Brick work at 1st Floor ): 0.029555622223863688
# R-squared ( Brick work at 1st Floor ): 0.9988786210559287
# Mean Squared Error (Electrical concealed, PVC Fitting, plastering at ground floor): 0.07867556008394343
# R-squared (Electrical concealed, PVC Fitting, plastering at ground floor): 0.9988339634379
# Mean Squared Error (4th floor Columns casting ): 0.045912934629760045
# R-squared (4th floor Columns casting ): 0.9987902800277259
# Mean Squared Error (4th Floor slab casting): 0.1354431352220851
# R-squared (4th Floor slab casting): 0.9988347189093308
# Mean Squared Error ( Brick work at 2nd Floor ): 0.0365064346554323
# R-squared ( Brick work at 2nd Floor ): 0.9988552877237468
# Mean Squared Error (Electrical concealed, PVC Fitting, plastering at 1st floor): 0.07867556008394343
# R-squared (Electrical concealed, PVC Fitting, plastering at 1st floor): 0.9988339634379
# Mean Squared Error (5th floor Columns casting ): 0.052818623973802235
# R-squared (5th floor Columns casting ): 0.9988141966619818
# Mean Squared Error (5th Floor slab casting): 0.1490667019980288
# R-squared (5th Floor slab casting): 0.9988314492679718
# Mean Squared Error ( Brick work at 3rd Floor ): 0.052818623973802235
# R-squared ( Brick work at 3rd Floor ): 0.9988141966619818
# Mean Squared Error (Electrical concealed, PVC Fitting, plastering at 2nd floor): 0.08622170732246921
# R-squared (Electrical concealed, PVC Fitting, plastering at 2nd floor): 0.9988680400379991
# Mean Squared Error (6th floor Columns casting ): 0.045912934629760045
# R-squared (6th floor Columns casting ): 0.9987902800277259
# Mean Squared Error (6th Floor slab casting): 0.1603627473380533
# R-squared (6th Floor slab casting): 0.9988498351096169
# Mean Squared Error ( Brick work at 4th Floor ): 0.052818623973802235
# R-squared ( Brick work at 4th Floor ): 0.9988141966619818
# Mean Squared Error (Electrical concealed, PVC Fitting, plastering at 3rd floor): 0.07867556008394343
# R-squared (Electrical concealed, PVC Fitting, plastering at 3rd floor): 0.9988339634379
# Mean Squared Error (7th floor Columns casting ): 0.052818623973802235
# R-squared (7th floor Columns casting ): 0.9988141966619818
# Mean Squared Error (7th Floor slab casting): 0.1490667019980288
# R-squared (7th Floor slab casting): 0.9988314492679718
# Mean Squared Error ( Brick work at 5th Floor ): 0.045912934629760045
# R-squared ( Brick work at 5th Floor ): 0.9987902800277259
# Mean Squared Error (Electrical concealed, PVC Fitting, plastering at 4th floor): 0.08622170732246921
# R-squared (Electrical concealed, PVC Fitting, plastering at 4th floor): 0.9988680400379991
# Mean Squared Error (8th floor Columns casting ): 0.052818623973802235
# R-squared (8th floor Columns casting ): 0.9988141966619818
# Mean Squared Error (8th Floor slab casting): 0.1603627473380533
# R-squared (8th Floor slab casting): 0.9988498351096169
# Mean Squared Error ( Brick work of 6th to 8th Floor ): 0.385405563798275
# R-squared ( Brick work of 6th to 8th Floor ): 0.9988063027823524
# Mean Squared Error (Electrical concealed, PVC Fitting, plastering at 5th-8th floor): 0.8796594685037105
# R-squared (Electrical concealed, PVC Fitting, plastering at 5th-8th floor): 0.9987657015465796
# Mean Squared Error (Plastering on outer sides): 1.1592547576374077
# R-squared (Plastering on outer sides): 0.9987782321957451
# Mean Squared Error (Tiles work): 2.459456600999212
# R-squared (Tiles work): 0.9988479629803197
# Mean Squared Error (Painting and Finishing): 2.459456600999212
# R-squared (Painting and Finishing): 0.9988479629803197
# Mean Squared Error (Plumbing & Sanitary,Electrification Works): 0.8822724560146296
# R-squared (Plumbing & Sanitary,Electrification Works): 0.9988934026333383
# Mean Squared Error (Doors & Windows Fixing Furniture work): 2.459456600999212
# R-squared (Doors & Windows Fixing Furniture work): 0.9988479629803197
# Mean Squared Error (other work): 0.2782535001818472
# R-squared (other work): 0.9988269664947982

# %%
# Load the new data (replace 'new_data.csv' with the actual file path)
new_data = pd.read_csv('new_8_test_file.csv')

# %%
# Converting date columns to datetime objeacts
new_data['actual_commencement_date'] = pd.to_datetime(new_data['actual_commencement_date'], errors='coerce')
new_data['estimated_finish_date'] = pd.to_datetime(new_data['estimated_finish_date'], errors='coerce')

# %%
current_date = datetime.now()

# %%
new_data['total_days'] = (new_data['estimated_finish_date'] - new_data['actual_commencement_date']).dt.days

# %%
new_data['duration_since_commencement'] = (current_date - new_data['actual_commencement_date']).dt.days
new_data['remaining_duration'] = (new_data['estimated_finish_date'] - current_date).dt.days
new_data['progress_ratio'] = new_data['duration_since_commencement'] / new_data['total_days']

# %%
# Define a function to determine the project status
def determine_status(row):
    if current_date > row['estimated_finish_date']:
        return 'completed'
    elif current_date >= row['actual_commencement_date']:
        return 'running'
    else:
        return 'upcoming'

# Apply the function to create the 'Status' column
new_data['current_stage'] = new_data.apply(determine_status, axis=1)

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 790 entries, 0 to 789
# Data columns (total 15 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   organisation_name                  790 non-null    object
#  1   project_category                   790 non-null    object
#  2   actual_commencement_date           790 non-null    datetime64[ns]
#  3   estimated_finish_date              790 non-null    datetime64[ns]
#  4   total_built_up_area_saleable_area  790 non-null    float64
#  5   total_area_of_project              790 non-null    float64
#  6   floor                              790 non-null    int64
#  7   project_state                      790 non-null    object
#  8   office_no                          790 non-null    float64
#  9   project_res_no                     790 non-null    object
#  10  total_days                         790 non-null    int64
#  11  duration_since_commencement        790 non-null    int64
#  12  remaining_duration                 790 non-null    int64
#  13  progress_ratio                     790 non-null    float64
#  14  current_stage                      790 non-null    object
# dtypes: datetime64[ns](2), float64(4), int64(4), object(5)
# memory usage: 92.7+ KB

# %%
# Performing label encoding on the 'current_stage' column
label_encoder = LabelEncoder()
new_data['current_stage'] =new_data['current_stage'].astype(str) # Converting to string to handle any NaN values left
new_data['current_stage_encoded'] = label_encoder.fit_transform(new_data['current_stage'])

# %%
# Performing label encoding on the 'current_stage' column
label_encoder = LabelEncoder()
new_data['project_state'] =new_data['project_state'].astype(str) # Converting to string to handle any NaN values left
new_data['project_state_encoded'] = label_encoder.fit_transform(new_data['project_state'])

# %%
new_data['office_no'] = new_data['office_no'].astype(str)

# %%
stage_columns = [ 'Cleaning & survey',
       'Excavation,leveling & P.C.C  for Basement  B1 ',
       ' Raft footing, Column B1, Retaining wall Reinforcement ,Concrete pouring ',
       'Slab of B (bottom) ', ' Ground Floor slab casting ',
       ' 1st floor Columns casting', ' 1st Floor slab casting',
       '2nd floor Columns casting ', '2nd Floor slab casting',
       ' Brick work at Basement to Ground Floor ',
       'Electrical concealed, PVC Fitting, plastering at Basement',
       '3rd floor Columns casting ', '3rd Floor slab casting',
       ' Brick work at 1st Floor ',
       'Electrical concealed, PVC Fitting, plastering at ground floor',
       '4th floor Columns casting ', '4th Floor slab casting',
       ' Brick work at 2nd Floor ',
       'Electrical concealed, PVC Fitting, plastering at 1st floor',
       '5th floor Columns casting ', '5th Floor slab casting',
       ' Brick work at 3rd Floor ',
       'Electrical concealed, PVC Fitting, plastering at 2nd floor',
       '6th floor Columns casting ', '6th Floor slab casting',
       ' Brick work at 4th Floor ',
       'Electrical concealed, PVC Fitting, plastering at 3rd floor',
       '7th floor Columns casting ', '7th Floor slab casting',
       ' Brick work at 5th Floor ',
       'Electrical concealed, PVC Fitting, plastering at 4th floor',
       '8th floor Columns casting ', '8th Floor slab casting',
       ' Brick work of 6th to 8th Floor ',
       'Electrical concealed, PVC Fitting, plastering at 5th-8th floor',
       'Plastering on outer sides', 'Tiles work', 'Painting and Finishing',
       'Plumbing & Sanitary,Electrification Works',
       'Doors & Windows Fixing Furniture work', 'other work']

# %%
# Create an empty DataFrame to store 'new_data' with added columns
new_data = new_data.copy()  # Assuming 'new_data' is your original DataFrame

# Add stage-related columns and 'total_days' column with NaN values
for stage in stage_columns:
    new_data[stage] = np.nan

new_data['total_days'] = np.nan

# Now, 'new_data_with_stages' contains the additional columns with NaN values

# %%
numerical_columns = new_data.select_dtypes(include=['int64', 'float64'])
stage_columns = [ 'Cleaning & survey',
       'Excavation,leveling & P.C.C  for Basement  B1 ',
       ' Raft footing, Column B1, Retaining wall Reinforcement ,Concrete pouring ',
       'Slab of B (bottom) ', ' Ground Floor slab casting ',
       ' 1st floor Columns casting', ' 1st Floor slab casting',
       '2nd floor Columns casting ', '2nd Floor slab casting',
       ' Brick work at Basement to Ground Floor ',
       'Electrical concealed, PVC Fitting, plastering at Basement',
       '3rd floor Columns casting ', '3rd Floor slab casting',
       ' Brick work at 1st Floor ',
       'Electrical concealed, PVC Fitting, plastering at ground floor',
       '4th floor Columns casting ', '4th Floor slab casting',
       ' Brick work at 2nd Floor ',
       'Electrical concealed, PVC Fitting, plastering at 1st floor',
       '5th floor Columns casting ', '5th Floor slab casting',
       ' Brick work at 3rd Floor ',
       'Electrical concealed, PVC Fitting, plastering at 2nd floor',
       '6th floor Columns casting ', '6th Floor slab casting',
       ' Brick work at 4th Floor ',
       'Electrical concealed, PVC Fitting, plastering at 3rd floor',
       '7th floor Columns casting ', '7th Floor slab casting',
       ' Brick work at 5th Floor ',
       'Electrical concealed, PVC Fitting, plastering at 4th floor',
       '8th floor Columns casting ', '8th Floor slab casting',
       ' Brick work of 6th to 8th Floor ',
       'Electrical concealed, PVC Fitting, plastering at 5th-8th floor',
       'Plastering on outer sides', 'Tiles work', 'Painting and Finishing',
       'Plumbing & Sanitary,Electrification Works',
       'Doors & Windows Fixing Furniture work', 'other work']
# Target variables
X_new = new_data[numerical_columns.columns.difference(stage_columns)].drop(columns='total_days')
#y_total_days = new_data['total_days']
#y_time_taken_at_each_stage = new_data[stage_columns]  # Replace with your actual stage columns

# %%
new_data['total_days'] = total_days_model.predict(new_data[X_new.columns])

for stage in stage_columns:
    stage_model = stage_models.get(stage)  # Use get to avoid KeyError
    if stage_model:
        new_data[stage] = stage_model.predict(new_data[X_new.columns])
    else:
        # If the stage column isn't in stage_models, fill it with NaN
        new_data[stage] = np.nan

# %%
stage_materials = {
    'Cleaning & survey': [],
    'Excavation,leveling & P.C.C  for Basement  B1 ': ['cement', 'sand', 'aggregates'],
    ' Raft footing, Column B1, Retaining wall Reinforcement ,Concrete pouring ': ['TMT bar', 'cement', 'sand', 'aggregates'],
    'Slab of B (bottom) ': ['TMT bar', 'cement', 'sand', 'aggregates'],
    ' Ground Floor slab casting ': ['TMT bar', 'cement', 'sand', 'aggregates'],
    ' 1st floor Columns casting': ['TMT bar', 'cement', 'sand', 'aggregates'],
    ' 1st Floor slab casting': ['TMT bar', 'cement', 'sand', 'aggregates'],
    '2nd floor Columns casting ': ['TMT bar', 'cement', 'sand', 'aggregates'],
    '2nd Floor slab casting': ['TMT bar', 'cement', 'sand', 'aggregates'],
    ' Brick work at Basement to Ground Floor ': ['blocks/bricks'],
    'Electrical concealed, PVC Fitting, plastering at Basement': ['circuit pipe', 'Cpvc', '&Pvc pipe'],
    '3rd floor Columns casting ': ['TMT bar', 'cement', 'sand', 'aggregates', 'cement', 'sand'],
    '3rd Floor slab casting': ['TMT bar', 'cement', 'sand', 'aggregates', 'cement', 'sand'],
    ' Brick work at 1st Floor ': ['blocks/bricks'],
    'Electrical concealed, PVC Fitting, plastering at ground floor': ['circuit pipe', 'Cpvc', '&Pvc pipe'],
    '4th floor Columns casting ': ['TMT bar', 'cement', 'sand', 'aggregates', 'cement', 'sand'],
    '4th Floor slab casting': ['TMT bar', 'cement', 'sand', 'aggregates', 'cement', 'sand'],
    ' Brick work at 2nd Floor ': ['blocks/bricks'],
    'Electrical concealed, PVC Fitting, plastering at 1st floor': ['circuit pipe', 'Cpvc', '&Pvc pipe'],
    '5th floor Columns casting ': ['TMT bar', 'cement', 'sand', 'aggregates', 'cement', 'sand'],
    '5th Floor slab casting': ['TMT bar', 'cement', 'sand', 'aggregates', 'cement', 'sand'],
    ' Brick work at 3rd Floor ': ['blocks/bricks'],
    'Electrical concealed, PVC Fitting, plastering at 2nd floor': ['circuit pipe', 'Cpvc', '&Pvc pipe'],
    '6th floor Columns casting ': ['TMT bar', 'cement', 'sand', 'aggregates', 'cement', 'sand'],
    '6th Floor slab casting': ['TMT bar', 'cement', 'sand', 'aggregates', 'cement', 'sand'],
    ' Brick work at 4th Floor ': ['blocks/bricks'],
    'Electrical concealed, PVC Fitting, plastering at 3rd floor': ['circuit pipe', 'Cpvc', '&Pvc pipe'],
    '7th floor Columns casting ': ['TMT bar', 'cement', 'sand', 'aggregates', 'cement', 'sand'],
    '7th Floor slab casting': [],
    ' Brick work at 5th Floor ': ['blocks/bricks'],
    'Electrical concealed, PVC Fitting, plastering at 4th floor': ['circuit pipe', 'Cpvc', '&Pvc pipe'],
    '8th floor Columns casting ': ['TMT bar', 'cement', 'sand', 'aggregates'],
    '8th Floor slab casting': [],
    ' Brick work of 6th to 8th Floor ': ['blocks/bricks'],
    'Electrical concealed, PVC Fitting, plastering at 5th-8th floor': ['circuit pipe', 'Cpvc', '&Pvc pipe'],
    'Plastering on outer sides': ['cement', 'sand'],
    'Tiles work': ['Tiles'],
    'Painting and Finishing': ['paint', 'putty', 'primer'],
    'Plumbing & Sanitary, Electrification Works': ['Wire', 'switch', 'nozzle Bib cock', 'shower', 'kitchen accessories', 'lights', 'fans', 'sheets', 'basin', 'sink', 'etc.'],
    'Doors & Windows Fixing Furniture work': ['Furniture', 'hardware', 'glass'],
    'other work': []
}

# %%
# Initialize empty lists to store relevant_stage and relevant_columns
relevant_stage_list = []
relevant_columns_list = []

# Iterate through each row (project) in new_data
for index, row in new_data.iterrows():
    days_elapsed = (current_date - row['actual_commencement_date']).days
    total_days = row['total_days']

    relevant_stage = None
    relevant_columns = []

    for stage in stage_columns:

        if total_days is None or np.isnan(total_days):
            # Set relevant_stage and relevant_columns to None if total_days is missing
            relevant_stage = None
            relevant_columns = []
            break

        stage_duration = row[stage]
        total_days -= stage_duration

        if total_days <= days_elapsed:
            relevant_stage = stage
            relevant_columns = [stage for stage in stage_columns[stage_columns.index(stage):]]
            break

    relevant_stage_list.append(relevant_stage)
    relevant_columns_list.append(relevant_columns)

    # Add the 'relevant_stage' and 'relevant_columns' columns to the new_data DataFrame
new_data['relevant_stage'] = relevant_stage_list
new_data['relevant_columns'] = relevant_columns_list

# %%
import pandas as pd
import numpy as np

# Initialize empty DataFrame to store adjusted days data
adjusted_days_data = pd.DataFrame(columns=stage_columns)

# Iterate through each row (project) in new_data
for index, row in new_data.iterrows():
    current_stage = row['current_stage']
    relevant_columns = row['relevant_columns']

    if current_stage == 'completed':
        # For completed projects, set 'days' to NaN for all stage columns
        days_values = [np.nan] * len(stage_columns)
    elif current_stage == 'running':
        # For running projects, update 'days' based on relevant_columns
        days_values = [row[stage] if stage in relevant_columns else np.nan for stage in stage_columns]
    elif current_stage == 'upcoming':
        # For upcoming projects, keep the predicted 'days' values
        days_values = [row[stage] for stage in stage_columns]

    # Append the days_values to the adjusted_days_data
    adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)

# Replace the original stage values in new_data with adjusted values
new_data[stage_columns] = adjusted_days_data
# Out:
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-103-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)

# %%
new_data
# Out:
#                          organisation_name           project_category  \
# 0               Shree Venkatesh Developers  Residential/Group Housing
# 1             SHREE SAI PRASAD ENTERPRISES  Residential/Group Housing
# 2                         Flying Earth LLP  Residential/Group Housing
# 3                     Vijay Nanakram Talda  Residential/Group Housing
# 4                    Mahesh Laxman Thakkar  Residential/Group Housing
# ..                                     ...                        ...
# 785  BHAWANI SHANKAR BUILDERS & DEVELOPERS  Residential/Group Housing
# 786                       JYOTI INDUSTRIES  Residential/Group Housing
# 787           Om Siddhivinayak Enterprises  Residential/Group Housing
# 788         NANIS BUILDCON PRIVATE LIMITED  Residential/Group Housing
# 789          RIYASAT ALI NIZAMUDDIN SHAIKH  Residential/Group Housing
#
#     actual_commencement_date estimated_finish_date  \
# 0                 2021-06-14            2023-12-31
# 1                 2021-09-09            2021-12-30
# 2                 2021-08-09            2023-06-30
# 3                 2021-08-09            2024-03-15
# 4                 2017-08-22            2018-08-22
# ..                       ...                   ...
# 785               2023-01-30            2029-12-31
# 786               2021-09-09            2024-12-30
# 787               2017-09-10            2019-03-31
# 788               2022-02-16            2026-06-30
# 789               2022-02-03            2028-12-31
#
#      total_built_up_area_saleable_area  total_area_of_project  floor  \
# 0                              1849.80                 637.31      8
# 1                               681.59                 638.00      8
# 2                              1229.00                 639.90      8
# 3                              1349.36                 640.57      8
# 4                              1732.36                 641.70      8
# ..                                 ...                    ...    ...
# 785                            3272.52                3000.00      8
# 786                            3585.66                3000.00      8
# 787                            5396.70                3000.00      8
# 788                            8391.42                3000.00      8
# 789                            1869.09                3002.33      8
#
#     project_state     office_no                        project_res_no  ...  \
# 0     MAHARASHTRA  9822649454.0               NASIK11S_AHMED1S_172000  ...
# 1     MAHARASHTRA  2812438207.0                        THANE12S_74000  ...
# 2     MAHARASHTRA  2226100796.0            Mumbai_Suburban_Two_484500  ...
# 3     MAHARASHTRA  9923636999.0      AHMED2S_AMra3s_AUR7S_TH1S_268500  ...
# 4     MAHARASHTRA  2228921755.0            Mumbai_Suburban_One_755500  ...
# ..            ...           ...                                   ...  ...
# 785   MAHARASHTRA  9112154050.0                   THANE7S_OMC4_316500  ...
# 786   MAHARASHTRA  9320805138.0                         THANE12S_4500  ...
# 787   MAHARASHTRA  2241270261.0                       THANE12S_281500  ...
# 788   MAHARASHTRA  7122243310.0  Nagpur5_Sangli_4s_Kohlapur_4s_108500  ...
# 789   MAHARASHTRA  2522222222.0                   THANE7S_OMC4_206000  ...
#
#       Brick work of 6th to 8th Floor   \
# 0                           31.055487
# 1                                 NaN
# 2                                 NaN
# 3                           31.817605
# 4                                 NaN
# ..                                ...
# 785                               NaN
# 786                         40.343511
# 787                               NaN
# 788                               NaN
# 789                               NaN
#
#      Electrical concealed, PVC Fitting, plastering at 5th-8th floor  \
# 0                                            46.137595
# 1                                                  NaN
# 2                                                  NaN
# 3                                            47.278817
# 4                                                  NaN
# ..                                                 ...
# 785                                                NaN
# 786                                          59.938931
# 787                                                NaN
# 788                                                NaN
# 789                                                NaN
#
#      Plastering on outer sides  Tiles work Painting and Finishing  \
# 0                    53.237977   79.874141              79.874141
# 1                          NaN         NaN                    NaN
# 2                          NaN         NaN                    NaN
# 3                    54.605153   81.879389              81.879389
# 4                          NaN         NaN                    NaN
# ..                         ...         ...                    ...
# 785                        NaN         NaN                    NaN
# 786                  69.160305  103.740458             103.740458
# 787                        NaN         NaN                    NaN
# 788                  90.411641  135.602863             135.602863
# 789                        NaN         NaN             216.653531
#
#      Plumbing & Sanitary,Electrification Works  \
# 0                                    48.803578
# 1                                          NaN
# 2                                          NaN
# 3                                    50.099857
# 4                                          NaN
# ..                                         ...
# 785                                        NaN
# 786                                  63.396947
# 787                                        NaN
# 788                                  82.946088
# 789                                 132.399380
#
#      Doors & Windows Fixing Furniture work  other work  \
# 0                                79.874141   26.620134
# 1                                      NaN         NaN
# 2                                      NaN         NaN
# 3                                81.879389   27.291698
# 4                                      NaN         NaN
# ..                                     ...         ...
# 785                             217.013359   72.337786
# 786                             103.740458   34.580153
# 787                                    NaN         NaN
# 788                             135.602863   45.255630
# 789                             216.653531   72.217844
#
#                                         relevant_stage  \
# 0                                  Slab of B (bottom)
# 1                                    Cleaning & survey
# 2                                    Cleaning & survey
# 3                               2nd Floor slab casting
# 4                                    Cleaning & survey
# ..                                                 ...
# 785              Doors & Windows Fixing Furniture work
# 786  Electrical concealed, PVC Fitting, plastering ...
# 787                                  Cleaning & survey
# 788                          Plastering on outer sides
# 789                             Painting and Finishing
#
#                                       relevant_columns
# 0    [Slab of B (bottom) ,  Ground Floor slab casti...
# 1    [Cleaning & survey, Excavation,leveling & P.C....
# 2    [Cleaning & survey, Excavation,leveling & P.C....
# 3    [2nd Floor slab casting,  Brick work at Baseme...
# 4    [Cleaning & survey, Excavation,leveling & P.C....
# ..                                                 ...
# 785  [Doors & Windows Fixing Furniture work, other ...
# 786  [Electrical concealed, PVC Fitting, plastering...
# 787  [Cleaning & survey, Excavation,leveling & P.C....
# 788  [Plastering on outer sides, Tiles work, Painti...
# 789  [Painting and Finishing, Plumbing & Sanitary,E...
#
# [790 rows x 60 columns]

# %%
# Define a function to print project details
def print_project_details(row, current_date):
    print(f'Organization Name: {row["organisation_name"]}')
    print(f'office_no	: {row["office_no"]}')
    print(f'project_res_no: {row["project_res_no"]}')
    print(f'Current Stage: {row["current_stage"]}')
    print(f'Total Days: {row["total_days"]}')
    print('Stage Details:')
    current_materials = []  # List to store materials for the current stage
    current_stage_start_date = current_date  # Initialize with the current date

    for stage in stage_columns:
        stage_duration = row[stage]

        if not pd.isna(stage_duration):
            # Calculate the stage end date
            stage_end_date = current_stage_start_date + pd.Timedelta(days=stage_duration)

            # Format the dates for display
            start_date_str = current_stage_start_date.strftime('%Y-%m-%d')
            end_date_str = stage_end_date.strftime('%Y-%m-%d')

            # Print the stage, days, and start and end dates
            print(f'{stage}: {stage_duration} days ({start_date_str} - {end_date_str})')

            # Update the start date for the next stage
            current_stage_start_date = stage_end_date

            # Check if there are materials for this stage
            materials = stage_materials.get(stage, [])

            if materials:
                # Display materials if available
                current_materials = materials

            if current_materials:
                # Print materials for the stage
                print(f'Materials: {", ".join(current_materials)}')

    print('-----------------')

# Iterate through each row (project) in the new_data DataFrame
for index, row in new_data.iterrows():
    # You need to pass the current date as an argument
    print_project_details(row, current_date)
# Out:
# Streaming output truncated to the last 5000 lines.
# project_res_no: Nagpur5_Sangli_4s_Kohlapur_4s_583500
# Current Stage: running
# Total Days: 1642.26
# Stage Details:
# 8th Floor slab casting: 35.971078244799955 days (2023-10-30 - 2023-12-05)
#  Brick work of 6th to 8th Floor : 54.8167461812 days (2023-12-05 - 2024-01-29)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 5th-8th floor: 81.39240458239998 days (2024-01-29 - 2024-04-19)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# Plastering on outer sides: 94.11984732680003 days (2024-04-19 - 2024-07-22)
# Materials: cement, sand
# Tiles work: 141.34637406600024 days (2024-07-22 - 2024-12-11)
# Materials: Tiles
# Painting and Finishing: 141.34637406600024 days (2024-12-11 - 2025-05-01)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 86.27022900580005 days (2025-05-01 - 2025-07-26)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 141.34637406600024 days (2025-07-26 - 2025-12-15)
# Materials: Furniture, hardware, glass
# other work: 46.96803435170004 days (2025-12-15 - 2026-01-31)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: SONY NOORIE REALITY
# office_no	: 2225350824.0
# project_res_no: THANE11S_313000
# Current Stage: completed
# Total Days: 131.0
# Stage Details:
# -----------------
# Organization Name: ROYAL FANTASY BUILDERS AND DEVELOPERS
# office_no	: 8411000094.0
# project_res_no: Jalga2s_Chand2s_Sola3_Sat6s_525500
# Current Stage: completed
# Total Days: 479.7
# Stage Details:
# -----------------
# Organization Name: Parth Developers
# office_no	: 2228751000.0
# project_res_no: Mumbai_Suburban_Two_170500
# Current Stage: completed
# Total Days: 354.99
# Stage Details:
# -----------------
# Organization Name: RSDevelopers
# office_no	: 2172313094.0
# project_res_no: Jalga2s_Chand2s_Sola3_Sat6s_302500
# Current Stage: completed
# Total Days: 202.0
# Stage Details:
# -----------------
# Organization Name: MEENAR ASSOCIATES
# office_no	: 2205552350.0
# project_res_no: THANE11S_287000
# Current Stage: completed
# Total Days: 302.37
# Stage Details:
# -----------------
# Organization Name: B M C Properties
# office_no	: 2027410154.0
# project_res_no: Pune_Six_613500
# Current Stage: running
# Total Days: 825.6
# Stage Details:
#  Brick work of 6th to 8th Floor : 27.53043893479995 days (2023-10-30 - 2023-11-27)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 5th-8th floor: 40.95793892940007 days (2023-11-27 - 2024-01-07)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# Plastering on outer sides: 47.16583969229993 days (2024-01-07 - 2024-02-23)
# Materials: cement, sand
# Tiles work: 70.90076335540014 days (2024-02-23 - 2024-05-04)
# Materials: Tiles
# Painting and Finishing: 70.90076335540014 days (2024-05-04 - 2024-07-13)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 43.328244277399925 days (2024-07-13 - 2024-08-26)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 70.90076335540014 days (2024-08-26 - 2024-11-05)
# Materials: Furniture, hardware, glass
# other work: 23.546851143999966 days (2024-11-05 - 2024-11-28)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: R S DEVELOPERS
# office_no	: 9881128915.0
# project_res_no: PUNE_One_484000
# Current Stage: running
# Total Days: 1238.63
# Stage Details:
#  Brick work at 3rd Floor : 15.374856871099983 days (2023-10-30 - 2023-11-14)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 2nd floor: 20.090009539300034 days (2023-11-14 - 2023-12-05)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 6th floor Columns casting : 14.183702289700015 days (2023-12-05 - 2023-12-19)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 6th Floor slab casting: 27.192891218700048 days (2023-12-19 - 2024-01-15)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 4th Floor : 15.374856871099983 days (2024-01-15 - 2024-01-30)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 3rd floor: 18.913282439799968 days (2024-01-30 - 2024-02-18)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 7th floor Columns casting : 15.374856871099983 days (2024-02-18 - 2024-03-05)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 7th Floor slab casting: 26.017099232699998 days (2024-03-05 - 2024-03-31)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 5th Floor : 14.183702289700015 days (2024-03-31 - 2024-04-14)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 4th floor: 20.090009539300034 days (2024-04-14 - 2024-05-04)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 8th floor Columns casting : 15.374856871099983 days (2024-05-04 - 2024-05-19)
# Materials: TMT bar, cement, sand, aggregates
# 8th Floor slab casting: 27.192891218700048 days (2024-05-19 - 2024-06-15)
# Materials: TMT bar, cement, sand, aggregates
#  Brick work of 6th to 8th Floor : 41.36979961540007 days (2024-06-15 - 2024-07-27)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 5th-8th floor: 61.47412214009995 days (2024-07-27 - 2024-09-26)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# Plastering on outer sides: 70.95687022630003 days (2024-09-26 - 2024-12-06)
# Materials: cement, sand
# Tiles work: 106.43358782199994 days (2024-12-06 - 2025-03-23)
# Materials: Tiles
# Painting and Finishing: 106.43358782199994 days (2025-03-23 - 2025-07-07)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 65.03120228879995 days (2025-07-07 - 2025-09-10)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 106.43358782199994 days (2025-09-10 - 2025-12-26)
# Materials: Furniture, hardware, glass
# other work: 35.45696564700001 days (2025-12-26 - 2026-01-30)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: Nine Construction
# office_no	: 9967436299.0
# project_res_no: Palghar_Two_69500
# Current Stage: completed
# Total Days: 867.0
# Stage Details:
# -----------------
# Organization Name: ASHWINI AJIT KARANDIKAR
# office_no	: 2221636722.0
# project_res_no: Mumbai_Suburban_One_603000
# Current Stage: completed
# Total Days: 959.71
# Stage Details:
# -----------------
# Organization Name: Shree Sadguru Builders
# office_no	: 2143254499.0
# project_res_no: RAIGARH_Two_308000
# Current Stage: running
# Total Days: 1163.0
# Stage Details:
# 5th Floor slab casting: 24.414122140000014 days (2023-10-30 - 2023-11-23)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 3rd Floor : 14.42652672000002 days (2023-11-23 - 2023-12-08)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 2nd floor: 18.865458020000002 days (2023-12-08 - 2023-12-27)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 6th floor Columns casting : 13.314961829000016 days (2023-12-27 - 2024-01-09)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 6th Floor slab casting: 25.523854960000016 days (2024-01-09 - 2024-02-04)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 4th Floor : 14.42652672000002 days (2024-02-04 - 2024-02-18)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 3rd floor: 17.755725190000017 days (2024-02-18 - 2024-03-07)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 7th floor Columns casting : 14.42652672000002 days (2024-03-07 - 2024-03-21)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 7th Floor slab casting: 24.414122140000014 days (2024-03-21 - 2024-04-15)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 5th Floor : 13.314961829000016 days (2024-04-15 - 2024-04-28)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 4th floor: 18.865458020000002 days (2024-04-28 - 2024-05-17)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 8th floor Columns casting : 14.42652672000002 days (2024-05-17 - 2024-05-31)
# Materials: TMT bar, cement, sand, aggregates
# 8th Floor slab casting: 25.523854960000016 days (2024-05-31 - 2024-06-26)
# Materials: TMT bar, cement, sand, aggregates
#  Brick work of 6th to 8th Floor : 38.83530533859998 days (2024-06-26 - 2024-08-04)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 5th-8th floor: 57.70610687000012 days (2024-08-04 - 2024-09-30)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# Plastering on outer sides: 66.58396946999989 days (2024-09-30 - 2024-12-06)
# Materials: cement, sand
# Tiles work: 99.8759542 days (2024-12-06 - 2025-03-16)
# Materials: Tiles
# Painting and Finishing: 99.8759542 days (2025-03-16 - 2025-06-24)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 61.035305340000086 days (2025-06-24 - 2025-08-24)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 99.8759542 days (2025-08-24 - 2025-12-02)
# Materials: Furniture, hardware, glass
# other work: 33.291984729999974 days (2025-12-02 - 2026-01-04)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: Shilp Vihar CO OP Housing Society Ltd
# office_no	: 9604694644.0
# project_res_no: Sindh3s_Wardha2s_NASIK8S_977500
# Current Stage: running
# Total Days: 1427.4
# Stage Details:
# Electrical concealed, PVC Fitting, plastering at 3rd floor: 21.79786259770001 days (2023-10-30 - 2023-11-21)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 7th floor Columns casting : 17.712624047800038 days (2023-11-21 - 2023-12-09)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 7th Floor slab casting: 29.97730916339996 days (2023-12-09 - 2024-01-08)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 5th Floor : 16.350114505699967 days (2024-01-08 - 2024-01-24)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 4th floor: 23.16250000250001 days (2024-01-24 - 2024-02-16)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 8th floor Columns casting : 17.712624047800038 days (2024-02-16 - 2024-03-05)
# Materials: TMT bar, cement, sand, aggregates
# 8th Floor slab casting: 31.322576339000044 days (2024-03-05 - 2024-04-05)
# Materials: TMT bar, cement, sand, aggregates
#  Brick work of 6th to 8th Floor : 47.69351144599994 days (2024-04-05 - 2024-05-23)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 5th-8th floor: 70.8375954180001 days (2024-05-23 - 2024-08-02)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# Plastering on outer sides: 81.71908396859986 days (2024-08-02 - 2024-10-22)
# Materials: cement, sand
# Tiles work: 122.63444657700025 days (2024-10-22 - 2025-02-22)
# Materials: Tiles
# Painting and Finishing: 122.63444657700025 days (2025-02-22 - 2025-06-25)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 74.9532442734001 days (2025-06-25 - 2025-09-08)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 122.63444657700025 days (2025-09-08 - 2026-01-08)
# Materials: Furniture, hardware, glass
# other work: 40.855820615099944 days (2026-01-08 - 2026-02-18)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: SWAMI CONSTRUCTIONS
# office_no	: 2532310351.0
# project_res_no: NASIK11S_AHMED1S_187000
# Current Stage: running
# Total Days: 873.88
# Stage Details:
# Slab of B (bottom) : 12.5006679411 days (2023-10-30 - 2023-11-12)
# Materials: TMT bar, cement, sand, aggregates
#  Ground Floor slab casting : 15.012824428199984 days (2023-11-12 - 2023-11-27)
# Materials: TMT bar, cement, sand, aggregates
#  1st floor Columns casting: 9.174503816860003 days (2023-11-27 - 2023-12-06)
# Materials: TMT bar, cement, sand, aggregates
#  1st Floor slab casting: 16.66049618019998 days (2023-12-06 - 2023-12-22)
# Materials: TMT bar, cement, sand, aggregates
# 2nd floor Columns casting : 9.174503816860003 days (2023-12-22 - 2024-01-01)
# Materials: TMT bar, cement, sand, aggregates
# 2nd Floor slab casting: 17.505143129199972 days (2024-01-01 - 2024-01-18)
# Materials: TMT bar, cement, sand, aggregates
#  Brick work at Basement to Ground Floor : 19.165057256800015 days (2024-01-18 - 2024-02-06)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at Basement: 12.5006679411 days (2024-02-06 - 2024-02-19)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 3rd floor Columns casting : 10.007633587619983 days (2024-02-19 - 2024-02-29)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 3rd Floor slab casting: 18.34480916209999 days (2024-02-29 - 2024-03-18)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 1st Floor : 8.33616412237002 days (2024-03-18 - 2024-03-26)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at ground floor: 13.337862590699997 days (2024-03-26 - 2024-04-09)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 4th floor Columns casting : 10.007633587619983 days (2024-04-09 - 2024-04-19)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 4th Floor slab casting: 17.505143129199972 days (2024-04-19 - 2024-05-06)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 2nd Floor : 9.174503816860003 days (2024-05-06 - 2024-05-15)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 1st floor: 13.337862590699997 days (2024-05-15 - 2024-05-29)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 5th floor Columns casting : 10.837509538900017 days (2024-05-29 - 2024-06-09)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 5th Floor slab casting: 18.34480916209999 days (2024-06-09 - 2024-06-27)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 3rd Floor : 10.837509538900017 days (2024-06-27 - 2024-07-08)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 2nd floor: 14.172127860899966 days (2024-07-08 - 2024-07-22)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 6th floor Columns casting : 10.007633587619983 days (2024-07-22 - 2024-08-01)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 6th Floor slab casting: 19.165057256800015 days (2024-08-01 - 2024-08-20)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 4th Floor : 10.837509538900017 days (2024-08-20 - 2024-08-31)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 3rd floor: 13.337862590699997 days (2024-08-31 - 2024-09-13)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 7th floor Columns casting : 10.837509538900017 days (2024-09-13 - 2024-09-24)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 7th Floor slab casting: 18.34480916209999 days (2024-09-24 - 2024-10-13)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 5th Floor : 10.007633587619983 days (2024-10-13 - 2024-10-23)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 4th floor: 14.172127860899966 days (2024-10-23 - 2024-11-06)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 8th floor Columns casting : 10.837509538900017 days (2024-11-06 - 2024-11-17)
# Materials: TMT bar, cement, sand, aggregates
# 8th Floor slab casting: 19.165057256800015 days (2024-11-17 - 2024-12-06)
# Materials: TMT bar, cement, sand, aggregates
#  Brick work of 6th to 8th Floor : 29.19026717429996 days (2024-12-06 - 2025-01-04)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 5th-8th floor: 43.32770992080003 days (2025-01-04 - 2025-02-16)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# Plastering on outer sides: 49.98606870190009 days (2025-02-16 - 2025-04-07)
# Materials: cement, sand
# Tiles work: 75.0220419888001 days (2025-04-07 - 2025-06-21)
# Materials: Tiles
# Painting and Finishing: 75.0220419888001 days (2025-06-21 - 2025-09-04)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 45.83158396519994 days (2025-09-04 - 2025-10-20)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 75.0220419888001 days (2025-10-20 - 2026-01-03)
# Materials: Furniture, hardware, glass
# other work: 25.009637409100005 days (2026-01-03 - 2026-01-28)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: RIYAZ ACHHAN KHAN
# office_no	: 2225925515.0
# project_res_no: THANE11S_343000
# Current Stage: completed
# Total Days: 496.0
# Stage Details:
# -----------------
# Organization Name: AV AFFORDABLE HOUSING LLP
# office_no	: 2506058585.0
# project_res_no: Palghar_One_885500
# Current Stage: completed
# Total Days: 567.0
# Stage Details:
# -----------------
# Organization Name: SAFA ENTERPRISES
# office_no	: 2226518591.0
# project_res_no: THANE12S_166500
# Current Stage: running
# Total Days: 1571.42
# Stage Details:
# 8th Floor slab casting: 34.50724236169996 days (2023-10-30 - 2023-12-04)
#  Brick work of 6th to 8th Floor : 52.469942751199866 days (2023-12-04 - 2024-01-25)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 5th-8th floor: 77.99255725130007 days (2024-01-25 - 2024-04-12)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# Plastering on outer sides: 90.00286259699992 days (2024-04-12 - 2024-07-11)
# Materials: cement, sand
# Tiles work: 135.0042939300003 days (2024-07-11 - 2024-11-23)
# Materials: Tiles
# Painting and Finishing: 135.0042939300003 days (2024-11-23 - 2025-04-07)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 82.48478053809987 days (2025-04-07 - 2025-06-29)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 135.0042939300003 days (2025-06-29 - 2025-11-11)
# Materials: Furniture, hardware, glass
# other work: 45.00400762939996 days (2025-11-11 - 2025-12-26)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: SHREE AMBESH CONSTRUCTION
# office_no	: 2228046567.0
# project_res_no: THANE11S_569500
# Current Stage: completed
# Total Days: 1056.91
# Stage Details:
# -----------------
# Organization Name: RAJENDRA SUKHADEV MIRGANE
# office_no	: 2184222080.0
# project_res_no: Jalga2s_Chand2s_Sola3_Sat6s_326500
# Current Stage: completed
# Total Days: 659.0
# Stage Details:
# -----------------
# Organization Name: CHANDIWALA ENTERPRISES
# office_no	: 2226288813.0
# project_res_no: Mumbai_Suburban_Three_106000
# Current Stage: completed
# Total Days: 385.9
# Stage Details:
# -----------------
# Organization Name: Newstar Builders
# office_no	: 8698440022.0
# project_res_no: Palghar_One_60500
# Current Stage: completed
# Total Days: 571.08
# Stage Details:
# -----------------
# Organization Name: MAYUR TANAJI BELDARE
# office_no	: 2024362240.0
# project_res_no: PUNE_Four_4500
# Current Stage: completed
# Total Days: 1148.0
# Stage Details:
# -----------------
# Organization Name: MAA KRUPA BUILDCON
# office_no	: 2532123456.0
# project_res_no: NASIK11S_AHMED1S_23500
# Current Stage: running
# Total Days: 786.13
# Stage Details:
#  Ground Floor slab casting : 13.505667941400004 days (2023-10-30 - 2023-11-13)
# Materials: TMT bar, cement, sand, aggregates
#  1st floor Columns casting: 8.25178435133001 days (2023-11-13 - 2023-11-21)
# Materials: TMT bar, cement, sand, aggregates
#  1st Floor slab casting: 15.00687022849997 days (2023-11-21 - 2023-12-06)
# Materials: TMT bar, cement, sand, aggregates
# 2nd floor Columns casting : 8.25178435133001 days (2023-12-06 - 2023-12-14)
# Materials: TMT bar, cement, sand, aggregates
# 2nd Floor slab casting: 15.752805341800022 days (2023-12-14 - 2023-12-30)
# Materials: TMT bar, cement, sand, aggregates
#  Brick work at Basement to Ground Floor : 17.255925576999992 days (2023-12-30 - 2024-01-16)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at Basement: 11.24627862330001 days (2024-01-16 - 2024-01-27)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 3rd floor Columns casting : 9.009961831749989 days (2024-01-27 - 2024-02-05)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 3rd Floor slab casting: 16.510916027300013 days (2024-02-05 - 2024-02-22)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 1st Floor : 7.505534350909985 days (2024-02-22 - 2024-02-29)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at ground floor: 11.9981679354 days (2024-02-29 - 2024-03-12)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 4th floor Columns casting : 9.009961831749989 days (2024-03-12 - 2024-03-21)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 4th Floor slab casting: 15.752805341800022 days (2024-03-21 - 2024-04-06)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 2nd Floor : 8.25178435133001 days (2024-04-06 - 2024-04-14)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 1st floor: 11.9981679354 days (2024-04-14 - 2024-04-26)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 5th floor Columns casting : 9.749379771150018 days (2024-04-26 - 2024-05-06)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 5th Floor slab casting: 16.510916027300013 days (2024-05-06 - 2024-05-23)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 3rd Floor : 9.749379771150018 days (2024-05-23 - 2024-06-01)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 2nd floor: 12.750000003599984 days (2024-06-01 - 2024-06-14)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 6th floor Columns casting : 9.009961831749989 days (2024-06-14 - 2024-06-23)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 6th Floor slab casting: 17.255925576999992 days (2024-06-23 - 2024-07-10)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 4th Floor : 9.749379771150018 days (2024-07-10 - 2024-07-20)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 3rd floor: 11.9981679354 days (2024-07-20 - 2024-08-01)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 7th floor Columns casting : 9.749379771150018 days (2024-08-01 - 2024-08-11)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 7th Floor slab casting: 16.510916027300013 days (2024-08-11 - 2024-08-27)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 5th Floor : 9.009961831749989 days (2024-08-27 - 2024-09-05)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 4th floor: 12.750000003599984 days (2024-09-05 - 2024-09-18)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 8th floor Columns casting : 9.749379771150018 days (2024-09-18 - 2024-09-28)
# Materials: TMT bar, cement, sand, aggregates
# 8th Floor slab casting: 17.255925576999992 days (2024-09-28 - 2024-10-15)
# Materials: TMT bar, cement, sand, aggregates
#  Brick work of 6th to 8th Floor : 26.263024805999958 days (2024-10-15 - 2024-11-10)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 5th-8th floor: 38.993549618900076 days (2024-11-10 - 2024-12-19)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# Plastering on outer sides: 45.013167937599974 days (2024-12-19 - 2025-02-02)
# Materials: cement, sand
# Tiles work: 67.50000000259985 days (2025-02-02 - 2025-04-11)
# Materials: Tiles
# Painting and Finishing: 67.50000000259985 days (2025-04-11 - 2025-06-17)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 41.27886450029993 days (2025-06-17 - 2025-07-29)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 67.50000000259985 days (2025-07-29 - 2025-10-04)
# Materials: Furniture, hardware, glass
# other work: 22.500000003899967 days (2025-10-04 - 2025-10-27)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: Vaibhav Realtors
# office_no	: 9324460355.0
# project_res_no: Mumbai_Suburban_Two_445500
# Current Stage: running
# Total Days: 873.96
# Stage Details:
# Slab of B (bottom) : 12.501240460200002 days (2023-10-30 - 2023-11-12)
# Materials: TMT bar, cement, sand, aggregates
#  Ground Floor slab casting : 15.012824428199984 days (2023-11-12 - 2023-11-27)
# Materials: TMT bar, cement, sand, aggregates
#  1st floor Columns casting: 9.174923664190002 days (2023-11-27 - 2023-12-06)
# Materials: TMT bar, cement, sand, aggregates
#  1st Floor slab casting: 16.66202289759998 days (2023-12-06 - 2023-12-22)
# Materials: TMT bar, cement, sand, aggregates
# 2nd floor Columns casting : 9.174923664190002 days (2023-12-22 - 2024-01-01)
# Materials: TMT bar, cement, sand, aggregates
# 2nd Floor slab casting: 17.505944655899974 days (2024-01-01 - 2024-01-18)
# Materials: TMT bar, cement, sand, aggregates
#  Brick work at Basement to Ground Floor : 19.167690844600017 days (2024-01-18 - 2024-02-06)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at Basement: 12.501240460200002 days (2024-02-06 - 2024-02-19)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 3rd floor Columns casting : 10.008091602889982 days (2024-02-19 - 2024-02-29)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 3rd Floor slab casting: 18.34648855149999 days (2024-02-29 - 2024-03-18)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 1st Floor : 8.33692748115002 days (2024-03-18 - 2024-03-26)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at ground floor: 13.339083964699993 days (2024-03-26 - 2024-04-09)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 4th floor Columns casting : 10.008091602889982 days (2024-04-09 - 2024-04-19)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 4th Floor slab casting: 17.505944655899974 days (2024-04-19 - 2024-05-06)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 2nd Floor : 9.174923664190002 days (2024-05-06 - 2024-05-15)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 1st floor: 13.339083964699993 days (2024-05-15 - 2024-05-29)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 5th floor Columns casting : 10.838501905300017 days (2024-05-29 - 2024-06-09)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 5th Floor slab casting: 18.34648855149999 days (2024-06-09 - 2024-06-27)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 3rd Floor : 10.838501905300017 days (2024-06-27 - 2024-07-08)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 2nd floor: 14.172776715799964 days (2024-07-08 - 2024-07-22)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 6th floor Columns casting : 10.008091602889982 days (2024-07-22 - 2024-08-01)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 6th Floor slab casting: 19.167690844600017 days (2024-08-01 - 2024-08-20)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 4th Floor : 10.838501905300017 days (2024-08-20 - 2024-08-31)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 3rd floor: 13.339083964699993 days (2024-08-31 - 2024-09-13)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 7th floor Columns casting : 10.838501905300017 days (2024-09-13 - 2024-09-24)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 7th Floor slab casting: 18.34648855149999 days (2024-09-24 - 2024-10-13)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 5th Floor : 10.008091602889982 days (2024-10-13 - 2024-10-23)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 4th floor: 14.172776715799964 days (2024-10-23 - 2024-11-06)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 8th floor Columns casting : 10.838501905300017 days (2024-11-06 - 2024-11-17)
# Materials: TMT bar, cement, sand, aggregates
# 8th Floor slab casting: 19.167690844600017 days (2024-11-17 - 2024-12-06)
# Materials: TMT bar, cement, sand, aggregates
#  Brick work of 6th to 8th Floor : 29.19293893009996 days (2024-12-06 - 2025-01-04)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 5th-8th floor: 43.329694653600036 days (2025-01-04 - 2025-02-16)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# Plastering on outer sides: 49.98606870190009 days (2025-02-16 - 2025-04-07)
# Materials: cement, sand
# Tiles work: 75.0254771033001 days (2025-04-07 - 2025-06-21)
# Materials: Tiles
# Painting and Finishing: 75.0254771033001 days (2025-06-21 - 2025-09-04)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 45.83578243839994 days (2025-09-04 - 2025-10-20)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 75.0254771033001 days (2025-10-20 - 2026-01-03)
# Materials: Furniture, hardware, glass
# other work: 25.010782447300002 days (2026-01-03 - 2026-01-28)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: Shashwat Homes
# office_no	: 2512600000.0
# project_res_no: THANE11S_850000
# Current Stage: completed
# Total Days: 202.0
# Stage Details:
# -----------------
# Organization Name: R K Lunkad Housing corporation
# office_no	: 1046703400.0
# project_res_no: PUNE_Five_464000
# Current Stage: completed
# Total Days: 623.0
# Stage Details:
# -----------------
# Organization Name: Charms Corporation
# office_no	: 2225381934.0
# project_res_no: THANE11S_120000
# Current Stage: completed
# Total Days: 1574.0
# Stage Details:
# -----------------
# Organization Name: GURUDATTA DEVELOPERS
# office_no	: 9021205389.0
# project_res_no: PUNE_Three_393500
# Current Stage: running
# Total Days: 873.96
# Stage Details:
# Slab of B (bottom) : 12.501526719700003 days (2023-10-30 - 2023-11-12)
# Materials: TMT bar, cement, sand, aggregates
#  Ground Floor slab casting : 15.012824428199984 days (2023-11-12 - 2023-11-27)
# Materials: TMT bar, cement, sand, aggregates
#  1st floor Columns casting: 9.175133587850002 days (2023-11-27 - 2023-12-06)
# Materials: TMT bar, cement, sand, aggregates
#  1st Floor slab casting: 16.66240457699998 days (2023-12-06 - 2023-12-22)
# Materials: TMT bar, cement, sand, aggregates
# 2nd floor Columns casting : 9.175133587850002 days (2023-12-22 - 2024-01-01)
# Materials: TMT bar, cement, sand, aggregates
# 2nd Floor slab casting: 17.506345419299972 days (2024-01-01 - 2024-01-18)
# Materials: TMT bar, cement, sand, aggregates
#  Brick work at Basement to Ground Floor : 19.167690844600017 days (2024-01-18 - 2024-02-06)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at Basement: 12.501526719700003 days (2024-02-06 - 2024-02-19)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 3rd floor Columns casting : 10.008091602889982 days (2024-02-19 - 2024-02-29)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 3rd Floor slab casting: 18.34690839879999 days (2024-02-29 - 2024-03-18)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 1st Floor : 8.33692748115002 days (2024-03-18 - 2024-03-26)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at ground floor: 13.339389308299994 days (2024-03-26 - 2024-04-09)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 4th floor Columns casting : 10.008091602889982 days (2024-04-09 - 2024-04-19)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 4th Floor slab casting: 17.506345419299972 days (2024-04-19 - 2024-05-06)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 2nd Floor : 9.175133587850002 days (2024-05-06 - 2024-05-15)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 1st floor: 13.339389308299994 days (2024-05-15 - 2024-05-29)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 5th floor Columns casting : 10.838501905300017 days (2024-05-29 - 2024-06-09)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 5th Floor slab casting: 18.34690839879999 days (2024-06-09 - 2024-06-27)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 3rd Floor : 10.838501905300017 days (2024-06-27 - 2024-07-08)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 2nd floor: 14.172776715799964 days (2024-07-08 - 2024-07-22)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 6th floor Columns casting : 10.008091602889982 days (2024-07-22 - 2024-08-01)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 6th Floor slab casting: 19.167690844600017 days (2024-08-01 - 2024-08-20)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 4th Floor : 10.838501905300017 days (2024-08-20 - 2024-08-31)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 3rd floor: 13.339389308299994 days (2024-08-31 - 2024-09-13)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 7th floor Columns casting : 10.838501905300017 days (2024-09-13 - 2024-09-24)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 7th Floor slab casting: 18.34690839879999 days (2024-09-24 - 2024-10-13)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 5th Floor : 10.008091602889982 days (2024-10-13 - 2024-10-23)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 4th floor: 14.172776715799964 days (2024-10-23 - 2024-11-06)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 8th floor Columns casting : 10.838501905300017 days (2024-11-06 - 2024-11-17)
# Materials: TMT bar, cement, sand, aggregates
# 8th Floor slab casting: 19.167690844600017 days (2024-11-17 - 2024-12-06)
# Materials: TMT bar, cement, sand, aggregates
#  Brick work of 6th to 8th Floor : 29.19293893009996 days (2024-12-06 - 2025-01-04)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 5th-8th floor: 43.33068702000004 days (2025-01-04 - 2025-02-16)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# Plastering on outer sides: 49.98606870190009 days (2025-02-16 - 2025-04-07)
# Materials: cement, sand
# Tiles work: 75.0271946605001 days (2025-04-07 - 2025-06-21)
# Materials: Tiles
# Painting and Finishing: 75.0271946605001 days (2025-06-21 - 2025-09-04)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 45.83683205679994 days (2025-09-04 - 2025-10-20)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 75.0271946605001 days (2025-10-20 - 2026-01-03)
# Materials: Furniture, hardware, glass
# other work: 25.011354966300004 days (2026-01-03 - 2026-01-28)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: LUIZA HOMES
# office_no	: 2502333067.0
# project_res_no: Palghar_One_84500
# Current Stage: completed
# Total Days: 864.05
# Stage Details:
# -----------------
# Organization Name: SHRI SWAMI SAMARTH DEVELOPERS
# office_no	: 2029516775.0
# project_res_no: PUNE_Two_275500
# Current Stage: running
# Total Days: 1030.4
# Stage Details:
# 6th Floor slab casting: 22.609351143000023 days (2023-10-30 - 2023-11-22)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 4th Floor : 12.779198475999975 days (2023-11-22 - 2023-12-04)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 3rd floor: 15.728244275100026 days (2023-12-04 - 2023-12-20)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 7th floor Columns casting : 12.779198475999975 days (2023-12-20 - 2024-01-02)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 7th Floor slab casting: 21.626335873299983 days (2024-01-02 - 2024-01-24)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 5th Floor : 11.796183206300011 days (2024-01-24 - 2024-02-04)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 4th floor: 16.71125954480002 days (2024-02-04 - 2024-02-21)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 8th floor Columns casting : 12.779198475999975 days (2024-02-21 - 2024-03-05)
# Materials: TMT bar, cement, sand, aggregates
# 8th Floor slab casting: 22.609351143000023 days (2024-03-05 - 2024-03-27)
# Materials: TMT bar, cement, sand, aggregates
#  Brick work of 6th to 8th Floor : 34.405534349299984 days (2024-03-27 - 2024-05-01)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 5th-8th floor: 51.116793894099935 days (2024-05-01 - 2024-06-21)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# Plastering on outer sides: 58.98091603169992 days (2024-06-21 - 2024-08-19)
# Materials: cement, sand
# Tiles work: 88.47137404260002 days (2024-08-19 - 2024-11-15)
# Materials: Tiles
# Painting and Finishing: 88.47137404260002 days (2024-11-15 - 2025-02-12)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 54.06583969320004 days (2025-02-12 - 2025-04-07)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 88.47137404260002 days (2025-04-07 - 2025-07-04)
# Materials: Furniture, hardware, glass
# other work: 29.496183201799987 days (2025-07-04 - 2025-08-03)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: PRKRITI SPACE LLP
# office_no	: 2029700294.0
# project_res_no: PUNE_Three_336000
# Current Stage: completed
# Total Days: 1362.04
# Stage Details:
# -----------------
# Organization Name: SANGITA Last Name SINGH
# office_no	: 2227742003.0
# project_res_no: THANE11S_806500
# Current Stage: completed
# Total Days: 212.0
# Stage Details:
# -----------------
# Organization Name: SIDDHIVINAYAK BUILDCON
# office_no	: 2532397473.0
# project_res_no: Sindh3s_Wardha2s_NASIK8S_713000
# Current Stage: running
# Total Days: 1283.1
# Stage Details:
# 5th Floor slab casting: 26.95293892799997 days (2023-10-30 - 2023-11-26)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 3rd Floor : 15.926736645100034 days (2023-11-26 - 2023-12-12)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 2nd floor: 20.827270987599974 days (2023-12-12 - 2024-01-02)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 6th floor Columns casting : 14.701603057000009 days (2024-01-02 - 2024-01-16)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 6th Floor slab casting: 28.159637401599962 days (2024-01-16 - 2024-02-14)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 4th Floor : 15.926736645100034 days (2024-02-14 - 2024-03-01)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 3rd floor: 19.58931298179998 days (2024-03-01 - 2024-03-20)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 7th floor Columns casting : 15.926736645100034 days (2024-03-20 - 2024-04-05)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 7th Floor slab casting: 26.95293892799997 days (2024-04-05 - 2024-05-02)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 5th Floor : 14.701603057000009 days (2024-05-02 - 2024-05-17)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 4th floor: 20.827270987599974 days (2024-05-17 - 2024-06-07)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 8th floor Columns casting : 15.926736645100034 days (2024-06-07 - 2024-06-22)
# Materials: TMT bar, cement, sand, aggregates
# 8th Floor slab casting: 28.159637401599962 days (2024-06-22 - 2024-07-21)
# Materials: TMT bar, cement, sand, aggregates
#  Brick work of 6th to 8th Floor : 42.87967557320002 days (2024-07-21 - 2024-09-01)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 5th-8th floor: 63.66526717159995 days (2024-09-01 - 2024-11-04)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# Plastering on outer sides: 73.50801526549985 days (2024-11-04 - 2025-01-17)
# Materials: cement, sand
# Tiles work: 110.18988552399998 days (2025-01-17 - 2025-05-07)
# Materials: Tiles
# Painting and Finishing: 110.18988552399998 days (2025-05-07 - 2025-08-25)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 67.33826335559986 days (2025-08-25 - 2025-10-31)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 110.18988552399998 days (2025-10-31 - 2026-02-19)
# Materials: Furniture, hardware, glass
# other work: 36.75400763269992 days (2026-02-19 - 2026-03-27)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: SIDDHIVINAYAK BUILDPRO PRIVATE LIMITED
# office_no	: 9730969494.0
# project_res_no: Jalga2s_Chand2s_Sola3_Sat6s_812500
# Current Stage: running
# Total Days: 1547.18
# Stage Details:
# Painting and Finishing: 132.75944652300015 days (2023-10-30 - 2024-03-11)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 81.04785305110009 days (2024-03-11 - 2024-05-31)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 132.75944652300015 days (2024-05-31 - 2024-10-11)
# Materials: Furniture, hardware, glass
# other work: 44.3241412225 days (2024-10-11 - 2024-11-24)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: NEELKANTH CONSTRUCTIONS
# office_no	: 8080257175.0
# project_res_no: RAIGARH_One_527000
# Current Stage: completed
# Total Days: 459.3
# Stage Details:
# -----------------
# Organization Name: SHASHWAT HOMES
# office_no	: 9011563545.0
# project_res_no: THANE11S_288500
# Current Stage: completed
# Total Days: 234.6
# Stage Details:
# -----------------
# Organization Name: KAMBAR RESIDENCES
# office_no	: 9004444700.0
# project_res_no: THANE11S_49000
# Current Stage: completed
# Total Days: 205.99
# Stage Details:
# -----------------
# Organization Name: VAISHNAVI DEVELOPERS
# office_no	: 9371024340.0
# project_res_no: PUNE_Five_706500
# Current Stage: running
# Total Days: 874.38
# Stage Details:
# Slab of B (bottom) : 12.506965650200005 days (2023-10-30 - 2023-11-12)
# Materials: TMT bar, cement, sand, aggregates
#  Ground Floor slab casting : 15.01969465619999 days (2023-11-12 - 2023-11-27)
# Materials: TMT bar, cement, sand, aggregates
#  1st floor Columns casting: 9.179332061050001 days (2023-11-27 - 2023-12-06)
# Materials: TMT bar, cement, sand, aggregates
#  1st Floor slab casting: 16.67003816499998 days (2023-12-06 - 2023-12-22)
# Materials: TMT bar, cement, sand, aggregates
# 2nd floor Columns casting : 9.179332061050001 days (2023-12-22 - 2024-01-01)
# Materials: TMT bar, cement, sand, aggregates
# 2nd Floor slab casting: 17.51476145069998 days (2024-01-01 - 2024-01-18)
# Materials: TMT bar, cement, sand, aggregates
#  Brick work at Basement to Ground Floor : 19.176908399800013 days (2024-01-18 - 2024-02-06)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at Basement: 12.506965650200005 days (2024-02-06 - 2024-02-19)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 3rd floor Columns casting : 10.012900763329984 days (2024-02-19 - 2024-02-29)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 3rd Floor slab casting: 18.355725192099985 days (2024-02-29 - 2024-03-18)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 1st Floor : 8.340744274950014 days (2024-03-18 - 2024-03-26)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at ground floor: 13.34549618029999 days (2024-03-26 - 2024-04-09)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 4th floor Columns casting : 10.012900763329984 days (2024-04-09 - 2024-04-19)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 4th Floor slab casting: 17.51476145069998 days (2024-04-19 - 2024-05-06)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 2nd Floor : 9.179332061050001 days (2024-05-06 - 2024-05-16)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 1st floor: 13.34549618029999 days (2024-05-16 - 2024-05-29)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 5th floor Columns casting : 10.843711828900016 days (2024-05-29 - 2024-06-09)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 5th Floor slab casting: 18.355725192099985 days (2024-06-09 - 2024-06-27)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 3rd Floor : 10.843711828900016 days (2024-06-27 - 2024-07-08)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 2nd floor: 14.179265265799973 days (2024-07-08 - 2024-07-22)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 6th floor Columns casting : 10.012900763329984 days (2024-07-22 - 2024-08-01)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 6th Floor slab casting: 19.176908399800013 days (2024-08-01 - 2024-08-20)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 4th Floor : 10.843711828900016 days (2024-08-20 - 2024-08-31)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 3rd floor: 13.34549618029999 days (2024-08-31 - 2024-09-13)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 7th floor Columns casting : 10.843711828900016 days (2024-09-13 - 2024-09-24)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 7th Floor slab casting: 18.355725192099985 days (2024-09-24 - 2024-10-13)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 5th Floor : 10.012900763329984 days (2024-10-13 - 2024-10-23)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 4th floor: 14.179265265799973 days (2024-10-23 - 2024-11-06)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 8th floor Columns casting : 10.843711828900016 days (2024-11-06 - 2024-11-17)
# Materials: TMT bar, cement, sand, aggregates
# 8th Floor slab casting: 19.176908399800013 days (2024-11-17 - 2024-12-06)
# Materials: TMT bar, cement, sand, aggregates
#  Brick work of 6th to 8th Floor : 29.206297708099974 days (2024-12-06 - 2025-01-04)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 5th-8th floor: 43.34954198160005 days (2025-01-04 - 2025-02-16)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# Plastering on outer sides: 50.00896946590007 days (2025-02-16 - 2025-04-07)
# Materials: cement, sand
# Tiles work: 75.0615458045001 days (2025-04-07 - 2025-06-22)
# Materials: Tiles
# Painting and Finishing: 75.0615458045001 days (2025-06-22 - 2025-09-05)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 45.85782442479996 days (2025-09-05 - 2025-10-20)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 75.0615458045001 days (2025-10-20 - 2026-01-04)
# Materials: Furniture, hardware, glass
# other work: 25.02223282730001 days (2026-01-04 - 2026-01-29)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: DESAI CONSTRUCTIONS
# office_no	: 2221631513.0
# project_res_no: THANE12S_866500
# Current Stage: completed
# Total Days: 134.0
# Stage Details:
# -----------------
# Organization Name: M/S KALPSUTRA BUILDCON
# office_no	: 9029788348.0
# project_res_no: RAIGARH_Two_257500
# Current Stage: running
# Total Days: 768.78
# Stage Details:
#  Ground Floor slab casting : 13.204236644000014 days (2023-10-30 - 2023-11-12)
# Materials: TMT bar, cement, sand, aggregates
#  1st floor Columns casting: 8.07156488500001 days (2023-11-12 - 2023-11-20)
# Materials: TMT bar, cement, sand, aggregates
#  1st Floor slab casting: 14.675572520000001 days (2023-11-20 - 2023-12-05)
# Materials: TMT bar, cement, sand, aggregates
# 2nd floor Columns casting : 8.07156488500001 days (2023-12-05 - 2023-12-13)
# Materials: TMT bar, cement, sand, aggregates
# 2nd Floor slab casting: 15.409351150000015 days (2023-12-13 - 2023-12-28)
# Materials: TMT bar, cement, sand, aggregates
#  Brick work at Basement to Ground Floor : 16.876908400000033 days (2023-12-28 - 2024-01-14)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at Basement: 11.003530535000017 days (2024-01-14 - 2024-01-25)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 3rd floor Columns casting : 8.805343511000016 days (2024-01-25 - 2024-02-03)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 3rd Floor slab casting: 16.14312977000002 days (2024-02-03 - 2024-02-19)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 1st Floor : 7.337786260000001 days (2024-02-19 - 2024-02-27)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at ground floor: 11.737099241300005 days (2024-02-27 - 2024-03-09)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 4th floor Columns casting : 8.805343511000016 days (2024-03-09 - 2024-03-18)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 4th Floor slab casting: 15.409351150000015 days (2024-03-18 - 2024-04-03)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 2nd Floor : 8.07156488500001 days (2024-04-03 - 2024-04-11)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 1st floor: 11.737099241300005 days (2024-04-11 - 2024-04-22)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 5th floor Columns casting : 9.53912213700002 days (2024-04-22 - 2024-05-02)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 5th Floor slab casting: 16.14312977000002 days (2024-05-02 - 2024-05-18)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 3rd Floor : 9.53912213700002 days (2024-05-18 - 2024-05-28)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 2nd floor: 12.4706679377 days (2024-05-28 - 2024-06-09)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 6th floor Columns casting : 8.805343511000016 days (2024-06-09 - 2024-06-18)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 6th Floor slab casting: 16.876908400000033 days (2024-06-18 - 2024-07-05)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 4th Floor : 9.53912213700002 days (2024-07-05 - 2024-07-14)
# Materials: blocks/bricks
# ...
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 5th-8th floor: 83.67187023149998 days (2024-01-31 - 2024-04-24)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# Plastering on outer sides: 96.62290076189994 days (2024-04-24 - 2024-07-30)
# Materials: cement, sand
# Tiles work: 144.94208016499985 days (2024-07-30 - 2024-12-22)
# Materials: Tiles
# Painting and Finishing: 144.94208016499985 days (2024-12-22 - 2025-05-16)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 88.59933206290006 days (2025-05-16 - 2025-08-12)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 144.94208016499985 days (2025-08-12 - 2026-01-04)
# Materials: Furniture, hardware, glass
# other work: 48.35238549499998 days (2026-01-04 - 2026-02-21)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: ASHIRWAD DEVELOPERS
# office_no	: 2225403333.0
# project_res_no: THANE11S_179500
# Current Stage: completed
# Total Days: 611.0
# Stage Details:
# -----------------
# Organization Name: SHIVTEJ BUILDCON
# office_no	: 9870590644.0
# project_res_no: THANE12S_516000
# Current Stage: running
# Total Days: 1142.54
# Stage Details:
# Electrical concealed, PVC Fitting, plastering at 1st floor: 17.43770992579997 days (2023-10-30 - 2023-11-16)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 5th floor Columns casting : 14.182280538699999 days (2023-11-16 - 2023-12-01)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 5th Floor slab casting: 24.006450380900027 days (2023-12-01 - 2023-12-25)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 3rd Floor : 14.182280538699999 days (2023-12-25 - 2024-01-08)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 2nd floor: 18.544761446799985 days (2024-01-08 - 2024-01-26)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 6th floor Columns casting : 13.090305345199988 days (2024-01-26 - 2024-02-08)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 6th Floor slab casting: 25.080095420799967 days (2024-02-08 - 2024-03-05)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 4th Floor : 14.182280538699999 days (2024-03-05 - 2024-03-19)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 3rd floor: 17.43770992579997 days (2024-03-19 - 2024-04-05)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 7th floor Columns casting : 14.182280538699999 days (2024-04-05 - 2024-04-19)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 7th Floor slab casting: 24.006450380900027 days (2024-04-19 - 2024-05-13)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 5th Floor : 13.090305345199988 days (2024-05-13 - 2024-05-26)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 4th floor: 18.544761446799985 days (2024-05-26 - 2024-06-14)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 8th floor Columns casting : 14.182280538699999 days (2024-06-14 - 2024-06-28)
# Materials: TMT bar, cement, sand, aggregates
# 8th Floor slab casting: 25.080095420799967 days (2024-06-28 - 2024-07-23)
# Materials: TMT bar, cement, sand, aggregates
#  Brick work of 6th to 8th Floor : 38.15768130050005 days (2024-07-23 - 2024-08-30)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 5th-8th floor: 56.718702289099994 days (2024-08-30 - 2024-10-26)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# Plastering on outer sides: 65.4738549623001 days (2024-10-26 - 2024-12-31)
# Materials: cement, sand
# Tiles work: 98.1257633586999 days (2024-12-31 - 2025-04-08)
# Materials: Tiles
# Painting and Finishing: 98.1257633586999 days (2025-04-08 - 2025-07-15)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 60.02662213510009 days (2025-07-15 - 2025-09-13)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 98.1257633586999 days (2025-09-13 - 2025-12-20)
# Materials: Furniture, hardware, glass
# other work: 32.691984732700035 days (2025-12-20 - 2026-01-22)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: MR. ANIL RAMKRISHNA BHAMBERE AND MRS. VIDYA ANIL BHAMBERE
# office_no	: 9545042176.0
# project_res_no: NASIK11S_AHMED1S_39500
# Current Stage: running
# Total Days: 2014.0
# Stage Details:
# Electrical concealed, PVC Fitting, plastering at 5th-8th floor: 99.9312977099999 days (2023-10-30 - 2024-02-07)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# Plastering on outer sides: 115.30534350000012 days (2024-02-07 - 2024-06-01)
# Materials: cement, sand
# Tiles work: 172.9580153000002 days (2024-06-01 - 2024-11-21)
# Materials: Tiles
# Painting and Finishing: 172.9580153000002 days (2024-11-21 - 2025-05-13)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 105.69656489999997 days (2025-05-13 - 2025-08-27)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 172.9580153000002 days (2025-08-27 - 2026-02-16)
# Materials: Furniture, hardware, glass
# other work: 57.65267175999998 days (2026-02-16 - 2026-04-14)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: RAVI AAKAR GROUP OF CONSTRUCTION
# office_no	: 2532311648.0
# project_res_no: Sindh3s_Wardha2s_NASIK8S_455000
# Current Stage: running
# Total Days: 1238.57
# Stage Details:
#  Brick work at 3rd Floor : 15.372872138199982 days (2023-10-30 - 2023-11-14)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 2nd floor: 20.087414119500032 days (2023-11-14 - 2023-12-04)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 6th floor Columns casting : 14.183816793500014 days (2023-12-04 - 2023-12-19)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 6th Floor slab casting: 27.183454195800053 days (2023-12-19 - 2024-01-15)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 4th Floor : 15.372872138199982 days (2024-01-15 - 2024-01-30)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 3rd floor: 18.913435111499965 days (2024-01-30 - 2024-02-18)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 7th floor Columns casting : 15.372872138199982 days (2024-02-18 - 2024-03-05)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 7th Floor slab casting: 26.013950377899995 days (2024-03-05 - 2024-03-31)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 5th Floor : 14.183816793500014 days (2024-03-31 - 2024-04-14)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 4th floor: 20.087414119500032 days (2024-04-14 - 2024-05-04)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 8th floor Columns casting : 15.372872138199982 days (2024-05-04 - 2024-05-19)
# Materials: TMT bar, cement, sand, aggregates
# 8th Floor slab casting: 27.183454195800053 days (2024-05-19 - 2024-06-15)
# Materials: TMT bar, cement, sand, aggregates
#  Brick work of 6th to 8th Floor : 41.370801523800075 days (2024-06-15 - 2024-07-27)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 5th-8th floor: 61.45973282709995 days (2024-07-27 - 2024-09-26)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# Plastering on outer sides: 70.93454198220003 days (2024-09-26 - 2024-12-06)
# Materials: cement, sand
# Tiles work: 106.40438934899993 days (2024-12-06 - 2025-03-23)
# Materials: Tiles
# Painting and Finishing: 106.40438934899993 days (2025-03-23 - 2025-07-07)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 65.00181297579995 days (2025-07-07 - 2025-09-10)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 106.40438934899993 days (2025-09-10 - 2025-12-25)
# Materials: Furniture, hardware, glass
# other work: 35.45696564690001 days (2025-12-25 - 2026-01-30)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: TEJRAJ INFRA LLP
# office_no	: 2025511601.0
# project_res_no: PUNE_Two_23000
# Current Stage: running
# Total Days: 1055.33
# Stage Details:
# Electrical concealed, PVC Fitting, plastering at ground floor: 16.111603048899987 days (2023-10-30 - 2023-11-15)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 4th floor Columns casting : 12.083931294300001 days (2023-11-15 - 2023-11-27)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 4th Floor slab casting: 21.146479004199968 days (2023-11-27 - 2023-12-18)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 2nd Floor : 11.076937027100021 days (2023-12-18 - 2023-12-29)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 1st floor: 16.111603048899987 days (2023-12-29 - 2024-01-15)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 5th floor Columns casting : 13.090925571400003 days (2024-01-15 - 2024-01-28)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 5th Floor slab casting: 22.153874044600013 days (2024-01-28 - 2024-02-19)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 3rd Floor : 13.090925571400003 days (2024-02-19 - 2024-03-03)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 2nd floor: 17.118902669500002 days (2024-03-03 - 2024-03-20)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 6th floor Columns casting : 12.083931294300001 days (2024-03-20 - 2024-04-01)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 6th Floor slab casting: 23.160429390200015 days (2024-04-01 - 2024-04-24)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 4th Floor : 13.090925571400003 days (2024-04-24 - 2024-05-07)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 3rd floor: 16.111603048899987 days (2024-05-07 - 2024-05-23)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 7th floor Columns casting : 13.090925571400003 days (2024-05-23 - 2024-06-06)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 7th Floor slab casting: 22.153874044600013 days (2024-06-06 - 2024-06-28)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 5th Floor : 12.083931294300001 days (2024-06-28 - 2024-07-10)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 4th floor: 17.118902669500002 days (2024-07-10 - 2024-07-27)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 8th floor Columns casting : 13.090925571400003 days (2024-07-27 - 2024-08-09)
# Materials: TMT bar, cement, sand, aggregates
# 8th Floor slab casting: 23.160429390200015 days (2024-08-09 - 2024-09-01)
# Materials: TMT bar, cement, sand, aggregates
#  Brick work of 6th to 8th Floor : 35.24413167689995 days (2024-09-01 - 2024-10-06)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 5th-8th floor: 52.36618320140002 days (2024-10-06 - 2024-11-28)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# Plastering on outer sides: 60.41965649130002 days (2024-11-28 - 2025-01-27)
# Materials: cement, sand
# Tiles work: 90.62948473209984 days (2025-01-27 - 2025-04-28)
# Materials: Tiles
# Painting and Finishing: 90.62948473209984 days (2025-04-28 - 2025-07-27)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 55.3836354979 days (2025-07-27 - 2025-09-21)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 90.62948473209984 days (2025-09-21 - 2025-12-20)
# Materials: Furniture, hardware, glass
# other work: 30.211259538400032 days (2025-12-20 - 2026-01-20)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: SHRIKRISHNA ENTERPRISES
# office_no	: 9890555464.0
# project_res_no: THANE12S_518500
# Current Stage: completed
# Total Days: 627.8
# Stage Details:
# -----------------
# Organization Name: BHAWANI SHANKAR BUILDERS & DEVELOPERS
# office_no	: 9112154050.0
# project_res_no: THANE7S_OMC4_316500
# Current Stage: running
# Total Days: 2527.0
# Stage Details:
# Doors & Windows Fixing Furniture work: 217.01335880000002 days (2023-10-30 - 2024-06-03)
# Materials: Furniture, hardware, glass
# other work: 72.33778626000002 days (2024-06-03 - 2024-08-14)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: JYOTI INDUSTRIES
# office_no	: 9320805138.0
# project_res_no: THANE12S_4500
# Current Stage: running
# Total Days: 1208.0
# Stage Details:
# Electrical concealed, PVC Fitting, plastering at 2nd floor: 19.59541985000004 days (2023-10-30 - 2023-11-19)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 6th floor Columns casting : 13.832061070000007 days (2023-11-19 - 2023-12-02)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 6th Floor slab casting: 26.51145038000003 days (2023-12-02 - 2023-12-29)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 4th Floor : 14.984732820000017 days (2023-12-29 - 2024-01-13)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 3rd floor: 18.442748089999956 days (2024-01-13 - 2024-01-31)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 7th floor Columns casting : 14.984732820000017 days (2024-01-31 - 2024-02-15)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
# 7th Floor slab casting: 25.35877862999997 days (2024-02-15 - 2024-03-12)
# Materials: TMT bar, cement, sand, aggregates, cement, sand
#  Brick work at 5th Floor : 13.832061070000007 days (2024-03-12 - 2024-03-26)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 4th floor: 19.59541985000004 days (2024-03-26 - 2024-04-14)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# 8th floor Columns casting : 14.984732820000017 days (2024-04-14 - 2024-04-29)
# Materials: TMT bar, cement, sand, aggregates
# 8th Floor slab casting: 26.51145038000003 days (2024-04-29 - 2024-05-26)
# Materials: TMT bar, cement, sand, aggregates
#  Brick work of 6th to 8th Floor : 40.34351144999993 days (2024-05-26 - 2024-07-05)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 5th-8th floor: 59.938931300000085 days (2024-07-05 - 2024-09-03)
# Materials: circuit pipe, Cpvc, &Pvc pipe
# Plastering on outer sides: 69.16030534000011 days (2024-09-03 - 2024-11-11)
# Materials: cement, sand
# Tiles work: 103.74045800000016 days (2024-11-11 - 2025-02-23)
# Materials: Tiles
# Painting and Finishing: 103.74045800000016 days (2025-02-23 - 2025-06-07)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 63.39694656000006 days (2025-06-07 - 2025-08-09)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 103.74045800000016 days (2025-08-09 - 2025-11-21)
# Materials: Furniture, hardware, glass
# other work: 34.58015267000006 days (2025-11-21 - 2025-12-25)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: Om Siddhivinayak Enterprises
# office_no	: 2241270261.0
# project_res_no: THANE12S_281500
# Current Stage: completed
# Total Days: 567.62
# Stage Details:
# -----------------
# Organization Name: NANIS BUILDCON PRIVATE LIMITED
# office_no	: 7122243310.0
# project_res_no: Nagpur5_Sangli_4s_Kohlapur_4s_108500
# Current Stage: running
# Total Days: 1579.78
# Stage Details:
# Plastering on outer sides: 90.41164121839991 days (2023-10-30 - 2024-01-28)
# Materials: cement, sand
# Tiles work: 135.60286255899987 days (2024-01-28 - 2024-06-12)
# Materials: Tiles
# Painting and Finishing: 135.60286255899987 days (2024-06-12 - 2024-10-26)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 82.94608778730004 days (2024-10-26 - 2025-01-17)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 135.60286255899987 days (2025-01-17 - 2025-06-01)
# Materials: Furniture, hardware, glass
# other work: 45.25562977419989 days (2025-06-01 - 2025-07-16)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: RIYASAT ALI NIZAMUDDIN SHAIKH
# office_no	: 2522222222.0
# project_res_no: THANE7S_OMC4_206000
# Current Stage: running
# Total Days: 2522.62
# Stage Details:
# Painting and Finishing: 216.65353050599973 days (2023-10-30 - 2024-06-03)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 132.39937972599972 days (2024-06-03 - 2024-10-13)
# Materials: paint, putty, primer
# Doors & Windows Fixing Furniture work: 216.65353050599973 days (2024-10-13 - 2025-05-18)
# Materials: Furniture, hardware, glass
# other work: 72.21784350869989 days (2025-05-18 - 2025-07-29)
# Materials: Furniture, hardware, glass
# -----------------

# %%
import pandas as pd

# Create a list to store the data
data = []

# Iterate through each row (project) in the new_data DataFrame
for index, row in new_data.iterrows():
    current_materials = []  # List to store materials for the current stage
    current_stage_start_date = current_date  # Initialize with the current date
    project_id = f'Project_{index + 1}'  # Generate a project_id

    for stage in stage_columns:
        stage_duration = row[stage]

        if not pd.isna(stage_duration):
            # Calculate the stage end date
            stage_end_date = current_stage_start_date + pd.Timedelta(days=stage_duration)

            # Format the dates for display
            start_date_str = current_stage_start_date.strftime('%m/%d/%Y')
            end_date_str = stage_end_date.strftime('%m/%d/%Y')

            # Check if there are materials for this stage
            materials = stage_materials.get(stage, [])

            if materials:
                # Store the data in the desired format
                data.append([end_date_str, stage, ", ".join(materials), project_id, row['organisation_name'], row['office_no'], row['project_res_no']])

            # Update the start date for the next stage
            current_stage_start_date = stage_end_date

# Create a DataFrame from the data
output_data = pd.DataFrame(data, columns=['Date', 'Stage', 'Recommended Materials', 'Project_ID', 'organisation_name', 'office_no', 'project_res_no'])

# Save the DataFrame to a CSV file
output_data.to_csv('output_8_final.csv', index=False)
