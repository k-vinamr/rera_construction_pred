# %% [markdown]
# <a href="https://colab.research.google.com/github/k-vinamr/rera_construction_pred/blob/main/5_floor_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display
import statsmodels as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.model_selection import train_test_split,GridSearchCV,RandomizedSearchCV
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor
from sklearn.metrics import r2_score,mean_squared_error
from sklearn import preprocessing
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from datetime import datetime
# Load your dataset
data = pd.read_csv('augmented_5_floor.csv')

# %%
data
# Out:
#                     organisation_name           project_category  \
# 0          SHREE VRUNDAVAN DEVELOPERS  Residential/Group Housing
# 1      SHASHIKALA RAMCHANDRA SALUNKHE  Residential/Group Housing
# 2                NEELKANTH ASSOCIATES  Residential/Group Housing
# 3             BALASAHEB SHANKAR SUTAR  Residential/Group Housing
# 4        Varad Builders and Promoters  Residential/Group Housing
# ...                               ...                        ...
# 19995            SARANG VALLABH BAGLA  Residential/Group Housing
# 19996                  ADITI BUILDCON  Residential/Group Housing
# 19997                   CRYSTAL HOMES  Residential/Group Housing
# 19998                Panorama Heights  Residential/Group Housing
# 19999                JYOTI DEVELOPERS  Residential/Group Housing
#
#       actual_commencement_date estimated_finish_date  \
# 0                   2017-08-31            2017-12-01
# 1                   2021-09-09            2021-12-15
# 2                   2021-09-09            2021-12-15
# 3                   2020-05-23            2020-08-30
# 4                   2021-09-09            2021-12-20
# ...                        ...                   ...
# 19995               2021-08-11            2022-12-27
# 19996               2021-09-04            2023-03-28
# 19997               2021-08-03            2024-06-29
# 19998               2020-05-13            2021-07-03
# 19999               2021-08-04            2023-07-04
#
#        total_built_up_area_saleable_area  total_area_of_project  floor  \
# 0                             779.260000             557.310000      5
# 1                             714.200000             511.500000      5
# 2                            1366.200000             683.100000      5
# 3                             403.090000             336.000000      5
# 4                             690.000000             575.000000      5
# ...                                  ...                    ...    ...
# 19995                        1003.138381             564.130349      5
# 19996                        6244.525348            5990.672079      5
# 19997                         402.260317             898.603681      5
# 19998                         687.958154             522.410163      5
# 19999                         716.884248             477.663933      5
#
#       project_state  total_days  Cleaning & survey  ...  \
# 0       MAHARASHTRA          92           0.596628  ...
# 1       MAHARASHTRA          97           0.629053  ...
# 2       MAHARASHTRA          97           0.629053  ...
# 3       MAHARASHTRA          99           0.642023  ...
# 4       MAHARASHTRA         102           0.661479  ...
# ...             ...         ...                ...  ...
# 19995   MAHARASHTRA         508           3.294423  ...
# 19996   MAHARASHTRA         567           3.677043  ...
# 19997   MAHARASHTRA        1056           6.848249  ...
# 19998   MAHARASHTRA         408           2.645914  ...
# 19999   MAHARASHTRA         690           4.474708  ...
#
#        Plastering on outer sides  Tiles work  Painting and Finishing  \
# 0                       8.949416    7.159533                9.546044
# 1                       9.435798    7.548638               10.064851
# 2                       9.435798    7.548638               10.064851
# 3                       9.630350    7.704280               10.272374
# 4                       9.922179    7.937743               10.583658
# ...                          ...         ...                     ...
# 19995                  49.416342   39.533074               52.710765
# 19996                  55.155642   44.124514               58.832685
# 19997                 102.723735   82.178988              109.571984
# 19998                  39.688716   31.750973               42.334630
# 19999                  67.120623   53.696498               71.595331
#
#        Plumbing & Sanitary,Electrification Works  \
# 0                                       5.369650
# 1                                       5.661479
# 2                                       5.661479
# 3                                       5.778210
# 4                                       5.953307
# ...                                          ...
# 19995                                  29.649805
# 19996                                  33.093385
# 19997                                  61.634241
# 19998                                  23.813230
# 19999                                  40.272374
#
#        Doors & Windows Fixing Furniture work  duration_since_commencement  \
# 0                                   8.352789                         2251
# 1                                   8.806744                          781
# 2                                   8.806744                          781
# 3                                   8.988327                         1255
# 4                                   9.260700                          781
# ...                                      ...                          ...
# 19995                              46.121920                          812
# 19996                              51.478599                          781
# 19997                              95.875486                          812
# 19998                              37.042802                         1260
# 19999                              62.645914                          812
#
#        remaining_duration  progress_ratio  current_stage      area_bin
# 0                   -2160       24.467391      completed   (500, 1000]
# 1                    -685        8.051546      completed   (500, 1000]
# 2                    -685        8.051546      completed  (1000, 1500]
# 3                   -1157       12.676768      completed      (0, 500]
# 4                    -680        7.656863      completed   (500, 1000]
# ...                   ...             ...            ...           ...
# 19995                -305        1.598425      completed  (1000, 1500]
# 19996                -215        1.377425      completed  (6000, 6500]
# 19997                 243        0.768939        running      (0, 500]
# 19998                -853        3.088235      completed   (500, 1000]
# 19999                -123        1.176812      completed   (500, 1000]
#
# [20000 rows x 41 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 41 columns):
#  #   Column                                                                     Non-Null Count  Dtype
# ---  ------                                                                     --------------  -----
#  0   organisation_name                                                          20000 non-null  object
#  1   project_category                                                           20000 non-null  object
#  2   actual_commencement_date                                                   20000 non-null  object
#  3   estimated_finish_date                                                      20000 non-null  object
#  4   total_built_up_area_saleable_area                                          20000 non-null  float64
#  5   total_area_of_project                                                      20000 non-null  float64
#  6   floor                                                                      20000 non-null  int64
#  7   project_state                                                              20000 non-null  object
#  8   total_days                                                                 20000 non-null  int64
#  9   Cleaning & survey                                                          20000 non-null  float64
#  10  Excavation,leveling & P.C.C  for Basement  B1                              20000 non-null  float64
#  11   Raft footing, Column B1, Retaining wall Reinforcement ,Concrete pouring   20000 non-null  float64
#  12  Slab of B (bottom)                                                         20000 non-null  float64
#  13   Ground Floor slab casting                                                 20000 non-null  float64
#  14   1st floor Columns casting                                                 20000 non-null  float64
#  15   1st Floor slab casting                                                    20000 non-null  float64
#  16  2nd floor Columns casting                                                  20000 non-null  float64
#  17  2nd Floor slab casting                                                     20000 non-null  float64
#  18   Brick work at Basement to Ground Floor                                    20000 non-null  float64
#  19  3rd floor Columns casting                                                  20000 non-null  float64
#  20  3rd Floor slab casting                                                     20000 non-null  float64
#  21   Brick work at 1st Floor                                                   20000 non-null  float64
#  22  Electrical concealed, PVC Fitting, plastering at basement- ground floor    20000 non-null  float64
#  23  4th floor Columns casting                                                  20000 non-null  float64
#  24  4th Floor slab casting                                                     20000 non-null  float64
#  25   Brick work at 2nd Floor                                                   20000 non-null  float64
#  26  Electrical concealed, PVC Fitting, plastering at 1st floor                 20000 non-null  float64
#  27  5th floor Columns casting                                                  20000 non-null  float64
#  28  5th Floor slab casting                                                     20000 non-null  float64
#  29   Brick work of 3rd to 5th Floor                                            20000 non-null  float64
#  30  Electrical concealed, PVC Fitting, plastering at 2nd-5th floor             20000 non-null  float64
#  31  Plastering on outer sides                                                  20000 non-null  float64
#  32  Tiles work                                                                 20000 non-null  float64
#  33  Painting and Finishing                                                     20000 non-null  float64
#  34  Plumbing & Sanitary,Electrification Works                                  20000 non-null  float64
#  35  Doors & Windows Fixing Furniture work                                      20000 non-null  float64
#  36  duration_since_commencement                                                20000 non-null  int64
#  37  remaining_duration                                                         20000 non-null  int64
#  38  progress_ratio                                                             20000 non-null  float64
#  39  current_stage                                                              20000 non-null  object
#  40  area_bin                                                                   20000 non-null  object
# dtypes: float64(30), int64(4), object(7)
# memory usage: 6.3+ MB

# %%
# Converting date columns to datetime objects
data['actual_commencement_date'] = pd.to_datetime(data['actual_commencement_date'], errors='coerce')
data['estimated_finish_date'] = pd.to_datetime(data['estimated_finish_date'], errors='coerce')

# %%
current_date = datetime.now()

# %%
data['duration_since_commencement'] = (current_date - data['actual_commencement_date']).dt.days
data['remaining_duration'] = (data['estimated_finish_date'] - current_date).dt.days
data['progress_ratio'] = data['duration_since_commencement'] / data['total_days']

# %%
# Define a function to determine the project status
def determine_status(row):
    if current_date > row['estimated_finish_date']:
        return 'completed'
    elif current_date >= row['actual_commencement_date']:
        return 'running'
    else:
        return 'upcoming'

# Apply the function to create the 'Status' column
data['current_stage'] = data.apply(determine_status, axis=1)

# %%
data.columns
# Out:
# Index(['organisation_name', 'project_category', 'actual_commencement_date',
#        'estimated_finish_date', 'total_built_up_area_saleable_area',
#        'total_area_of_project', 'floor', 'project_state', 'total_days',
#        'Cleaning & survey', 'Excavation,leveling & P.C.C  for Basement  B1 ',
#        ' Raft footing, Column B1, Retaining wall Reinforcement ,Concrete pouring ',
#        'Slab of B (bottom) ', ' Ground Floor slab casting ',
#        ' 1st floor Columns casting', ' 1st Floor slab casting',
#        '2nd floor Columns casting ', '2nd Floor slab casting',
#        ' Brick work at Basement to Ground Floor ',
#        '3rd floor Columns casting ', '3rd Floor slab casting',
#        ' Brick work at 1st Floor ',
#        'Electrical concealed, PVC Fitting, plastering at basement- ground floor',
#        '4th floor Columns casting ', '4th Floor slab casting',
#        ' Brick work at 2nd Floor ',
#        'Electrical concealed, PVC Fitting, plastering at 1st floor',
#        '5th floor Columns casting ', '5th Floor slab casting',
#        ' Brick work of 3rd to 5th Floor ',
#        'Electrical concealed, PVC Fitting, plastering at 2nd-5th floor',
#        'Plastering on outer sides', 'Tiles work', 'Painting and Finishing',
#        'Plumbing & Sanitary,Electrification Works',
#        'Doors & Windows Fixing Furniture work', 'duration_since_commencement',
#        'remaining_duration', 'progress_ratio', 'current_stage', 'area_bin',
#        'current_stage_encoded', 'project_state_encoded'],
#       dtype='object')

# %%
# Performing label encoding on the 'current_stage' column
label_encoder = LabelEncoder()
data['current_stage'] = data['current_stage'].astype(str) # Converting to string to handle any NaN values left
data['current_stage_encoded'] = label_encoder.fit_transform(data['current_stage'])

# %%
# Performing label encoding on the 'current_stage' column
label_encoder = LabelEncoder()
data['project_state'] = data['project_state'].astype(str) # Converting to string to handle any NaN values left
data['project_state_encoded'] = label_encoder.fit_transform(data['project_state'])

# %%
(data['current_stage'].value_counts()).plot(kind='barh'); plt.show()

# %%
data['total_days'].describe()
# Out:
# count    20000.000000
# mean       724.407650
# std        478.348066
# min         92.000000
# 25%        356.000000
# 50%        628.000000
# 75%        995.000000
# max       3612.000000
# Name: total_days, dtype: float64

# %%
# Feature selection - use relevant features for input
numerical_columns = data.select_dtypes(include=['int64', 'float64'])
stage_columns = [ 'Cleaning & survey', 'Excavation,leveling & P.C.C  for Basement  B1 ',
       ' Raft footing, Column B1, Retaining wall Reinforcement ,Concrete pouring ',
       'Slab of B (bottom) ', ' Ground Floor slab casting ',
       ' 1st floor Columns casting', ' 1st Floor slab casting',
       '2nd floor Columns casting ', '2nd Floor slab casting',
       ' Brick work at Basement to Ground Floor ',
       '3rd floor Columns casting ', '3rd Floor slab casting',
       ' Brick work at 1st Floor ',
       'Electrical concealed, PVC Fitting, plastering at basement- ground floor',
       '4th floor Columns casting ', '4th Floor slab casting',
       ' Brick work at 2nd Floor ',
       'Electrical concealed, PVC Fitting, plastering at 1st floor',
       '5th floor Columns casting ', '5th Floor slab casting',
       ' Brick work of 3rd to 5th Floor ',
       'Electrical concealed, PVC Fitting, plastering at 2nd-5th floor',
       'Plastering on outer sides', 'Tiles work', 'Painting and Finishing',
       'Plumbing & Sanitary,Electrification Works',
       'Doors & Windows Fixing Furniture work']
# Target variables
X = data[numerical_columns.columns.difference(stage_columns)].drop(columns='total_days')
y_total_days = data['total_days']
y_time_taken_at_each_stage = data[stage_columns]

# %%
X.columns
# Out:
# Index(['current_stage_encoded', 'duration_since_commencement', 'floor',
#        'progress_ratio', 'project_state_encoded', 'remaining_duration',
#        'total_area_of_project', 'total_built_up_area_saleable_area'],
#       dtype='object')

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# Assuming you have loaded your data and defined 'X' and 'y_total_days' as specified

# Split the data into training and testing sets
X_train, X_test, y_train_total_days, y_test_total_days = train_test_split(
    X, y_total_days, test_size=0.2, random_state=42)

# Create a function to train a Random Forest regression model, make predictions, and evaluate its performance
def train_evaluate_model(X_train, X_test, y_train_total_days, y_test_total_day):
    model = RandomForestRegressor(n_estimators=100, random_state=42)
    model.fit(X_train, y_train_total_days)
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test_total_days, y_pred)
    r2 = r2_score(y_test_total_days, y_pred)
    return mse, r2

# Initial model performance
initial_mse, initial_r2 = train_evaluate_model(X_train, X_test, y_train_total_days, y_test_total_days)
feature_impact = {}

for column in X.columns:
    X_temp = X.drop(columns=[column])
    mse, r2 = train_evaluate_model(X_train, X_test, y_train_total_days, y_test_total_days)
    mse_change = initial_mse - mse
    r2_change = r2 - initial_r2
    feature_impact[column] = {'MSE Change': mse_change, 'R-squared Change': r2_change}

# Print the impact of removing each feature
for column, impact in feature_impact.items():
    print(f"Removed '{column}':")
    print(f"MSE Change: {impact['MSE Change']:.2f}")
    print(f"R-squared Change: {impact['R-squared Change']:.4f}\n")
# Out:
# Removed 'current_stage_encoded':
# MSE Change: 0.00
# R-squared Change: 0.0000
#
# Removed 'duration_since_commencement':
# MSE Change: 0.00
# R-squared Change: 0.0000
#
# Removed 'floor':
# MSE Change: 0.00
# R-squared Change: 0.0000
#
# Removed 'progress_ratio':
# MSE Change: 0.00
# R-squared Change: 0.0000
#
# Removed 'project_state_encoded':
# MSE Change: 0.00
# R-squared Change: 0.0000
#
# Removed 'remaining_duration':
# MSE Change: 0.00
# R-squared Change: 0.0000
#
# Removed 'total_area_of_project':
# MSE Change: 0.00
# R-squared Change: 0.0000
#
# Removed 'total_built_up_area_saleable_area':
# MSE Change: 0.00
# R-squared Change: 0.0000

# %%
# Train a Random Forest model on the entire dataset
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X, y_total_days)

# Get feature importances
importances = model.feature_importances_

# Pair feature names with their importance scores
feature_importance = list(zip(X.columns, importances))

# Sort features by importance (in descending order)
feature_importance.sort(key=lambda x: x[1], reverse=True)

# Print the feature importances
for feature, importance in feature_importance:
    print(f"{feature}: {importance:.4f}")
# Out:
# remaining_duration: 0.6385
# progress_ratio: 0.2282
# duration_since_commencement: 0.1323
# total_built_up_area_saleable_area: 0.0005
# total_area_of_project: 0.0005
# project_state_encoded: 0.0000
# current_stage_encoded: 0.0000
# floor: 0.0000

# %%
# Split the data into training and testing sets
X_train, X_test, y_train_total_days, y_test_total_days, y_train_time, y_test_time = train_test_split(
    X, y_total_days, y_time_taken_at_each_stage, test_size=0.2, random_state=42)

# Create and train the regression model for total days
total_days_model = RandomForestRegressor(n_estimators=100, random_state=42)
total_days_model.fit(X_train, y_train_total_days)

# Predict total days on the test set
y_pred_total_days = total_days_model.predict(X_test)

# Evaluate the model for total days
mse_total_days = mean_squared_error(y_test_total_days, y_pred_total_days)
r2_total_days = r2_score(y_test_total_days, y_pred_total_days)
print(f'Mean Squared Error (Total Days): {mse_total_days}')
print(f'R-squared (Total Days): {r2_total_days}')
# Out:
# Mean Squared Error (Total Days): 40.75890345
# R-squared (Total Days): 0.9998259904025173

# %%
from sklearn.metrics import make_scorer
from sklearn.model_selection import cross_val_score
# Define a custom scorer for cross-validation
mse_scorer = make_scorer(mean_squared_error)  # Use make_scorer to create the custom scorer

# Perform K-Fold Cross-Validation
k = 5  # You can adjust the number of folds
cv_scores = cross_val_score(total_days_model, X, y_total_days, cv=k, scoring=mse_scorer)

# Print the mean and standard deviation of MSE scores
print("Cross-Validation Mean MSE:", np.mean(cv_scores))
print("Cross-Validation MSE Std Dev:", np.std(cv_scores))
# Out:
# Cross-Validation Mean MSE: 40.72763143000001
# Cross-Validation MSE Std Dev: 14.98967034497936

# %%
# Create and train the regression model for time taken at each stage
stage_models = {}
for stage in stage_columns:
    stage_model = RandomForestRegressor(n_estimators=100, random_state=42)
    stage_model.fit(X_train, y_train_time[stage])
    stage_models[stage] = stage_model

# Predict time taken at each stage on the test set
y_pred_time = {}
for stage, stage_model in stage_models.items():
    y_pred_time[stage] = stage_model.predict(X_test)

# %%
# Assuming you have already converted 'actual_commencement_date' to a datetime object
# Calculate days elapsed for each project
current_date = datetime.now()
data['days_elapsed'] = (current_date - data['actual_commencement_date']).dt.days

# Define a function to determine the relevant stage and relevant columns for each project
def determine_relevant_stage_and_columns(row):
    days_elapsed = row['days_elapsed']
    total_days = 0
    relevant_stage = None
    relevant_columns = []

    for stage in stage_columns:
        stage_duration = row[stage]  # Days required for the current stage
        total_days += stage_duration
        if total_days >= days_elapsed:
            relevant_stage = stage
            relevant_columns = [stage for stage in stage_columns[stage_columns.index(stage):]]
            break

    return relevant_stage, relevant_columns, total_days

# Apply the function to create the 'relevant_stage' and 'relevant_columns' columns
data[['relevant_stage', 'relevant_columns', 'total_days']] = data.apply(determine_relevant_stage_and_columns, axis=1, result_type='expand')

# Filter projects based on current_stage
completed_projects = data[data['current_stage'] == 'completed']
running_projects = data[data['current_stage'] == 'running']
upcoming_projects = data[data['current_stage'] == 'upcoming']

# Define a function to make predictions based on the current stage
def make_predictions(row):
    if row['current_stage'] == 'completed':
        return None  # No predictions for completed projects
    elif row['current_stage'] == 'running':
        if row['relevant_stage'] is not None:
            if row['relevant_stage'] in row['relevant_columns']:
                return row[row['relevant_stage']] - (row['days_elapsed'] - row['total_days'])
            else:
                return None  # Skip stages before the relevant stage
        else:
            return None  # Skip predictions for running projects with no relevant stage
    elif row['current_stage'] == 'upcoming':
        return row['total_days']  # Include all stages for upcoming projects

# Apply the make_predictions function to create the 'predicted_time_taken' column
data['predicted_time_taken'] = data.apply(make_predictions, axis=1)

# %%
# Evaluate the models for time taken at each stage
mse_stage = {}
r2_stage = {}
for stage in stage_columns:
    mse_stage[stage] = mean_squared_error(y_test_time[stage], y_pred_time[stage])
    r2_stage[stage] = r2_score(y_test_time[stage], y_pred_time[stage])
    print(f'Mean Squared Error ({stage}): {mse_stage[stage]}')
    print(f'R-squared ({stage}): {r2_stage[stage]}')
# Out:
# Mean Squared Error (Cleaning & survey): 0.0017482804464614655
# R-squared (Cleaning & survey): 0.9998225277078143
# Mean Squared Error (Excavation,leveling & P.C.C  for Basement  B1 ): 0.027069673087825347
# R-squared (Excavation,leveling & P.C.C  for Basement  B1 ): 0.9998282556389431
# Mean Squared Error ( Raft footing, Column B1, Retaining wall Reinforcement ,Concrete pouring ): 0.04942240017789802
# R-squared ( Raft footing, Column B1, Retaining wall Reinforcement ,Concrete pouring ): 0.999827949566355
# Mean Squared Error (Slab of B (bottom) ): 0.015692618378022362
# R-squared (Slab of B (bottom) ): 0.9998230003684427
# Mean Squared Error ( Ground Floor slab casting ): 0.054822441599419465
# R-squared ( Ground Floor slab casting ): 0.9998225394685071
# Mean Squared Error ( 1st floor Columns casting): 0.008347176850772544
# R-squared ( 1st floor Columns casting): 0.9998249292018819
# Mean Squared Error ( 1st Floor slab casting): 0.027069673087825347
# R-squared ( 1st Floor slab casting): 0.9998282556389431
# Mean Squared Error (2nd floor Columns casting ): 0.008347176850772544
# R-squared (2nd floor Columns casting ): 0.9998249292018819
# Mean Squared Error (2nd Floor slab casting): 0.03130038455124178
# R-squared (2nd Floor slab casting): 0.9998198764280112
# Mean Squared Error ( Brick work at Basement to Ground Floor ): 0.02182891298127113
# R-squared ( Brick work at Basement to Ground Floor ): 0.9998290195064476
# Mean Squared Error (3rd floor Columns casting ): 0.009932254314221383
# R-squared (3rd floor Columns casting ): 0.9998249569766058
# Mean Squared Error (3rd Floor slab casting): 0.033590575953206324
# R-squared (3rd Floor slab casting): 0.9998238707216073
# Mean Squared Error ( Brick work at 1st Floor ): 0.0052463832760526385
# R-squared ( Brick work at 1st Floor ): 0.9998356254930928
# Mean Squared Error (Electrical concealed, PVC Fitting, plastering at basement- ground floor): 0.04942240017789802
# R-squared (Electrical concealed, PVC Fitting, plastering at basement- ground floor): 0.999827949566355
# Mean Squared Error (4th floor Columns casting ): 0.009932254314221383
# R-squared (4th floor Columns casting ): 0.9998249569766058
# Mean Squared Error (4th Floor slab casting): 0.03130038455124178
# R-squared (4th Floor slab casting): 0.9998198764280112
# Mean Squared Error ( Brick work at 2nd Floor ): 0.0052463832760526385
# R-squared ( Brick work at 2nd Floor ): 0.9998356254930928
# Mean Squared Error (Electrical concealed, PVC Fitting, plastering at 1st floor): 0.027069673087825347
# R-squared (Electrical concealed, PVC Fitting, plastering at 1st floor): 0.9998282556389431
# Mean Squared Error (5th floor Columns casting ): 0.011902846222375276
# R-squared (5th floor Columns casting ): 0.9998212592461828
# Mean Squared Error (5th Floor slab casting): 0.033590575953206324
# R-squared (5th Floor slab casting): 0.9998238707216073
# Mean Squared Error ( Brick work of 3rd to 5th Floor ): 0.054822441599419465
# R-squared ( Brick work of 3rd to 5th Floor ): 0.9998225394685071
# Mean Squared Error (Electrical concealed, PVC Fitting, plastering at 2nd-5th floor): 0.31905957309893235
# R-squared (Electrical concealed, PVC Fitting, plastering at 2nd-5th floor): 0.9998347523976877
# Mean Squared Error (Plastering on outer sides): 0.3856921674627896
# R-squared (Plastering on outer sides): 0.9998259885765627
# Mean Squared Error (Tiles work): 0.2400767499886409
# R-squared (Tiles work): 0.9998307584206558
# Mean Squared Error (Painting and Finishing): 0.42989570907794256
# R-squared (Painting and Finishing): 0.9998295321030541
# Mean Squared Error (Plumbing & Sanitary,Electrification Works): 0.14335109170842758
# R-squared (Plumbing & Sanitary,Electrification Works): 0.9998203465986044
# Mean Squared Error (Doors & Windows Fixing Furniture work): 0.31905957309893235
# R-squared (Doors & Windows Fixing Furniture work): 0.9998347523976877

# %%
# Load the new data (replace 'new_data.csv' with the actual file path)
new_data = pd.read_csv('new_5_test_file.csv')

# %%
# Converting date columns to datetime objeacts
new_data['actual_commencement_date'] = pd.to_datetime(new_data['actual_commencement_date'], errors='coerce')
new_data['estimated_finish_date'] = pd.to_datetime(new_data['estimated_finish_date'], errors='coerce')

# %%
current_date = datetime.now()

# %%
new_data['total_days'] = (new_data['estimated_finish_date'] - new_data['actual_commencement_date']).dt.days

# %%
new_data['duration_since_commencement'] = (current_date - new_data['actual_commencement_date']).dt.days
new_data['remaining_duration'] = (new_data['estimated_finish_date'] - current_date).dt.days
new_data['progress_ratio'] = new_data['duration_since_commencement'] / new_data['total_days']

# %%
# Define a function to determine the project status
def determine_status(row):
    if current_date > row['estimated_finish_date']:
        return 'completed'
    elif current_date >= row['actual_commencement_date']:
        return 'running'
    else:
        return 'upcoming'

# Apply the function to create the 'Status' column
new_data['current_stage'] = new_data.apply(determine_status, axis=1)

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 163 entries, 0 to 162
# Data columns (total 15 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   organisation_name                  163 non-null    object
#  1   project_category                   163 non-null    object
#  2   actual_commencement_date           163 non-null    datetime64[ns]
#  3   estimated_finish_date              163 non-null    datetime64[ns]
#  4   total_built_up_area_saleable_area  163 non-null    float64
#  5   total_area_of_project              163 non-null    float64
#  6   floor                              163 non-null    int64
#  7   project_state                      163 non-null    object
#  8   office_no                          163 non-null    float64
#  9   project_res_no                     163 non-null    object
#  10  total_days                         163 non-null    int64
#  11  duration_since_commencement        163 non-null    int64
#  12  remaining_duration                 163 non-null    int64
#  13  progress_ratio                     163 non-null    float64
#  14  current_stage                      163 non-null    object
# dtypes: datetime64[ns](2), float64(4), int64(4), object(5)
# memory usage: 19.2+ KB

# %%
# Performing label encoding on the 'current_stage' column
label_encoder = LabelEncoder()
new_data['current_stage'] =new_data['current_stage'].astype(str) # Converting to string to handle any NaN values left
new_data['current_stage_encoded'] = label_encoder.fit_transform(new_data['current_stage'])

# %%
# Performing label encoding on the 'current_stage' column
label_encoder = LabelEncoder()
new_data['project_state'] =new_data['project_state'].astype(str) # Converting to string to handle any NaN values left
new_data['project_state_encoded'] = label_encoder.fit_transform(new_data['project_state'])

# %%
new_data['office_no'] = new_data['office_no'].astype(str)

# %%
stage_columns = [ 'Cleaning & survey', 'Excavation,leveling & P.C.C  for Basement  B1 ',
       ' Raft footing, Column B1, Retaining wall Reinforcement ,Concrete pouring ',
       'Slab of B (bottom) ', ' Ground Floor slab casting ',
       ' 1st floor Columns casting', ' 1st Floor slab casting',
       '2nd floor Columns casting ', '2nd Floor slab casting',
       ' Brick work at Basement to Ground Floor ',
       '3rd floor Columns casting ', '3rd Floor slab casting',
       ' Brick work at 1st Floor ',
       'Electrical concealed, PVC Fitting, plastering at basement- ground floor',
       '4th floor Columns casting ', '4th Floor slab casting',
       ' Brick work at 2nd Floor ',
       'Electrical concealed, PVC Fitting, plastering at 1st floor',
       '5th floor Columns casting ', '5th Floor slab casting',
       ' Brick work of 3rd to 5th Floor ',
       'Electrical concealed, PVC Fitting, plastering at 2nd-5th floor',
       'Plastering on outer sides', 'Tiles work', 'Painting and Finishing',
       'Plumbing & Sanitary,Electrification Works',
       'Doors & Windows Fixing Furniture work']

# %%
# Create an empty DataFrame to store 'new_data' with added columns
new_data = new_data.copy()  # Assuming 'new_data' is your original DataFrame

# Add stage-related columns and 'total_days' column with NaN values
for stage in stage_columns:
    new_data[stage] = np.nan

new_data['total_days'] = np.nan

# Now, 'new_data_with_stages' contains the additional columns with NaN values

# %%
numerical_columns = new_data.select_dtypes(include=['int64', 'float64'])
stage_columns = [ 'Cleaning & survey', 'Excavation,leveling & P.C.C  for Basement  B1 ',
       ' Raft footing, Column B1, Retaining wall Reinforcement ,Concrete pouring ',
       'Slab of B (bottom) ', ' Ground Floor slab casting ',
       ' 1st floor Columns casting', ' 1st Floor slab casting',
       '2nd floor Columns casting ', '2nd Floor slab casting',
       ' Brick work at Basement to Ground Floor ',
       '3rd floor Columns casting ', '3rd Floor slab casting',
       ' Brick work at 1st Floor ',
       'Electrical concealed, PVC Fitting, plastering at basement- ground floor',
       '4th floor Columns casting ', '4th Floor slab casting',
       ' Brick work at 2nd Floor ',
       'Electrical concealed, PVC Fitting, plastering at 1st floor',
       '5th floor Columns casting ', '5th Floor slab casting',
       ' Brick work of 3rd to 5th Floor ',
       'Electrical concealed, PVC Fitting, plastering at 2nd-5th floor',
       'Plastering on outer sides', 'Tiles work', 'Painting and Finishing',
       'Plumbing & Sanitary,Electrification Works',
       'Doors & Windows Fixing Furniture work']

# Target variables
X_new = new_data[numerical_columns.columns.difference(stage_columns)].drop(columns='total_days')
#y_total_days = new_data['total_days']
#y_time_taken_at_each_stage = new_data[stage_columns]  # Replace with your actual stage columns

# %%
new_data['total_days'] = total_days_model.predict(new_data[X_new.columns])

for stage in stage_columns:
    stage_model = stage_models.get(stage)  # Use get to avoid KeyError
    if stage_model:
        new_data[stage] = stage_model.predict(new_data[X_new.columns])
    else:
        # If the stage column isn't in stage_models, fill it with NaN
        new_data[stage] = np.nan

# %%
stage_materials = {
    'Cleaning & survey': [],
    'Excavation,leveling & P.C.C  for Basement  B1 ': ['cement', 'sand', 'aggregates'],
    ' Raft footing, Column B1, Retaining wall Reinforcement ,Concrete pouring ': ['TMT bar', 'cement', 'sand', 'aggregates'],
    'Slab of B (bottom) ': ['TMT bar', 'cement', 'sand', 'aggregates'],
    ' Ground Floor slab casting ': ['TMT bar', 'cement', 'sand', 'aggregates', 'Pvc pipes', 'circuit pipes', 'lightbox', 'fan box'],
    ' 1st floor Columns casting': ['TMT bar', 'cement', 'sand', 'aggregates'],
    ' 1st Floor slab casting': ['TMT bar', 'cement', 'sand', 'aggregates', 'Pvc pipes', 'circuit pipes', 'lightbox', 'fan box'],
    '2nd floor Columns casting ': ['TMT bar', 'cement', 'sand', 'aggregates'],
    '2nd Floor slab casting': ['TMT bar', 'cement', 'sand', 'aggregates', 'Pvc pipes', 'circuit pipes', 'lightbox', 'fan box'],
    ' Brick work at Basement to Ground Floor ': ['blocks/bricks'],
    '3rd floor Columns casting ': ['TMT bar', 'cement', 'sand', 'aggregates', 'Pvc pipes', 'circuit pipes', 'lightbox', 'fan box'],
    '3rd Floor slab casting': ['TMT bar', 'cement', 'sand', 'aggregates'],
    ' Brick work at 1st Floor ': ['blocks/bricks'],
    'Electrical concealed, PVC Fitting, plastering at basement- ground floor': ['cement', 'sand', 'circuit pipe', 'Cpvc', '&Pvc pipe'],
    '4th floor Columns casting ': ['TMT bar', 'cement', 'sand', 'aggregates'],
    '4th Floor slab casting': ['TMT bar', 'cement', 'sand', 'aggregates', 'Pvc pipes', 'circuit pipes', 'lightbox', 'fan box'],
    ' Brick work at 2nd Floor ': ['blocks/bricks'],
    'Electrical concealed, PVC Fitting, plastering at 1st floor': ['cement', 'sand', 'circuit pipe', 'Cpvc', '&Pvc pipe'],
    '5th floor Columns casting ': ['TMT bar', 'cement', 'sand', 'aggregates'],
    '5th Floor slab casting': ['TMT bar', 'cement', 'sand', 'aggregates', 'Pvc pipes', 'circuit pipes', 'lightbox', 'fan box'],
    ' Brick work of 3rd to 5th Floor ': ['blocks/bricks'],
    'Electrical concealed, PVC Fitting, plastering at 2nd-5th floor': ['cement', 'sand', 'circuit pipe', 'Cpvc', '&Pvc pipe'],
    'Plastering on outer sides': ['cement', 'sand'],
    'Tiles work': ['Tiles'],
    'Painting and Finishing': ['paint', 'putty', 'primer'],
    'Plumbing & Sanitary,Electrification Works': ['Wire', 'switch', 'nozzle Bib cock', 'shower', 'kitchen accessories', 'lights', 'fans', 'sheets', 'basin', 'sink', 'etc.'],
    'Doors & Windows Fixing Furniture work': ['Furniture', 'hardware', 'glass'],
}

# %%
# Initialize empty lists to store relevant_stage and relevant_columns
relevant_stage_list = []
relevant_columns_list = []

# Iterate through each row (project) in new_data
for index, row in new_data.iterrows():
    days_elapsed = (current_date - row['actual_commencement_date']).days
    total_days = row['total_days']

    relevant_stage = None
    relevant_columns = []

    for stage in stage_columns:

        if total_days is None or np.isnan(total_days):
            # Set relevant_stage and relevant_columns to None if total_days is missing
            relevant_stage = None
            relevant_columns = []
            break

        stage_duration = row[stage]
        total_days -= stage_duration

        if total_days <= days_elapsed:
            relevant_stage = stage
            relevant_columns = [stage for stage in stage_columns[stage_columns.index(stage):]]
            break

    relevant_stage_list.append(relevant_stage)
    relevant_columns_list.append(relevant_columns)

    # Add the 'relevant_stage' and 'relevant_columns' columns to the new_data DataFrame
new_data['relevant_stage'] = relevant_stage_list
new_data['relevant_columns'] = relevant_columns_list

# %%
import pandas as pd
import numpy as np

# Initialize empty DataFrame to store adjusted days data
adjusted_days_data = pd.DataFrame(columns=stage_columns)

# Iterate through each row (project) in new_data
for index, row in new_data.iterrows():
    current_stage = row['current_stage']
    relevant_columns = row['relevant_columns']

    if current_stage == 'completed':
        # For completed projects, set 'days' to NaN for all stage columns
        days_values = [np.nan] * len(stage_columns)
    elif current_stage == 'running':
        # For running projects, update 'days' based on relevant_columns
        days_values = [row[stage] if stage in relevant_columns else np.nan for stage in stage_columns]
    elif current_stage == 'upcoming':
        # For upcoming projects, keep the predicted 'days' values
        days_values = [row[stage] for stage in stage_columns]

    # Append the days_values to the adjusted_days_data
    adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)

# Replace the original stage values in new_data with adjusted values
new_data[stage_columns] = adjusted_days_data
# Out:
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)
# <ipython-input-39-06976df5c563>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adjusted_days_data = adjusted_days_data.append(pd.Series(days_values, index=stage_columns), ignore_index=True)

# %%
new_data
# Out:
#                               organisation_name           project_category  \
# 0                  Metric Homes Private Limited  Residential/Group Housing
# 1                         KRISHNA PANDIT GHARAT  Residential/Group Housing
# 2                   Vastu And Chopra Developers  Residential/Group Housing
# 3                           DHAVAL CONSTRUCTION  Residential/Group Housing
# 4    SMART VALUE HOMES (BOISAR) PRIVATE LIMITED  Residential/Group Housing
# ..                                          ...                        ...
# 158                         DATTARAJ DEVELOPERS  Residential/Group Housing
# 159              Shree Siddhivinayak Developers  Residential/Group Housing
# 160                                    V4 Infra  Residential/Group Housing
# 161      Vijay Supreme Builders Private Limited  Residential/Group Housing
# 162                      BALARAM PIRAJI SHINGTE  Residential/Group Housing
#
#     actual_commencement_date estimated_finish_date  \
# 0                 2023-03-01            2024-12-31
# 1                 2021-05-29            2023-03-31
# 2                 2017-08-27            2019-06-30
# 3                 2018-02-27            2019-12-31
# 4                 2017-07-25            2019-05-31
# ..                       ...                   ...
# 158               2021-09-09            2023-08-28
# 159               2022-01-12            2023-12-31
# 160               2017-09-10            2019-08-31
# 161               2018-07-11            2020-06-30
# 162               2017-09-08            2019-08-29
#
#      total_built_up_area_saleable_area  total_area_of_project  floor  \
# 0                              1293.65                 258.73      5
# 1                               494.99                 329.99      5
# 2                               750.00                1000.00      5
# 3                               863.44                1630.64      5
# 4                             11014.20               14927.42      5
# ..                                 ...                    ...    ...
# 158                             541.43                 541.63      5
# 159                            1623.05                 678.00      5
# 160                             422.20                 401.37      5
# 161                            1558.08                 468.04      5
# 162                            9363.00               10500.00      5
#
#     project_state     office_no                        project_res_no  ...  \
# 0     MAHARASHTRA  9987221188.0       Sindh3s_Wardha2s_NASIK8S_191500  ...
# 1     MAHARASHTRA  9920835555.0                    RAIGARH_Two_174500  ...
# 2     MAHARASHTRA  2024464217.0                       PUNE_One_207500  ...
# 3     MAHARASHTRA  9923963927.0               NASIK11S_AHMED1S_399500  ...
# 4     MAHARASHTRA  2266614444.0                     Palghar_One_39500  ...
# ..            ...           ...                                   ...  ...
# 158   MAHARASHTRA  2532530653.0       Sindh3s_Wardha2s_NASIK8S_518500  ...
# 159   MAHARASHTRA  9820264648.0                   THANE7S_OMC4_271000  ...
# 160   MAHARASHTRA  7152249538.0       Sindh3s_Wardha2s_NASIK8S_265000  ...
# 161     Rajasthan  1414043359.0                        RAJ/P/2019/883  ...
# 162   MAHARASHTRA  2025430643.0  Nagpur5_Sangli_4s_Kohlapur_4s_764500  ...
#
#      5th Floor slab casting   Brick work of 3rd to 5th Floor   \
# 0                       NaN                               NaN
# 1                       NaN                               NaN
# 2                       NaN                               NaN
# 3                       NaN                               NaN
# 4                       NaN                               NaN
# ..                      ...                               ...
# 158                     NaN                               NaN
# 159               20.483684                         26.070143
# 160                     NaN                               NaN
# 161                     NaN                               NaN
# 162                     NaN                               NaN
#
#      Electrical concealed, PVC Fitting, plastering at 2nd-5th floor  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 158                                                NaN
# 159                                          65.175357
# 160                                                NaN
# 161                                                NaN
# 162                                                NaN
#
#      Plastering on outer sides Tiles work  Painting and Finishing  \
# 0                    65.271401  52.216342               69.621790
# 1                          NaN        NaN                     NaN
# 2                          NaN        NaN                     NaN
# 3                          NaN        NaN                     NaN
# 4                          NaN        NaN                     NaN
# ..                         ...        ...                     ...
# 158                        NaN        NaN                     NaN
# 159                  69.830739  55.866148               74.488197
# 160                        NaN        NaN                     NaN
# 161                        NaN        NaN                     NaN
# 162                        NaN        NaN                     NaN
#
#      Plumbing & Sanitary,Electrification Works  \
# 0                                    39.162840
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ..                                         ...
# 158                                        NaN
# 159                                  41.899611
# 160                                        NaN
# 161                                        NaN
# 162                                        NaN
#
#      Doors & Windows Fixing Furniture work             relevant_stage  \
# 0                                60.919974  Plastering on outer sides
# 1                                      NaN          Cleaning & survey
# 2                                      NaN          Cleaning & survey
# 3                                      NaN          Cleaning & survey
# 4                                      NaN          Cleaning & survey
# ..                                     ...                        ...
# 158                                    NaN          Cleaning & survey
# 159                              65.175357        Slab of B (bottom)
# 160                                    NaN          Cleaning & survey
# 161                                    NaN          Cleaning & survey
# 162                                    NaN          Cleaning & survey
#
#                                       relevant_columns
# 0    [Plastering on outer sides, Tiles work, Painti...
# 1    [Cleaning & survey, Excavation,leveling & P.C....
# 2    [Cleaning & survey, Excavation,leveling & P.C....
# 3    [Cleaning & survey, Excavation,leveling & P.C....
# 4    [Cleaning & survey, Excavation,leveling & P.C....
# ..                                                 ...
# 158  [Cleaning & survey, Excavation,leveling & P.C....
# 159  [Slab of B (bottom) ,  Ground Floor slab casti...
# 160  [Cleaning & survey, Excavation,leveling & P.C....
# 161  [Cleaning & survey, Excavation,leveling & P.C....
# 162  [Cleaning & survey, Excavation,leveling & P.C....
#
# [163 rows x 46 columns]

# %%
# Define a function to print project details
def print_project_details(row, current_date):
    print(f'Organization Name: {row["organisation_name"]}')
    print(f'office_no	: {row["office_no"]}')
    print(f'project_res_no: {row["project_res_no"]}')
    print(f'Current Stage: {row["current_stage"]}')
    print(f'Total Days: {row["total_days"]}')
    print('Stage Details:')
    current_materials = []  # List to store materials for the current stage
    current_stage_start_date = current_date  # Initialize with the current date

    for stage in stage_columns:
        stage_duration = row[stage]

        if not pd.isna(stage_duration):
            # Calculate the stage end date
            stage_end_date = current_stage_start_date + pd.Timedelta(days=stage_duration)

            # Format the dates for display
            start_date_str = current_stage_start_date.strftime('%Y-%m-%d')
            end_date_str = stage_end_date.strftime('%Y-%m-%d')

            # Print the stage, days, and start and end dates
            print(f'{stage}: {stage_duration} days ({start_date_str} - {end_date_str})')

            # Update the start date for the next stage
            current_stage_start_date = stage_end_date

            # Check if there are materials for this stage
            materials = stage_materials.get(stage, [])

            if materials:
                # Display materials if available
                current_materials = materials

            if current_materials:
                # Print materials for the stage
                print(f'Materials: {", ".join(current_materials)}')

    print('-----------------')

# Iterate through each row (project) in the new_data DataFrame
for index, row in new_data.iterrows():
    # You need to pass the current date as an argument
    print_project_details(row, current_date)
# Out:
# Organization Name: Metric Homes Private Limited
# office_no	: 9987221188.0
# project_res_no: Sindh3s_Wardha2s_NASIK8S_191500
# Current Stage: running
# Total Days: 670.98
# Stage Details:
# Plastering on outer sides: 65.27140077821015 days (2023-10-30 - 2024-01-03)
# Materials: cement, sand
# Tiles work: 52.216342412451475 days (2024-01-03 - 2024-02-24)
# Materials: Tiles
# Painting and Finishing: 69.62178988326873 days (2024-02-24 - 2024-05-04)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 39.16284046692612 days (2024-05-04 - 2024-06-12)
# Materials: Wire, switch, nozzle Bib cock, shower, kitchen accessories, lights, fans, sheets, basin, sink, etc.
# Doors & Windows Fixing Furniture work: 60.91997405966277 days (2024-06-12 - 2024-08-12)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: KRISHNA PANDIT GHARAT
# office_no	: 9920835555.0
# project_res_no: RAIGARH_Two_174500
# Current Stage: completed
# Total Days: 671.11
# Stage Details:
# -----------------
# Organization Name: Vastu And Chopra Developers
# office_no	: 2024464217.0
# project_res_no: PUNE_One_207500
# Current Stage: completed
# Total Days: 671.24
# Stage Details:
# -----------------
# Organization Name: DHAVAL CONSTRUCTION
# office_no	: 9923963927.0
# project_res_no: NASIK11S_AHMED1S_399500
# Current Stage: completed
# Total Days: 672.06
# Stage Details:
# -----------------
# Organization Name: SMART VALUE HOMES (BOISAR) PRIVATE LIMITED
# office_no	: 2266614444.0
# project_res_no: Palghar_One_39500
# Current Stage: completed
# Total Days: 675.41
# Stage Details:
# -----------------
# Organization Name: SHREE KRISHNA BUILT HOME
# office_no	: 91797762443.0
# project_res_no: RAIGARH_Two_173000
# Current Stage: running
# Total Days: 677.15
# Stage Details:
#  Ground Floor slab casting : 24.59387808041502 days (2023-10-30 - 2023-11-23)
# Materials: TMT bar, cement, sand, aggregates, Pvc pipes, circuit pipes, lightbox, fan box
#  1st floor Columns casting: 9.662308690013015 days (2023-11-23 - 2023-12-03)
# Materials: TMT bar, cement, sand, aggregates
#  1st Floor slab casting: 17.565239948119306 days (2023-12-03 - 2023-12-21)
# Materials: TMT bar, cement, sand, aggregates, Pvc pipes, circuit pipes, lightbox, fan box
# 2nd floor Columns casting : 9.662308690013015 days (2023-12-21 - 2023-12-30)
# Materials: TMT bar, cement, sand, aggregates
# 2nd Floor slab casting: 18.439961089494126 days (2023-12-30 - 2024-01-18)
# Materials: TMT bar, cement, sand, aggregates, Pvc pipes, circuit pipes, lightbox, fan box
#  Brick work at Basement to Ground Floor : 15.811050583657579 days (2024-01-18 - 2024-02-03)
# Materials: blocks/bricks
# 3rd floor Columns casting : 10.537120622568127 days (2024-02-03 - 2024-02-13)
# Materials: TMT bar, cement, sand, aggregates, Pvc pipes, circuit pipes, lightbox, fan box
# 3rd Floor slab casting: 19.31805447470814 days (2024-02-13 - 2024-03-03)
# Materials: TMT bar, cement, sand, aggregates
#  Brick work at 1st Floor : 7.90552529182882 days (2024-03-03 - 2024-03-11)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at basement- ground floor: 23.71377431906615 days (2024-03-11 - 2024-04-04)
# Materials: cement, sand, circuit pipe, Cpvc, &Pvc pipe
# 4th floor Columns casting : 10.537120622568127 days (2024-04-04 - 2024-04-15)
# Materials: TMT bar, cement, sand, aggregates
# 4th Floor slab casting: 18.439961089494126 days (2024-04-15 - 2024-05-03)
# Materials: TMT bar, cement, sand, aggregates, Pvc pipes, circuit pipes, lightbox, fan box
#  Brick work at 2nd Floor : 7.90552529182882 days (2024-05-03 - 2024-05-11)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 1st floor: 17.565239948119306 days (2024-05-11 - 2024-05-28)
# Materials: cement, sand, circuit pipe, Cpvc, &Pvc pipe
# 5th floor Columns casting : 11.419092088197138 days (2024-05-28 - 2024-06-09)
# Materials: TMT bar, cement, sand, aggregates
# 5th Floor slab casting: 19.31805447470814 days (2024-06-09 - 2024-06-28)
# Materials: TMT bar, cement, sand, aggregates, Pvc pipes, circuit pipes, lightbox, fan box
#  Brick work of 3rd to 5th Floor : 24.59387808041502 days (2024-06-28 - 2024-07-23)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 2nd-5th floor: 61.44837872892336 days (2024-07-23 - 2024-09-22)
# Materials: cement, sand, circuit pipe, Cpvc, &Pvc pipe
# Plastering on outer sides: 65.83657587548632 days (2024-09-22 - 2024-11-27)
# Materials: cement, sand
# Tiles work: 52.70116731517512 days (2024-11-27 - 2025-01-19)
# Materials: Tiles
# Painting and Finishing: 70.27756160830106 days (2025-01-19 - 2025-03-30)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 39.534630350194554 days (2025-03-30 - 2025-05-09)
# Materials: Wire, switch, nozzle Bib cock, shower, kitchen accessories, lights, fans, sheets, basin, sink, etc.
# Doors & Windows Fixing Furniture work: 61.44837872892336 days (2025-05-09 - 2025-07-09)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: NANDKISHOR BHIMRAO CHAVAN
# office_no	: 9850588612.0
# project_res_no: AHMED2S_AMra3s_AUR7S_TH1S_715500
# Current Stage: running
# Total Days: 676.16
# Stage Details:
#  Brick work at Basement to Ground Floor : 15.779299610894935 days (2023-10-30 - 2023-11-15)
# Materials: blocks/bricks
# 3rd floor Columns casting : 10.527937743190696 days (2023-11-15 - 2023-11-25)
# Materials: TMT bar, cement, sand, aggregates, Pvc pipes, circuit pipes, lightbox, fan box
# 3rd Floor slab casting: 19.293800259403337 days (2023-11-25 - 2023-12-14)
# Materials: TMT bar, cement, sand, aggregates
#  Brick work at 1st Floor : 7.895953307393022 days (2023-12-14 - 2023-12-22)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at basement- ground floor: 23.687859922178994 days (2023-12-22 - 2024-01-15)
# Materials: cement, sand, circuit pipe, Cpvc, &Pvc pipe
# 4th floor Columns casting : 10.527937743190696 days (2024-01-15 - 2024-01-26)
# Materials: TMT bar, cement, sand, aggregates
# 4th Floor slab casting: 18.431517509727588 days (2024-01-26 - 2024-02-13)
# Materials: TMT bar, cement, sand, aggregates, Pvc pipes, circuit pipes, lightbox, fan box
#  Brick work at 2nd Floor : 7.895953307393022 days (2024-02-13 - 2024-02-21)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 1st floor: 17.53981841763941 days (2024-02-21 - 2024-03-09)
# Materials: cement, sand, circuit pipe, Cpvc, &Pvc pipe
# 5th floor Columns casting : 11.40526588845654 days (2024-03-09 - 2024-03-21)
# Materials: TMT bar, cement, sand, aggregates
# 5th Floor slab casting: 19.293800259403337 days (2024-03-21 - 2024-04-09)
# Materials: TMT bar, cement, sand, aggregates, Pvc pipes, circuit pipes, lightbox, fan box
#  Brick work of 3rd to 5th Floor : 24.585525291828773 days (2024-04-09 - 2024-05-04)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 2nd-5th floor: 61.412970168612084 days (2024-05-04 - 2024-07-04)
# Materials: cement, sand, circuit pipe, Cpvc, &Pvc pipe
# Plastering on outer sides: 65.8015564202334 days (2024-07-04 - 2024-09-08)
# Materials: cement, sand
# Tiles work: 52.63968871595332 days (2024-09-08 - 2024-10-31)
# Materials: Tiles
# Painting and Finishing: 70.21530479896255 days (2024-10-31 - 2025-01-09)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 39.48093385214008 days (2025-01-09 - 2025-02-17)
# Materials: Wire, switch, nozzle Bib cock, shower, kitchen accessories, lights, fans, sheets, basin, sink, etc.
# Doors & Windows Fixing Furniture work: 61.412970168612084 days (2025-02-17 - 2025-04-20)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: PERFECT BUILDWELL
# office_no	: 2532355051.0
# project_res_no: NASIK11S_AHMED1S_758500
# Current Stage: completed
# Total Days: 677.53
# Stage Details:
# -----------------
# Organization Name: PATIL BUILDERS
# office_no	: 8888161886.0
# project_res_no: Palghar_One_1
# Current Stage: completed
# Total Days: 676.94
# Stage Details:
# -----------------
# Organization Name: IPSIT ENTERPRISE
# office_no	: 2228331228.0
# project_res_no: Palghar_One_160500
# Current Stage: completed
# Total Days: 677.0
# Stage Details:
# -----------------
# Organization Name: SMRITI INFRAHEIGHTS PRIVATE LIMITED
# office_no	: 9769001588.0
# project_res_no: Palghar_One_358500
# Current Stage: completed
# Total Days: 677.0
# Stage Details:
# -----------------
# Organization Name: OM PROPERTIES
# office_no	: 9890173534.0
# project_res_no: Nagpur5_Sangli_4s_Kohlapur_4s_649500
# Current Stage: completed
# Total Days: 680.0
# Stage Details:
# -----------------
# Organization Name: Seven Star Realty
# office_no	: 9561534560.0
# project_res_no: PUNE_Four_15000
# Current Stage: completed
# Total Days: 680.88
# Stage Details:
# -----------------
# Organization Name: SALMAN KHALILURRAHMAN MULLA
# office_no	: 9021528233.0
# project_res_no: RAIGARH_One_898000
# Current Stage: completed
# Total Days: 679.69
# Stage Details:
# -----------------
# Organization Name: SARTHAK INFRA
# office_no	: 2148221535.0
# project_res_no: RAIGARH_Two_359000
# Current Stage: completed
# Total Days: 680.06
# Stage Details:
# -----------------
# Organization Name: AJIT DAMJI POKAR HUF KARTA AJIT D POKAR
# office_no	: 2532460864.0
# project_res_no: NASIK11S_AHMED1S_108500
# Current Stage: completed
# Total Days: 681.01
# Stage Details:
# -----------------
# Organization Name: SACHIN GANPATRAO TAWARE
# office_no	: 9970958483.0
# project_res_no: PUNE_One_651000
# Current Stage: completed
# Total Days: 681.14
# Stage Details:
# -----------------
# Organization Name: UTKARSH BUILDERS AND DEVELOPERS
# office_no	: 2532314166.0
# project_res_no: Sindh3s_Wardha2s_NASIK8S_963500
# Current Stage: completed
# Total Days: 681.13
# Stage Details:
# -----------------
# Organization Name: MUNISH INFRA LLP
# office_no	: 8691030000.0
# project_res_no: Palghar_One_297000
# Current Stage: completed
# Total Days: 681.0
# Stage Details:
# -----------------
# Organization Name: SHIVANSH DEVELOPERS
# office_no	: 2027515582.0
# project_res_no: PUNE_Three_813000
# Current Stage: completed
# Total Days: 682.01
# Stage Details:
# -----------------
# Organization Name: Pawansut Builders
# office_no	: 9373371117.0
# project_res_no: Sindh3s_Wardha2s_NASIK8S_256500
# Current Stage: completed
# Total Days: 682.67
# Stage Details:
# -----------------
# Organization Name: Shyam Oil Products
# office_no	: 9422161781.0
# project_res_no: AHMED2S_AMra3s_AUR7S_TH1S_117000
# Current Stage: completed
# Total Days: 681.26
# Stage Details:
# -----------------
# Organization Name: VARAD INFRA
# office_no	: 2514563211.0
# project_res_no: THANE7S_OMC4_449500
# Current Stage: running
# Total Days: 683.07
# Stage Details:
#  Ground Floor slab casting : 24.79797665369657 days (2023-10-30 - 2023-11-24)
# Materials: TMT bar, cement, sand, aggregates, Pvc pipes, circuit pipes, lightbox, fan box
#  1st floor Columns casting: 9.737782101167348 days (2023-11-24 - 2023-12-03)
# Materials: TMT bar, cement, sand, aggregates
#  1st Floor slab casting: 17.71725032425417 days (2023-12-03 - 2023-12-21)
# Materials: TMT bar, cement, sand, aggregates, Pvc pipes, circuit pipes, lightbox, fan box
# 2nd floor Columns casting : 9.737782101167348 days (2023-12-21 - 2023-12-31)
# Materials: TMT bar, cement, sand, aggregates
# 2nd Floor slab casting: 18.603112840466956 days (2023-12-31 - 2024-01-18)
# Materials: TMT bar, cement, sand, aggregates, Pvc pipes, circuit pipes, lightbox, fan box
#  Brick work at Basement to Ground Floor : 15.940155642023312 days (2024-01-18 - 2024-02-03)
# Materials: blocks/bricks
# 3rd floor Columns casting : 10.627548638132325 days (2024-02-03 - 2024-02-14)
# Materials: TMT bar, cement, sand, aggregates, Pvc pipes, circuit pipes, lightbox, fan box
# 3rd Floor slab casting: 19.490402075227 days (2024-02-14 - 2024-03-04)
# Materials: TMT bar, cement, sand, aggregates
#  Brick work at 1st Floor : 7.974046692607016 days (2024-03-04 - 2024-03-12)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at basement- ground floor: 23.917937743190638 days (2024-03-12 - 2024-04-05)
# Materials: cement, sand, circuit pipe, Cpvc, &Pvc pipe
# 4th floor Columns casting : 10.627548638132325 days (2024-04-05 - 2024-04-16)
# Materials: TMT bar, cement, sand, aggregates
# 4th Floor slab casting: 18.603112840466956 days (2024-04-16 - 2024-05-05)
# Materials: TMT bar, cement, sand, aggregates, Pvc pipes, circuit pipes, lightbox, fan box
#  Brick work at 2nd Floor : 7.974046692607016 days (2024-05-05 - 2024-05-13)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 1st floor: 17.71725032425417 days (2024-05-13 - 2024-05-30)
# Materials: cement, sand, circuit pipe, Cpvc, &Pvc pipe
# 5th floor Columns casting : 11.508287937743155 days (2024-05-30 - 2024-06-11)
# Materials: TMT bar, cement, sand, aggregates
# 5th Floor slab casting: 19.490402075227 days (2024-06-11 - 2024-06-30)
# Materials: TMT bar, cement, sand, aggregates, Pvc pipes, circuit pipes, lightbox, fan box
#  Brick work of 3rd to 5th Floor : 24.79797665369657 days (2024-06-30 - 2024-07-25)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 2nd-5th floor: 62.00038910505843 days (2024-07-25 - 2024-09-25)
# Materials: cement, sand, circuit pipe, Cpvc, &Pvc pipe
# Plastering on outer sides: 66.42315175097289 days (2024-09-25 - 2024-12-01)
# Materials: cement, sand
# Tiles work: 53.14319066147871 days (2024-12-01 - 2025-01-23)
# Materials: Tiles
# Painting and Finishing: 70.87418936446201 days (2025-01-23 - 2025-04-04)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 39.86089494163415 days (2025-04-04 - 2025-05-13)
# Materials: Wire, switch, nozzle Bib cock, shower, kitchen accessories, lights, fans, sheets, basin, sink, etc.
# Doors & Windows Fixing Furniture work: 62.00038910505843 days (2025-05-13 - 2025-07-14)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: Rohit Vasantrao Ghanwat
# office_no	: 2112222600.0
# project_res_no: PUNE_Five_630500
# Current Stage: completed
# Total Days: 682.82
# Stage Details:
# -----------------
# Organization Name: SHAKIL AHMAD MULLA
# office_no	: 2512665968.0
# project_res_no: THANE11S_402500
# Current Stage: completed
# Total Days: 682.68
# Stage Details:
# -----------------
# Organization Name: JAY HANUMANTRAO JADHAV
# office_no	: 7385684046.0
# project_res_no: Pune_Six_513500
# Current Stage: running
# Total Days: 684.18
# Stage Details:
# Plastering on outer sides: 66.55447470817107 days (2023-10-30 - 2024-01-04)
# Materials: cement, sand
# Tiles work: 53.23968871595341 days (2024-01-04 - 2024-02-27)
# Materials: Tiles
# Painting and Finishing: 70.99143968871616 days (2024-02-27 - 2024-05-08)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 39.93268482490269 days (2024-05-08 - 2024-06-17)
# Materials: Wire, switch, nozzle Bib cock, shower, kitchen accessories, lights, fans, sheets, basin, sink, etc.
# Doors & Windows Fixing Furniture work: 62.11660181582365 days (2024-06-17 - 2024-08-18)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: Shiv Builders and Developers
# office_no	: 8369473798.0
# project_res_no: THANE11S_158500
# Current Stage: completed
# Total Days: 684.08
# Stage Details:
# -----------------
# Organization Name: Manda Bhimrao Patekar
# office_no	: 9112280805.0
# project_res_no: NASIK11S_AHMED1S_872000
# Current Stage: running
# Total Days: 684.96
# Stage Details:
# Plastering on outer sides: 66.62937743190655 days (2023-10-30 - 2024-01-04)
# Materials: cement, sand
# Tiles work: 53.30428015564203 days (2024-01-04 - 2024-02-27)
# Materials: Tiles
# Painting and Finishing: 71.0692607003894 days (2024-02-27 - 2024-05-08)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 39.9782101167315 days (2024-05-08 - 2024-06-17)
# Materials: Wire, switch, nozzle Bib cock, shower, kitchen accessories, lights, fans, sheets, basin, sink, etc.
# Doors & Windows Fixing Furniture work: 62.1874189364461 days (2024-06-17 - 2024-08-18)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: DEZINERS HOMES PVT. LTD.
# office_no	: 2227709911.0
# project_res_no: RAIGARH_One_401000
# Current Stage: completed
# Total Days: 684.9
# Stage Details:
# -----------------
# Organization Name: Rajegaonkar Projects Private Limited
# office_no	: 2532570435.0
# project_res_no: NASIK11S_AHMED1S_882500
# Current Stage: running
# Total Days: 683.13
# Stage Details:
# Plastering on outer sides: 66.49805447470811 days (2023-10-30 - 2024-01-04)
# Materials: cement, sand
# Tiles work: 53.17431906614789 days (2024-01-04 - 2024-02-26)
# Materials: Tiles
# Painting and Finishing: 70.86900129701715 days (2024-02-26 - 2024-05-07)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 39.877821011673134 days (2024-05-07 - 2024-06-16)
# Materials: Wire, switch, nozzle Bib cock, shower, kitchen accessories, lights, fans, sheets, basin, sink, etc.
# Doors & Windows Fixing Furniture work: 62.03670557717243 days (2024-06-16 - 2024-08-17)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: LB ASSOCIATES
# office_no	: 9823030746.0
# project_res_no: Pune_Six_157500
# Current Stage: running
# Total Days: 685.0
# Stage Details:
# Plastering on outer sides: 66.63326848249021 days (2023-10-30 - 2024-01-04)
# Materials: cement, sand
# Tiles work: 53.307392996108966 days (2024-01-04 - 2024-02-27)
# Materials: Tiles
# Painting and Finishing: 71.07548638132327 days (2024-02-27 - 2024-05-08)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 39.9805447470817 days (2024-05-08 - 2024-06-17)
# Materials: Wire, switch, nozzle Bib cock, shower, kitchen accessories, lights, fans, sheets, basin, sink, etc.
# Doors & Windows Fixing Furniture work: 62.191050583657514 days (2024-06-17 - 2024-08-18)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: PRAPTI HOMES
# office_no	: 2027206570.0
# project_res_no: PUNE_Two_151500
# Current Stage: completed
# Total Days: 686.0
# Stage Details:
# -----------------
# Organization Name: SWASTIKCONSTRUCTION
# office_no	: 2025583720.0
# project_res_no: PUNE_Five_484000
# Current Stage: completed
# Total Days: 687.94
# Stage Details:
# -----------------
# Organization Name: A K ENTERPRISES
# office_no	: 2402356936.0
# project_res_no: AHMED2S_AMra3s_AUR7S_TH1S_424500
# Current Stage: completed
# Total Days: 685.17
# Stage Details:
# -----------------
# Organization Name: SACHIN BABANRAO SHINDE
# office_no	: 9822581111.0
# project_res_no: Jalga2s_Chand2s_Sola3_Sat6s_889500
# Current Stage: completed
# Total Days: 688.92
# Stage Details:
# -----------------
# Organization Name: KASHIBAI NARAYAN PATIL
# office_no	: 2227560002.0
# project_res_no: THANE12S_315000
# Current Stage: completed
# Total Days: 690.0
# Stage Details:
# -----------------
# Organization Name: Rohan Balasaheb Waghmare
# office_no	: 2162240990.0
# project_res_no: Jalga2s_Chand2s_Sola3_Sat6s_675500
# Current Stage: completed
# Total Days: 690.0
# Stage Details:
# -----------------
# Organization Name: VICKY KASHINATH BHOIR
# office_no	: 8082605366.0
# project_res_no: RAIGARH_Two_446500
# Current Stage: completed
# Total Days: 690.0
# Stage Details:
# -----------------
# Organization Name: NILAM VASUDEV PATIL
# office_no	: 9768111045.0
# project_res_no: RAIGARH_Two_212000
# Current Stage: completed
# Total Days: 690.0
# Stage Details:
# -----------------
# Organization Name: SARTHAK BUILDCON
# office_no	: 9511999000.0
# project_res_no: RAIGARH_Two_604500
# Current Stage: completed
# Total Days: 690.0
# Stage Details:
# -----------------
# Organization Name: MUNISHWAR DEVELOPERS
# office_no	: 8208167319.0
# project_res_no: RAIGARH_Two_524500
# Current Stage: completed
# Total Days: 690.0
# Stage Details:
# -----------------
# Organization Name: Tushar Mohanrao Khatavkar
# office_no	: 7507797792.0
# project_res_no: Nagpur5_Sangli_4s_Kohlapur_4s_959500
# Current Stage: completed
# Total Days: 690.0
# Stage Details:
# -----------------
# Organization Name: Ashtavinayak Builders and Developers
# office_no	: 2265206530.0
# project_res_no: RAIGARH_Two_962000
# Current Stage: completed
# Total Days: 689.84
# Stage Details:
# -----------------
# Organization Name: NEELKANTH ENTERPRISES
# office_no	: 8779889615.0
# project_res_no: RAIGARH_One_451500
# Current Stage: completed
# Total Days: 690.0
# Stage Details:
# -----------------
# Organization Name: MORYA DEVELOPERS
# office_no	: 2027410397.0
# project_res_no: PUNE_Two_36000
# Current Stage: completed
# Total Days: 690.0
# Stage Details:
# -----------------
# Organization Name: SHREEJI LIFESPACES INFRA PROJECTS
# office_no	: 9870642735.0
# project_res_no: RAIGARH_Two_417000
# Current Stage: completed
# Total Days: 690.0
# Stage Details:
# -----------------
# Organization Name: SHREE DARSHAN ENTERPRISES
# office_no	: 2513198852.0
# project_res_no: THANE12S_902500
# Current Stage: completed
# Total Days: 690.0
# Stage Details:
# -----------------
# Organization Name: Pratap Gulab Bhogade
# office_no	: 2412340021.0
# project_res_no: AHMED2S_AMra3s_AUR7S_TH1S_500
# Current Stage: completed
# Total Days: 690.0
# Stage Details:
# -----------------
# Organization Name: NILESH SURESH KSHATRIYA
# office_no	: 9923347799.0
# project_res_no: AHMED2S_AMra3s_AUR7S_TH1S_711000
# Current Stage: completed
# Total Days: 690.0
# Stage Details:
# -----------------
# Organization Name: Ramanuj Sidhariram Sharma
# office_no	: 8930203526.0
# project_res_no: RAIGARH_Two_498500
# Current Stage: completed
# Total Days: 690.0
# Stage Details:
# -----------------
# Organization Name: SHUBHANGI BALWANT PATIL
# office_no	: 2531111111.0
# project_res_no: Sindh3s_Wardha2s_NASIK8S_753000
# Current Stage: completed
# Total Days: 690.0
# Stage Details:
# -----------------
# Organization Name: RAHUL POPATRAO KAKULTE
# office_no	: 2532621014.0
# project_res_no: Sindh3s_Wardha2s_NASIK8S_829500
# Current Stage: completed
# Total Days: 690.0
# Stage Details:
# -----------------
# Organization Name: BASAVESHWAR MAHALINGAYYA SWAMI
# office_no	: 9422040760.0
# project_res_no: Nagpur5_Sangli_4s_Kohlapur_4s_516500
# Current Stage: completed
# Total Days: 690.0
# Stage Details:
# -----------------
# Organization Name: APEX BUILDCON
# office_no	: 9823106342.0
# project_res_no: Sindh3s_Wardha2s_NASIK8S_817500
# Current Stage: completed
# Total Days: 690.0
# Stage Details:
# -----------------
# Organization Name: Yash Sandeep Soni
# office_no	: 9404208555.0
# project_res_no: Sindh3s_Wardha2s_NASIK8S_743500
# Current Stage: completed
# Total Days: 690.0
# Stage Details:
# -----------------
# Organization Name: SARTHAK BUILDCON
# office_no	: 9511999000.0
# project_res_no: RAIGARH_Two_604500
# Current Stage: completed
# Total Days: 690.0
# Stage Details:
# -----------------
# Organization Name: K AND S INFRA
# office_no	: 2226686730.0
# project_res_no: RAIGARH_Three_213500
# Current Stage: completed
# Total Days: 690.0
# Stage Details:
# -----------------
# Organization Name: NASIR IBRAHIM DIWAN
# office_no	: 9821400944.0
# project_res_no: RAIGARH_Two_262000
# Current Stage: completed
# Total Days: 690.0
# Stage Details:
# -----------------
# Organization Name: R M CONSTRUCTION
# office_no	: 9273456020.0
# project_res_no: NASIK11S_AHMED1S_103500
# Current Stage: completed
# Total Days: 690.0
# Stage Details:
# -----------------
# Organization Name: Jay Malhar Construction
# office_no	: 2512437081.0
# project_res_no: THANE12S_414000
# Current Stage: completed
# Total Days: 690.0
# Stage Details:
# -----------------
# Organization Name: RIDDHEESH DEVELOPERS
# office_no	: 2532310996.0
# project_res_no: Sindh3s_Wardha2s_NASIK8S_734000
# Current Stage: completed
# Total Days: 690.0
# Stage Details:
# -----------------
# Organization Name: JYOTI DEVELOPERS
# office_no	: 2532310996.0
# project_res_no: Sindh3s_Wardha2s_NASIK8S_335000
# Current Stage: completed
# Total Days: 690.0
# Stage Details:
# -----------------
# Organization Name: Deep Realtors
# office_no	: 7350526700.0
# project_res_no: THANE12S_621500
# Current Stage: completed
# Total Days: 690.0
# Stage Details:
# -----------------
# Organization Name: SANJAY JAGGANNATH KOLHI
# office_no	: 2402348077.0
# project_res_no: AHMED2S_AMra3s_AUR7S_TH1S_702500
# Current Stage: completed
# Total Days: 690.0
# Stage Details:
# -----------------
# Organization Name: KAVITA RAJU BHADKE
# office_no	: 9423179952.0
# project_res_no: NASIK11S_AHMED1S_362500
# Current Stage: completed
# Total Days: 690.0
# Stage Details:
# -----------------
# Organization Name: GHANSHYAM AKHILESHWAR ROY
# office_no	: 2502331894.0
# project_res_no: Palghar_One_777000
# Current Stage: completed
# Total Days: 690.0
# Stage Details:
# -----------------
# Organization Name: SHREE DEVELOPERS
# office_no	: 9823365666.0
# project_res_no: Nagpur5_Sangli_4s_Kohlapur_4s_517000
# Current Stage: completed
# Total Days: 689.76
# Stage Details:
# -----------------
# Organization Name: SAACHI DEVELOPERS
# office_no	: 2338411083.0
# project_res_no: Nagpur5_Sangli_4s_Kohlapur_4s_630500
# Current Stage: completed
# Total Days: 690.0
# Stage Details:
# -----------------
# Organization Name: R P ENTERPRISES
# office_no	: 2512202488.0
# project_res_no: THANE12S_717500
# Current Stage: completed
# Total Days: 690.0
# Stage Details:
# -----------------
# Organization Name: SHAHZADALI ABDULWAHEB CHAUDHARY
# office_no	: 2512712072.0
# project_res_no: THANE12S_916500
# Current Stage: completed
# Total Days: 690.0
# Stage Details:
# -----------------
# Organization Name: SHYAMLAJI DEVELOPERS
# office_no	: 9422766128.0
# project_res_no: Sindh3s_Wardha2s_NASIK8S_433500
# Current Stage: completed
# Total Days: 690.0
# Stage Details:
# -----------------
# Organization Name: MAKARAND KRISHNAJI DESHPANDE
# office_no	: 9890047848.0
# project_res_no: NASIK11S_AHMED1S_888500
# Current Stage: completed
# Total Days: 690.0
# Stage Details:
# -----------------
# Organization Name: STONEHARD BUILDERS AND DEVELOPERS LLP
# office_no	: 9527319947.0
# project_res_no: RAIGARH_Two_661000
# Current Stage: completed
# Total Days: 690.0
# Stage Details:
# -----------------
# Organization Name: SUNNY HOMES
# office_no	: 2228132560.0
# project_res_no: RAIGARH_Two_294500
# Current Stage: completed
# Total Days: 690.0
# Stage Details:
# -----------------
# Organization Name: Shelar Developers
# office_no	: 9221043622.0
# project_res_no: THANE12S_787500
# Current Stage: completed
# Total Days: 690.0
# Stage Details:
# -----------------
# Organization Name: SUMAN LEELA ASSOCIATE
# office_no	: 2532312665.0
# project_res_no: Sindh3s_Wardha2s_NASIK8S_639500
# Current Stage: completed
# Total Days: 690.0
# Stage Details:
# -----------------
# Organization Name: SHREE MAHALAXMI CORP
# office_no	: 7719029029.0
# project_res_no: PUNE_Two_378000
# Current Stage: completed
# Total Days: 690.0
# Stage Details:
# -----------------
# Organization Name: Geetai Investment
# office_no	: 2512712761.0
# project_res_no: THANE12S_728000
# Current Stage: completed
# Total Days: 690.0
# Stage Details:
# -----------------
# Organization Name: CENTURY BUILDERS AND DEVELOPERS
# office_no	: 2532316349.0
# project_res_no: NASIK11S_AHMED1S_483000
# Current Stage: completed
# Total Days: 690.0
# Stage Details:
# -----------------
# Organization Name: RAVIRAJ BUILDWELL
# office_no	: 2532598924.0
# project_res_no: Sindh3s_Wardha2s_NASIK8S_325500
# Current Stage: completed
# Total Days: 690.0
# Stage Details:
# -----------------
# Organization Name: Veer Global Infraconstruction Limited
# office_no	: 2506525333.0
# project_res_no: Palghar_One_434000
# Current Stage: completed
# Total Days: 690.0
# Stage Details:
# -----------------
# Organization Name: PRUTHVI INFRA
# office_no	: 2112225004.0
# project_res_no: Jalga2s_Chand2s_Sola3_Sat6s_827500
# Current Stage: completed
# Total Days: 690.0
# Stage Details:
# -----------------
# Organization Name: HARAK PATIL REALTORS
# office_no	: 7757944043.0
# project_res_no: NASIK11S_AHMED1S_22000
# Current Stage: completed
# Total Days: 690.0
# Stage Details:
# -----------------
# Organization Name: RAJLAXMI DEVELOPERS
# office_no	: 9819557176.0
# project_res_no: THANE12S_886500
# Current Stage: completed
# Total Days: 690.0
# Stage Details:
# -----------------
# Organization Name: DABHADE AGARWAL ASSOCIATES
# office_no	: 9822547417.0
# project_res_no: PUNE_Two_236500
# Current Stage: completed
# Total Days: 690.0
# Stage Details:
# -----------------
# Organization Name: omganeshbuild
# office_no	: 2167227444.0
# project_res_no: Jalga2s_Chand2s_Sola3_Sat6s_822500
# Current Stage: completed
# Total Days: 690.0
# Stage Details:
# -----------------
# Organization Name: PADMAVATI CONSTRUCTION
# office_no	: 2222222222.0
# project_res_no: RAIGARH_Three_172000
# Current Stage: completed
# Total Days: 690.0
# Stage Details:
# -----------------
# Organization Name: GAURAV BUILDERS
# office_no	: 9422130345.0
# project_res_no: THANE7S_OMC4_592000
# Current Stage: completed
# Total Days: 690.0
# Stage Details:
# -----------------
# Organization Name: SHREE BALAJI INFRA
# office_no	: 2506558585.0
# project_res_no: Palghar_One_754500
# Current Stage: completed
# Total Days: 690.0
# Stage Details:
# -----------------
# Organization Name: SUDHIR DADASAHEB BABAR
# office_no	: 2347272150.0
# project_res_no: Nagpur5_Sangli_4s_Kohlapur_4s_520500
# Current Stage: completed
# Total Days: 690.0
# Stage Details:
# -----------------
# Organization Name: SKYLINE DEVELOPERS
# office_no	: 2227576192.0
# project_res_no: THANE11S_278000
# Current Stage: completed
# Total Days: 690.0
# Stage Details:
# -----------------
# Organization Name: KRISHNA BUILDERS & DEVELOPERS
# office_no	: 9226699255.0
# project_res_no: THANE12S_291000
# Current Stage: completed
# Total Days: 690.0
# Stage Details:
# -----------------
# Organization Name: BHOOMI SANKALP DEVELOPERS
# office_no	: 2228040707.0
# project_res_no: Palghar_One_631000
# Current Stage: completed
# Total Days: 690.07
# Stage Details:
# -----------------
# Organization Name: SHREE BALAJI ENTERPRISES
# office_no	: 9822775358.0
# project_res_no: Palghar_One_457000
# Current Stage: completed
# Total Days: 690.0
# Stage Details:
# -----------------
# Organization Name: SHRI KULSWAMINI PROMOTERS
# office_no	: 2025870145.0
# project_res_no: PUNE_Three_312000
# Current Stage: completed
# Total Days: 690.0
# Stage Details:
# -----------------
# Organization Name: M/S Tejal Park
# office_no	: 7276677800.0
# project_res_no: AHMED2S_AMra3s_AUR7S_TH1S_614500
# Current Stage: completed
# Total Days: 692.4
# Stage Details:
# -----------------
# Organization Name: MAYUR PRABHAKAR DESHMUKH
# office_no	: 2502845621.0
# project_res_no: Palghar_One_866500
# Current Stage: completed
# Total Days: 692.56
# Stage Details:
# -----------------
# Organization Name: VYANKATESH DEVELOPERS
# office_no	: 2162252601.0
# project_res_no: Jalga2s_Chand2s_Sola3_Sat6s_524000
# Current Stage: completed
# Total Days: 693.0
# Stage Details:
# -----------------
# Organization Name: RAJESH KANHA MHATRE
# office_no	: 9323698929.0
# project_res_no: RAIGARH_One_703000
# Current Stage: completed
# Total Days: 694.11
# Stage Details:
# -----------------
# Organization Name: GAJANAN REALTORS
# office_no	: 2532460864.0
# project_res_no: Sindh3s_Wardha2s_NASIK8S_818500
# Current Stage: completed
# Total Days: 693.45
# Stage Details:
# -----------------
# Organization Name: Mane and Khot Associate
# office_no	: 2332301555.0
# project_res_no: Nagpur5_Sangli_4s_Kohlapur_4s_681500
# Current Stage: running
# Total Days: 696.7
# Stage Details:
#  Ground Floor slab casting : 25.29333333333331 days (2023-10-30 - 2023-11-24)
# Materials: TMT bar, cement, sand, aggregates, Pvc pipes, circuit pipes, lightbox, fan box
#  1st floor Columns casting: 9.941517509727671 days (2023-11-24 - 2023-12-04)
# Materials: TMT bar, cement, sand, aggregates
#  1st Floor slab casting: 18.07003891050584 days (2023-12-04 - 2023-12-22)
# Materials: TMT bar, cement, sand, aggregates, Pvc pipes, circuit pipes, lightbox, fan box
# 2nd floor Columns casting : 9.941517509727671 days (2023-12-22 - 2024-01-01)
# Materials: TMT bar, cement, sand, aggregates
# 2nd Floor slab casting: 18.972178988326824 days (2024-01-01 - 2024-01-20)
# Materials: TMT bar, cement, sand, aggregates, Pvc pipes, circuit pipes, lightbox, fan box
#  Brick work at Basement to Ground Floor : 16.270272373540852 days (2024-01-20 - 2024-02-05)
# Materials: blocks/bricks
# 3rd floor Columns casting : 10.843268482490325 days (2024-02-05 - 2024-02-16)
# Materials: TMT bar, cement, sand, aggregates, Pvc pipes, circuit pipes, lightbox, fan box
# 3rd Floor slab casting: 19.88217898832689 days (2024-02-16 - 2024-03-07)
# Materials: TMT bar, cement, sand, aggregates
#  Brick work at 1st Floor : 8.132451361867714 days (2024-03-07 - 2024-03-15)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at basement- ground floor: 24.40190661478602 days (2024-03-15 - 2024-04-09)
# Materials: cement, sand, circuit pipe, Cpvc, &Pvc pipe
# 4th floor Columns casting : 10.843268482490325 days (2024-04-09 - 2024-04-19)
# Materials: TMT bar, cement, sand, aggregates
# 4th Floor slab casting: 18.972178988326824 days (2024-04-19 - 2024-05-08)
# Materials: TMT bar, cement, sand, aggregates, Pvc pipes, circuit pipes, lightbox, fan box
#  Brick work at 2nd Floor : 8.132451361867714 days (2024-05-08 - 2024-05-17)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 1st floor: 18.07003891050584 days (2024-05-17 - 2024-06-04)
# Materials: cement, sand, circuit pipe, Cpvc, &Pvc pipe
# 5th floor Columns casting : 11.741647211413728 days (2024-06-04 - 2024-06-15)
# Materials: TMT bar, cement, sand, aggregates
# 5th Floor slab casting: 19.88217898832689 days (2024-06-15 - 2024-07-05)
# Materials: TMT bar, cement, sand, aggregates, Pvc pipes, circuit pipes, lightbox, fan box
#  Brick work of 3rd to 5th Floor : 25.29333333333331 days (2024-07-05 - 2024-07-31)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 2nd-5th floor: 63.233333333333434 days (2024-07-31 - 2024-10-02)
# Materials: cement, sand, circuit pipe, Cpvc, &Pvc pipe
# Plastering on outer sides: 67.76264591439683 days (2024-10-02 - 2024-12-09)
# Materials: cement, sand
# Tiles work: 54.20000000000008 days (2024-12-09 - 2025-02-01)
# Materials: Tiles
# Painting and Finishing: 72.2988326848251 days (2025-02-01 - 2025-04-14)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 40.66984435797668 days (2025-04-14 - 2025-05-25)
# Materials: Wire, switch, nozzle Bib cock, shower, kitchen accessories, lights, fans, sheets, basin, sink, etc.
# Doors & Windows Fixing Furniture work: 63.233333333333434 days (2025-05-25 - 2025-07-27)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: Allwin Infrastructure
# office_no	: 9881624508.0
# project_res_no: Sindh3s_Wardha2s_NASIK8S_911000
# Current Stage: completed
# Total Days: 697.02
# Stage Details:
# -----------------
# Organization Name: BALAJI DEVELOPERS
# office_no	: 2532397482.0
# project_res_no: NASIK11S_AHMED1S_446500
# Current Stage: running
# Total Days: 697.64
# Stage Details:
#  Ground Floor slab casting : 25.336913099870277 days (2023-10-30 - 2023-11-24)
# Materials: TMT bar, cement, sand, aggregates, Pvc pipes, circuit pipes, lightbox, fan box
#  1st floor Columns casting: 9.953644617380071 days (2023-11-24 - 2023-12-04)
# Materials: TMT bar, cement, sand, aggregates
#  1st Floor slab casting: 18.094422827496757 days (2023-12-04 - 2023-12-22)
# Materials: TMT bar, cement, sand, aggregates, Pvc pipes, circuit pipes, lightbox, fan box
# 2nd floor Columns casting : 9.953644617380071 days (2023-12-22 - 2024-01-01)
# Materials: TMT bar, cement, sand, aggregates
# 2nd Floor slab casting: 18.99260700389103 days (2024-01-01 - 2024-01-20)
# Materials: TMT bar, cement, sand, aggregates, Pvc pipes, circuit pipes, lightbox, fan box
#  Brick work at Basement to Ground Floor : 16.29221789883268 days (2024-01-20 - 2024-02-05)
# Materials: blocks/bricks
# 3rd floor Columns casting : 10.86194552529188 days (2024-02-05 - 2024-02-16)
# Materials: TMT bar, cement, sand, aggregates, Pvc pipes, circuit pipes, lightbox, fan box
# 3rd Floor slab casting: 19.91642023346307 days (2024-02-16 - 2024-03-07)
# Materials: TMT bar, cement, sand, aggregates
#  Brick work at 1st Floor : 8.144241245136197 days (2024-03-07 - 2024-03-15)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at basement- ground floor: 24.429571984435825 days (2024-03-15 - 2024-04-09)
# Materials: cement, sand, circuit pipe, Cpvc, &Pvc pipe
# 4th floor Columns casting : 10.86194552529188 days (2024-04-09 - 2024-04-20)
# Materials: TMT bar, cement, sand, aggregates
# 4th Floor slab casting: 18.99260700389103 days (2024-04-20 - 2024-05-09)
# Materials: TMT bar, cement, sand, aggregates, Pvc pipes, circuit pipes, lightbox, fan box
#  Brick work at 2nd Floor : 8.144241245136197 days (2024-05-09 - 2024-05-17)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 1st floor: 18.094422827496757 days (2024-05-17 - 2024-06-04)
# Materials: cement, sand, circuit pipe, Cpvc, &Pvc pipe
# 5th floor Columns casting : 11.761880674448749 days (2024-06-04 - 2024-06-16)
# Materials: TMT bar, cement, sand, aggregates
# 5th Floor slab casting: 19.91642023346307 days (2024-06-16 - 2024-07-06)
# Materials: TMT bar, cement, sand, aggregates, Pvc pipes, circuit pipes, lightbox, fan box
#  Brick work of 3rd to 5th Floor : 25.336913099870277 days (2024-07-06 - 2024-07-31)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 2nd-5th floor: 63.325032425421625 days (2024-07-31 - 2024-10-02)
# Materials: cement, sand, circuit pipe, Cpvc, &Pvc pipe
# Plastering on outer sides: 67.83268482490267 days (2024-10-02 - 2024-12-09)
# Materials: cement, sand
# Tiles work: 54.27315175097285 days (2024-12-09 - 2025-02-01)
# Materials: Tiles
# Painting and Finishing: 72.36005188067466 days (2025-02-01 - 2025-04-15)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 40.72120622568096 days (2025-04-15 - 2025-05-25)
# Materials: Wire, switch, nozzle Bib cock, shower, kitchen accessories, lights, fans, sheets, basin, sink, etc.
# Doors & Windows Fixing Furniture work: 63.325032425421625 days (2025-05-25 - 2025-07-28)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: DINESH RAMRAO DOLARE
# office_no	: 9823266969.0
# project_res_no: AHMED2S_AMra3s_AUR7S_TH1S_283000
# Current Stage: completed
# Total Days: 696.93
# Stage Details:
# -----------------
# Organization Name: ROHINI SUBHASH PAWAR
# office_no	: 0.0
# project_res_no: NASIK11S_AHMED1S_694000
# Current Stage: running
# Total Days: 696.69
# Stage Details:
# Electrical concealed, PVC Fitting, plastering at basement- ground floor: 24.39980544747079 days (2023-10-30 - 2023-11-23)
# Materials: cement, sand, circuit pipe, Cpvc, &Pvc pipe
# 4th floor Columns casting : 10.853696498054497 days (2023-11-23 - 2023-12-04)
# Materials: TMT bar, cement, sand, aggregates
# 4th Floor slab casting: 18.953385214007785 days (2023-12-04 - 2023-12-23)
# Materials: TMT bar, cement, sand, aggregates, Pvc pipes, circuit pipes, lightbox, fan box
#  Brick work at 2nd Floor : 8.12276264591442 days (2023-12-23 - 2023-12-31)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 1st floor: 18.0508430609598 days (2023-12-31 - 2024-01-18)
# Materials: cement, sand, circuit pipe, Cpvc, &Pvc pipe
# 5th floor Columns casting : 11.746199740596591 days (2024-01-18 - 2024-01-30)
# Materials: TMT bar, cement, sand, aggregates
# 5th Floor slab casting: 19.932399481193254 days (2024-01-30 - 2024-02-19)
# Materials: TMT bar, cement, sand, aggregates, Pvc pipes, circuit pipes, lightbox, fan box
#  Brick work of 3rd to 5th Floor : 25.30277561608302 days (2024-02-19 - 2024-03-15)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 2nd-5th floor: 63.41763942931254 days (2024-03-15 - 2024-05-18)
# Materials: cement, sand, circuit pipe, Cpvc, &Pvc pipe
# Plastering on outer sides: 67.72276264591433 days (2024-05-18 - 2024-07-24)
# Materials: cement, sand
# Tiles work: 54.178988326848284 days (2024-07-24 - 2024-09-17)
# Materials: Tiles
# Painting and Finishing: 72.17431906614802 days (2024-09-17 - 2024-11-28)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 40.64591439688704 days (2024-11-28 - 2025-01-07)
# Materials: Wire, switch, nozzle Bib cock, shower, kitchen accessories, lights, fans, sheets, basin, sink, etc.
# Doors & Windows Fixing Furniture work: 63.41763942931254 days (2025-01-07 - 2025-03-12)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: SHRIJEEKRUPA REALTORS LLP
# office_no	: 9766135099.0
# project_res_no: Palghar_Two_4000
# Current Stage: running
# Total Days: 698.96
# Stage Details:
# Electrical concealed, PVC Fitting, plastering at 1st floor: 18.131258106355393 days (2023-10-30 - 2023-11-17)
# Materials: cement, sand, circuit pipe, Cpvc, &Pvc pipe
# 5th floor Columns casting : 11.78531776913096 days (2023-11-17 - 2023-11-29)
# Materials: TMT bar, cement, sand, aggregates
# 5th Floor slab casting: 19.944383916990923 days (2023-11-29 - 2023-12-19)
# Materials: TMT bar, cement, sand, aggregates, Pvc pipes, circuit pipes, lightbox, fan box
#  Brick work of 3rd to 5th Floor : 25.383761348897554 days (2023-12-19 - 2024-01-13)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 2nd-5th floor: 63.4594033722438 days (2024-01-13 - 2024-03-17)
# Materials: cement, sand, circuit pipe, Cpvc, &Pvc pipe
# Plastering on outer sides: 67.99221789883262 days (2024-03-17 - 2024-05-24)
# Materials: cement, sand
# Tiles work: 54.39377431906617 days (2024-05-24 - 2024-07-17)
# Materials: Tiles
# Painting and Finishing: 72.52503242542167 days (2024-07-17 - 2024-09-27)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 40.795330739299494 days (2024-09-27 - 2024-11-07)
# Materials: Wire, switch, nozzle Bib cock, shower, kitchen accessories, lights, fans, sheets, basin, sink, etc.
# Doors & Windows Fixing Furniture work: 63.4594033722438 days (2024-11-07 - 2025-01-10)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: Future Roof Realty
# office_no	: 9414069089.0
# project_res_no: RAJ/P/2022/1893
# Current Stage: completed
# Total Days: 699.11
# Stage Details:
# -----------------
# Organization Name: WARREN GERALD CONNOR
# office_no	: 9702242044.0
# project_res_no: THANE11S_867500
# Current Stage: completed
# Total Days: 699.01
# Stage Details:
# -----------------
# Organization Name: MetroDevelopers
# office_no	: 2184222199.0
# project_res_no: Jalga2s_Chand2s_Sola3_Sat6s_256000
# Current Stage: completed
# Total Days: 699.07
# Stage Details:
# -----------------
# Organization Name: SAMARTH DEVELOPERS AND PRAMOTERS
# office_no	: 2098500763.0
# project_res_no: Pune_Six_297000
# Current Stage: running
# Total Days: 700.28
# Stage Details:
# Plastering on outer sides: 68.11381322957205 days (2023-10-30 - 2024-01-06)
# Materials: cement, sand
# Tiles work: 54.50194552529192 days (2024-01-06 - 2024-02-29)
# Materials: Tiles
# Painting and Finishing: 72.6630350194554 days (2024-02-29 - 2024-05-12)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 40.864785992217854 days (2024-05-12 - 2024-06-22)
# Materials: Wire, switch, nozzle Bib cock, shower, kitchen accessories, lights, fans, sheets, basin, sink, etc.
# Doors & Windows Fixing Furniture work: 63.572892347600636 days (2024-06-22 - 2024-08-25)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: BURHANI BUILDER AND LAND DEVELOPERS
# office_no	: 7152254252.0
# project_res_no: Sindh3s_Wardha2s_NASIK8S_213500
# Current Stage: completed
# Total Days: 699.85
# Stage Details:
# -----------------
# Organization Name: Prabhat Developers
# office_no	: 2532579611.0
# project_res_no: NASIK11S_AHMED1S_771500
# Current Stage: completed
# Total Days: 699.8
# Stage Details:
# -----------------
# Organization Name: SHUBHARAMBHA DEVELOPERS
# office_no	: 2099999999.0
# project_res_no: PUNE_Three_185500
# Current Stage: completed
# Total Days: 700.0
# Stage Details:
# -----------------
# Organization Name: DEVIPRABHA REAL ESTATE
# office_no	: 7122443440.0
# project_res_no: Nagpur5_Sangli_4s_Kohlapur_4s_354500
# Current Stage: running
# Total Days: 701.0
# Stage Details:
# Plastering on outer sides: 68.19066147859934 days (2023-10-30 - 2024-01-06)
# Materials: cement, sand
# Tiles work: 54.552529182879304 days (2024-01-06 - 2024-03-01)
# Materials: Tiles
# Painting and Finishing: 72.73670557717281 days (2024-03-01 - 2024-05-12)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 40.91439688715948 days (2024-05-12 - 2024-06-22)
# Materials: Wire, switch, nozzle Bib cock, shower, kitchen accessories, lights, fans, sheets, basin, sink, etc.
# Doors & Windows Fixing Furniture work: 63.64461738002593 days (2024-06-22 - 2024-08-25)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: RAJESH SUBHASH DHARIA
# office_no	: 2145222220.0
# project_res_no: RAIGARH_Two_33000
# Current Stage: running
# Total Days: 701.0
# Stage Details:
# Plastering on outer sides: 68.19066147859934 days (2023-10-30 - 2024-01-06)
# Materials: cement, sand
# Tiles work: 54.552529182879304 days (2024-01-06 - 2024-03-01)
# Materials: Tiles
# Painting and Finishing: 72.73670557717281 days (2024-03-01 - 2024-05-12)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 40.91439688715948 days (2024-05-12 - 2024-06-22)
# Materials: Wire, switch, nozzle Bib cock, shower, kitchen accessories, lights, fans, sheets, basin, sink, etc.
# Doors & Windows Fixing Furniture work: 63.64461738002593 days (2024-06-22 - 2024-08-25)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: Amol Jagannath Ruchke
# office_no	: 9422164327.0
# project_res_no: AHMED2S_AMra3s_AUR7S_TH1S_140000
# Current Stage: running
# Total Days: 701.18
# Stage Details:
# Plastering on outer sides: 68.20817120622578 days (2023-10-30 - 2024-01-06)
# Materials: cement, sand
# Tiles work: 54.566536964980486 days (2024-01-06 - 2024-03-01)
# Materials: Tiles
# Painting and Finishing: 72.75538261997437 days (2024-03-01 - 2024-05-12)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 40.928404669260644 days (2024-05-12 - 2024-06-22)
# Materials: Wire, switch, nozzle Bib cock, shower, kitchen accessories, lights, fans, sheets, basin, sink, etc.
# Doors & Windows Fixing Furniture work: 63.660959792477286 days (2024-06-22 - 2024-08-25)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: SAI SIDDHI DEVELOPERS
# office_no	: 9029066349.0
# project_res_no: THANE7S_OMC4_124500
# Current Stage: running
# Total Days: 701.8
# Stage Details:
# Plastering on outer sides: 68.24902723735417 days (2023-10-30 - 2024-01-06)
# Materials: cement, sand
# Tiles work: 54.61478599221783 days (2024-01-06 - 2024-03-01)
# Materials: Tiles
# Painting and Finishing: 72.81971465629084 days (2024-03-01 - 2024-05-13)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 40.96284046692602 days (2024-05-13 - 2024-06-22)
# Materials: Wire, switch, nozzle Bib cock, shower, kitchen accessories, lights, fans, sheets, basin, sink, etc.
# Doors & Windows Fixing Furniture work: 63.72542153047987 days (2024-06-22 - 2024-08-25)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: ATUL TUKARAM WAGH
# office_no	: 2533556409.0
# project_res_no: NASIK11S_AHMED1S_600000
# Current Stage: running
# Total Days: 701.0
# Stage Details:
# 2nd floor Columns casting : 10.001297016861256 days (2023-10-30 - 2023-11-09)
# Materials: TMT bar, cement, sand, aggregates
# 2nd Floor slab casting: 19.09338521400781 days (2023-11-09 - 2023-11-28)
# Materials: TMT bar, cement, sand, aggregates, Pvc pipes, circuit pipes, lightbox, fan box
#  Brick work at Basement to Ground Floor : 16.365758754863762 days (2023-11-28 - 2023-12-14)
# Materials: blocks/bricks
# 3rd floor Columns casting : 10.910505836575917 days (2023-12-14 - 2023-12-25)
# Materials: TMT bar, cement, sand, aggregates, Pvc pipes, circuit pipes, lightbox, fan box
# 3rd Floor slab casting: 20.002594033722463 days (2023-12-25 - 2024-01-14)
# Materials: TMT bar, cement, sand, aggregates
#  Brick work at 1st Floor : 8.18287937743195 days (2024-01-14 - 2024-01-22)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at basement- ground floor: 24.548638132295753 days (2024-01-22 - 2024-02-16)
# Materials: cement, sand, circuit pipe, Cpvc, &Pvc pipe
# 4th floor Columns casting : 10.910505836575917 days (2024-02-16 - 2024-02-27)
# Materials: TMT bar, cement, sand, aggregates
# 4th Floor slab casting: 19.09338521400781 days (2024-02-27 - 2024-03-17)
# Materials: TMT bar, cement, sand, aggregates, Pvc pipes, circuit pipes, lightbox, fan box
#  Brick work at 2nd Floor : 8.18287937743195 days (2024-03-17 - 2024-03-25)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 1st floor: 18.184176394293154 days (2024-03-25 - 2024-04-12)
# Materials: cement, sand, circuit pipe, Cpvc, &Pvc pipe
# 5th floor Columns casting : 11.819714656290468 days (2024-04-12 - 2024-04-24)
# Materials: TMT bar, cement, sand, aggregates
# 5th Floor slab casting: 20.002594033722463 days (2024-04-24 - 2024-05-14)
# Materials: TMT bar, cement, sand, aggregates, Pvc pipes, circuit pipes, lightbox, fan box
#  Brick work of 3rd to 5th Floor : 25.457846952010364 days (2024-05-14 - 2024-06-09)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 2nd-5th floor: 63.64461738002593 days (2024-06-09 - 2024-08-11)
# Materials: cement, sand, circuit pipe, Cpvc, &Pvc pipe
# Plastering on outer sides: 68.19066147859934 days (2024-08-11 - 2024-10-18)
# ...
# Tiles work: 55.56420233463028 days (2024-01-07 - 2024-03-03)
# Materials: Tiles
# Painting and Finishing: 74.0856031128406 days (2024-03-03 - 2024-05-16)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 41.67315175097282 days (2024-05-16 - 2024-06-27)
# Materials: Wire, switch, nozzle Bib cock, shower, kitchen accessories, lights, fans, sheets, basin, sink, etc.
# Doors & Windows Fixing Furniture work: 64.8249027237353 days (2024-06-27 - 2024-08-30)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: ESSEN REALTORS
# office_no	: 2027481199.0
# project_res_no: PUNE_Three_526000
# Current Stage: running
# Total Days: 714.29
# Stage Details:
#  1st floor Columns casting: 10.190765239948165 days (2023-10-30 - 2023-11-09)
# Materials: TMT bar, cement, sand, aggregates
#  1st Floor slab casting: 18.55771725032426 days (2023-11-09 - 2023-11-28)
# Materials: TMT bar, cement, sand, aggregates, Pvc pipes, circuit pipes, lightbox, fan box
# 2nd floor Columns casting : 10.190765239948165 days (2023-11-28 - 2023-12-08)
# Materials: TMT bar, cement, sand, aggregates
# 2nd Floor slab casting: 19.465175097276237 days (2023-12-08 - 2023-12-27)
# Materials: TMT bar, cement, sand, aggregates, Pvc pipes, circuit pipes, lightbox, fan box
#  Brick work at Basement to Ground Floor : 16.708482490272328 days (2023-12-27 - 2024-01-13)
# Materials: blocks/bricks
# 3rd floor Columns casting : 11.121712062256837 days (2024-01-13 - 2024-01-24)
# Materials: TMT bar, cement, sand, aggregates, Pvc pipes, circuit pipes, lightbox, fan box
# 3rd Floor slab casting: 20.413488975356632 days (2024-01-24 - 2024-02-13)
# Materials: TMT bar, cement, sand, aggregates
#  Brick work at 1st Floor : 8.341517509727666 days (2024-02-13 - 2024-02-22)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at basement- ground floor: 25.03365758754865 days (2024-02-22 - 2024-03-18)
# Materials: cement, sand, circuit pipe, Cpvc, &Pvc pipe
# 4th floor Columns casting : 11.121712062256837 days (2024-03-18 - 2024-03-29)
# Materials: TMT bar, cement, sand, aggregates
# 4th Floor slab casting: 19.465175097276237 days (2024-03-29 - 2024-04-17)
# Materials: TMT bar, cement, sand, aggregates, Pvc pipes, circuit pipes, lightbox, fan box
#  Brick work at 2nd Floor : 8.341517509727666 days (2024-04-17 - 2024-04-26)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 1st floor: 18.55771725032426 days (2024-04-26 - 2024-05-14)
# Materials: cement, sand, circuit pipe, Cpvc, &Pvc pipe
# 5th floor Columns casting : 12.050881971465593 days (2024-05-14 - 2024-05-26)
# Materials: TMT bar, cement, sand, aggregates
# 5th Floor slab casting: 20.413488975356632 days (2024-05-26 - 2024-06-16)
# Materials: TMT bar, cement, sand, aggregates, Pvc pipes, circuit pipes, lightbox, fan box
#  Brick work of 3rd to 5th Floor : 25.99097276264589 days (2024-06-16 - 2024-07-12)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 2nd-5th floor: 64.89481193255502 days (2024-07-12 - 2024-09-15)
# Materials: cement, sand, circuit pipe, Cpvc, &Pvc pipe
# Plastering on outer sides: 69.61089494163436 days (2024-09-15 - 2024-11-23)
# Materials: cement, sand
# Tiles work: 55.67315175097272 days (2024-11-23 - 2025-01-18)
# Materials: Tiles
# Painting and Finishing: 74.13955901426732 days (2025-01-18 - 2025-04-02)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 41.77470817120626 days (2025-04-02 - 2025-05-14)
# Materials: Wire, switch, nozzle Bib cock, shower, kitchen accessories, lights, fans, sheets, basin, sink, etc.
# Doors & Windows Fixing Furniture work: 64.89481193255502 days (2025-05-14 - 2025-07-18)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: IFTEKHAR KAMRUDDIN KHAN
# office_no	: 2512693350.0
# project_res_no: RAIGARH_One_702000
# Current Stage: completed
# Total Days: 714.64
# Stage Details:
# -----------------
# Organization Name: MAHAVEER DEVELOPERS AND BUILDERS
# office_no	: 2184227853.0
# project_res_no: Jalga2s_Chand2s_Sola3_Sat6s_344000
# Current Stage: completed
# Total Days: 714.23
# Stage Details:
# -----------------
# Organization Name: AVINASH PUNDLIK THORAT
# office_no	: 2562233220.0
# project_res_no: THANE7S_OMC4_646500
# Current Stage: completed
# Total Days: 714.93
# Stage Details:
# -----------------
# Organization Name: KALPAVRUKSH DEVELOPERS
# office_no	: 2427244333.0
# project_res_no: AHMED2S_AMra3s_AUR7S_TH1S_22000
# Current Stage: completed
# Total Days: 715.13
# Stage Details:
# -----------------
# Organization Name: OM BUILDERS & DEVELOPERS
# office_no	: 2227431889.0
# project_res_no: RAIGARH_One_663000
# Current Stage: completed
# Total Days: 715.12
# Stage Details:
# -----------------
# Organization Name: ANNAPPA UMAJI DUPARGUDE
# office_no	: 9594943724.0
# project_res_no: RAIGARH_Two_196000
# Current Stage: running
# Total Days: 716.67
# Stage Details:
#  Ground Floor slab casting : 26.016757457846946 days (2023-10-30 - 2023-11-25)
# Materials: TMT bar, cement, sand, aggregates, Pvc pipes, circuit pipes, lightbox, fan box
#  1st floor Columns casting: 10.225434500648525 days (2023-11-25 - 2023-12-05)
# Materials: TMT bar, cement, sand, aggregates
#  1st Floor slab casting: 18.590142671854725 days (2023-12-05 - 2023-12-24)
# Materials: TMT bar, cement, sand, aggregates, Pvc pipes, circuit pipes, lightbox, fan box
# 2nd floor Columns casting : 10.225434500648525 days (2023-12-24 - 2024-01-03)
# Materials: TMT bar, cement, sand, aggregates
# 2nd Floor slab casting: 19.51420233463035 days (2024-01-03 - 2024-01-22)
# Materials: TMT bar, cement, sand, aggregates, Pvc pipes, circuit pipes, lightbox, fan box
#  Brick work at Basement to Ground Floor : 16.73206225680931 days (2024-01-22 - 2024-02-08)
# Materials: blocks/bricks
# 3rd floor Columns casting : 11.154396887159567 days (2024-02-08 - 2024-02-19)
# Materials: TMT bar, cement, sand, aggregates, Pvc pipes, circuit pipes, lightbox, fan box
# 3rd Floor slab casting: 20.447444876783408 days (2024-02-19 - 2024-03-11)
# Materials: TMT bar, cement, sand, aggregates
#  Brick work at 1st Floor : 8.361828793774333 days (2024-03-11 - 2024-03-19)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at basement- ground floor: 25.08548638132301 days (2024-03-19 - 2024-04-13)
# Materials: cement, sand, circuit pipe, Cpvc, &Pvc pipe
# 4th floor Columns casting : 11.154396887159567 days (2024-04-13 - 2024-04-24)
# Materials: TMT bar, cement, sand, aggregates
# 4th Floor slab casting: 19.51420233463035 days (2024-04-24 - 2024-05-14)
# Materials: TMT bar, cement, sand, aggregates, Pvc pipes, circuit pipes, lightbox, fan box
#  Brick work at 2nd Floor : 8.361828793774333 days (2024-05-14 - 2024-05-22)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 1st floor: 18.590142671854725 days (2024-05-22 - 2024-06-10)
# Materials: cement, sand, circuit pipe, Cpvc, &Pvc pipe
# 5th floor Columns casting : 12.082918287937684 days (2024-06-10 - 2024-06-22)
# Materials: TMT bar, cement, sand, aggregates
# 5th Floor slab casting: 20.447444876783408 days (2024-06-22 - 2024-07-12)
# Materials: TMT bar, cement, sand, aggregates, Pvc pipes, circuit pipes, lightbox, fan box
#  Brick work of 3rd to 5th Floor : 26.016757457846946 days (2024-07-12 - 2024-08-07)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 2nd-5th floor: 65.0564202334631 days (2024-08-07 - 2024-10-11)
# Materials: cement, sand, circuit pipe, Cpvc, &Pvc pipe
# Plastering on outer sides: 69.70525291828784 days (2024-10-11 - 2024-12-20)
# Materials: cement, sand
# Tiles work: 55.76887159533074 days (2024-12-20 - 2025-02-14)
# Materials: Tiles
# Painting and Finishing: 74.34604409857344 days (2025-02-14 - 2025-04-29)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 41.823151750972684 days (2025-04-29 - 2025-06-10)
# Materials: Wire, switch, nozzle Bib cock, shower, kitchen accessories, lights, fans, sheets, basin, sink, etc.
# Doors & Windows Fixing Furniture work: 65.0564202334631 days (2025-06-10 - 2025-08-14)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: SANKET BUILDTECH
# office_no	: 2554256053.0
# project_res_no: NASIK11S_AHMED1S_271000
# Current Stage: completed
# Total Days: 715.82
# Stage Details:
# -----------------
# Organization Name: Roopsanyog Co Op Housing Society ltd Nashik
# office_no	: 8329084144.0
# project_res_no: NASIK11S_AHMED1S_76500
# Current Stage: completed
# Total Days: 709.44
# Stage Details:
# -----------------
# Organization Name: BRAHMACHAITANYA ASSOCIATES
# office_no	: 9881643335.0
# project_res_no: PUNE_Five_844500
# Current Stage: running
# Total Days: 716.08
# Stage Details:
# Slab of B (bottom) : 13.929182879377386 days (2023-10-30 - 2023-11-13)
# Materials: TMT bar, cement, sand, aggregates
#  Ground Floor slab casting : 26.004773022049285 days (2023-11-13 - 2023-12-09)
# Materials: TMT bar, cement, sand, aggregates, Pvc pipes, circuit pipes, lightbox, fan box
#  1st floor Columns casting: 10.213022049286655 days (2023-12-09 - 2023-12-19)
# Materials: TMT bar, cement, sand, aggregates
#  1st Floor slab casting: 18.571725032425412 days (2023-12-19 - 2024-01-07)
# Materials: TMT bar, cement, sand, aggregates, Pvc pipes, circuit pipes, lightbox, fan box
# 2nd floor Columns casting : 10.213022049286655 days (2024-01-07 - 2024-01-17)
# Materials: TMT bar, cement, sand, aggregates
# 2nd Floor slab casting: 19.498132295719845 days (2024-01-17 - 2024-02-05)
# Materials: TMT bar, cement, sand, aggregates, Pvc pipes, circuit pipes, lightbox, fan box
#  Brick work at Basement to Ground Floor : 16.714552529182853 days (2024-02-05 - 2024-02-22)
# Materials: blocks/bricks
# 3rd floor Columns casting : 11.144591439688748 days (2024-02-22 - 2024-03-04)
# Materials: TMT bar, cement, sand, aggregates, Pvc pipes, circuit pipes, lightbox, fan box
# 3rd Floor slab casting: 20.423761348897543 days (2024-03-04 - 2024-03-25)
# Materials: TMT bar, cement, sand, aggregates
#  Brick work at 1st Floor : 8.357276264591452 days (2024-03-25 - 2024-04-02)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at basement- ground floor: 25.075330739299666 days (2024-04-02 - 2024-04-27)
# Materials: cement, sand, circuit pipe, Cpvc, &Pvc pipe
# 4th floor Columns casting : 11.144591439688748 days (2024-04-27 - 2024-05-08)
# Materials: TMT bar, cement, sand, aggregates
# 4th Floor slab casting: 19.498132295719845 days (2024-05-08 - 2024-05-28)
# Materials: TMT bar, cement, sand, aggregates, Pvc pipes, circuit pipes, lightbox, fan box
#  Brick work at 2nd Floor : 8.357276264591452 days (2024-05-28 - 2024-06-05)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 1st floor: 18.571725032425412 days (2024-06-05 - 2024-06-24)
# Materials: cement, sand, circuit pipe, Cpvc, &Pvc pipe
# 5th floor Columns casting : 12.07364461737997 days (2024-06-24 - 2024-07-06)
# Materials: TMT bar, cement, sand, aggregates
# 5th Floor slab casting: 20.423761348897543 days (2024-07-06 - 2024-07-26)
# Materials: TMT bar, cement, sand, aggregates, Pvc pipes, circuit pipes, lightbox, fan box
#  Brick work of 3rd to 5th Floor : 26.004773022049285 days (2024-07-26 - 2024-08-21)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 2nd-5th floor: 65.01193255512328 days (2024-08-21 - 2024-10-25)
# Materials: cement, sand, circuit pipe, Cpvc, &Pvc pipe
# Plastering on outer sides: 69.64396887159522 days (2024-10-25 - 2025-01-03)
# Materials: cement, sand
# Tiles work: 55.70894941634241 days (2025-01-03 - 2025-02-27)
# Materials: Tiles
# Painting and Finishing: 74.2889753566798 days (2025-02-27 - 2025-05-13)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 41.787548638132215 days (2025-05-13 - 2025-06-23)
# Materials: Wire, switch, nozzle Bib cock, shower, kitchen accessories, lights, fans, sheets, basin, sink, etc.
# Doors & Windows Fixing Furniture work: 65.01193255512328 days (2025-06-23 - 2025-08-27)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: DATTARAJ DEVELOPERS
# office_no	: 2532530653.0
# project_res_no: Sindh3s_Wardha2s_NASIK8S_518500
# Current Stage: completed
# Total Days: 715.66
# Stage Details:
# -----------------
# Organization Name: Shree Siddhivinayak Developers
# office_no	: 9820264648.0
# project_res_no: THANE7S_OMC4_271000
# Current Stage: running
# Total Days: 717.88
# Stage Details:
# Slab of B (bottom) : 13.96614785992215 days (2023-10-30 - 2023-11-13)
# Materials: TMT bar, cement, sand, aggregates
#  Ground Floor slab casting : 26.07014267185478 days (2023-11-13 - 2023-12-09)
# Materials: TMT bar, cement, sand, aggregates, Pvc pipes, circuit pipes, lightbox, fan box
#  1st floor Columns casting: 10.242127107652445 days (2023-12-09 - 2023-12-19)
# Materials: TMT bar, cement, sand, aggregates
#  1st Floor slab casting: 18.622049286640696 days (2023-12-19 - 2024-01-07)
# Materials: TMT bar, cement, sand, aggregates, Pvc pipes, circuit pipes, lightbox, fan box
# 2nd floor Columns casting : 10.242127107652445 days (2024-01-07 - 2024-01-17)
# Materials: TMT bar, cement, sand, aggregates
# 2nd Floor slab casting: 19.553151750972766 days (2024-01-17 - 2024-02-06)
# Materials: TMT bar, cement, sand, aggregates, Pvc pipes, circuit pipes, lightbox, fan box
#  Brick work at Basement to Ground Floor : 16.759377431906618 days (2024-02-06 - 2024-02-22)
# Materials: blocks/bricks
# 3rd floor Columns casting : 11.173229571984468 days (2024-02-22 - 2024-03-04)
# Materials: TMT bar, cement, sand, aggregates, Pvc pipes, circuit pipes, lightbox, fan box
# 3rd Floor slab casting: 20.483683527885823 days (2024-03-04 - 2024-03-25)
# Materials: TMT bar, cement, sand, aggregates
#  Brick work at 1st Floor : 8.379688715953321 days (2024-03-25 - 2024-04-02)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at basement- ground floor: 25.139066147859918 days (2024-04-02 - 2024-04-27)
# Materials: cement, sand, circuit pipe, Cpvc, &Pvc pipe
# 4th floor Columns casting : 11.173229571984468 days (2024-04-27 - 2024-05-09)
# Materials: TMT bar, cement, sand, aggregates
# 4th Floor slab casting: 19.553151750972766 days (2024-05-09 - 2024-05-28)
# Materials: TMT bar, cement, sand, aggregates, Pvc pipes, circuit pipes, lightbox, fan box
#  Brick work at 2nd Floor : 8.379688715953321 days (2024-05-28 - 2024-06-06)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 1st floor: 18.622049286640696 days (2024-06-06 - 2024-06-24)
# Materials: cement, sand, circuit pipe, Cpvc, &Pvc pipe
# 5th floor Columns casting : 12.104332036316466 days (2024-06-24 - 2024-07-06)
# Materials: TMT bar, cement, sand, aggregates
# 5th Floor slab casting: 20.483683527885823 days (2024-07-06 - 2024-07-27)
# Materials: TMT bar, cement, sand, aggregates, Pvc pipes, circuit pipes, lightbox, fan box
#  Brick work of 3rd to 5th Floor : 26.07014267185478 days (2024-07-27 - 2024-08-22)
# Materials: blocks/bricks
# Electrical concealed, PVC Fitting, plastering at 2nd-5th floor: 65.17535667963676 days (2024-08-22 - 2024-10-26)
# Materials: cement, sand, circuit pipe, Cpvc, &Pvc pipe
# Plastering on outer sides: 69.8307392996108 days (2024-10-26 - 2025-01-04)
# Materials: cement, sand
# Tiles work: 55.86614785992213 days (2025-01-04 - 2025-03-01)
# Materials: Tiles
# Painting and Finishing: 74.48819714656298 days (2025-03-01 - 2025-05-14)
# Materials: paint, putty, primer
# Plumbing & Sanitary,Electrification Works: 41.89961089494157 days (2025-05-14 - 2025-06-25)
# Materials: Wire, switch, nozzle Bib cock, shower, kitchen accessories, lights, fans, sheets, basin, sink, etc.
# Doors & Windows Fixing Furniture work: 65.17535667963676 days (2025-06-25 - 2025-08-29)
# Materials: Furniture, hardware, glass
# -----------------
# Organization Name: V4 Infra
# office_no	: 7152249538.0
# project_res_no: Sindh3s_Wardha2s_NASIK8S_265000
# Current Stage: completed
# Total Days: 720.1
# Stage Details:
# -----------------
# Organization Name: Vijay Supreme Builders Private Limited
# office_no	: 1414043359.0
# project_res_no: RAJ/P/2019/883
# Current Stage: completed
# Total Days: 727.49
# Stage Details:
# -----------------
# Organization Name: BALARAM PIRAJI SHINGTE
# office_no	: 2025430643.0
# project_res_no: Nagpur5_Sangli_4s_Kohlapur_4s_764500
# Current Stage: completed
# Total Days: 721.57
# Stage Details:
# -----------------

# %%
import pandas as pd

# Create a list to store the data
data = []

# Iterate through each row (project) in the new_data DataFrame
for index, row in new_data.iterrows():
    current_materials = []  # List to store materials for the current stage
    current_stage_start_date = current_date  # Initialize with the current date
    project_id = f'Project_{index + 1}'  # Generate a project_id

    for stage in stage_columns:
        stage_duration = row[stage]

        if not pd.isna(stage_duration):
            # Calculate the stage end date
            stage_end_date = current_stage_start_date + pd.Timedelta(days=stage_duration)

            # Format the dates for display
            start_date_str = current_stage_start_date.strftime('%m/%d/%Y')
            end_date_str = stage_end_date.strftime('%m/%d/%Y')

            # Check if there are materials for this stage
            materials = stage_materials.get(stage, [])

            if materials:
                # Store the data in the desired format
                data.append([end_date_str, stage, ", ".join(materials), project_id, row['organisation_name'], row['office_no'], row['project_res_no']])

            # Update the start date for the next stage
            current_stage_start_date = stage_end_date

# Create a DataFrame from the data
output_data = pd.DataFrame(data, columns=['Date', 'Stage', 'Recommended Materials', 'Project_ID', 'organisation_name', 'office_no', 'project_res_no'])

# Save the DataFrame to a CSV file
output_data.to_csv('output_5_final.csv', index=False)
